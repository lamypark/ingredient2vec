# %%
# import modules & set up logging
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

import os

# Set file names for train and test data
# test_data_dir = '{}'.format(os.sep).join([gensim.__path__[0], 'test', 'test_data']) + os.sep
test_data_dir = 'data/'
lee_train_file = test_data_dir + 'ingredient8_split'

class MyText(object):
    def __iter__(self):
        for line in open(lee_train_file):
            # assume there's one document per line, tokens separated by whitespace
            yield line.lower().split()

sentences = MyText()

print(sentences)

# %%
# default value of min_count=5
model = gensim.models.Word2Vec(sentences, min_count=5)
# default value of size=100
model = gensim.models.Word2Vec(sentences, size=200)
# default value of workers=3 (tutorial says 1...)
model = gensim.models.Word2Vec(sentences, workers=4)

# %%
for i in model.most_similar('beef', '', 100):
    print i
# Out:
# ('baked_potato', 0.9983985424041748)
# ('bantu_beer', 0.998054027557373)
# ('black_bean', 0.9979210495948792)
# ('beer', 0.9977806806564331)
# ('bean', 0.9974877238273621)
# ('bacon', 0.9962350130081177)
# ('banana', 0.9955548048019409)
# ('bilberry', 0.9941393136978149)
# ('boiled_beef', 0.9939573407173157)
# ('black_tea', 0.9932159185409546)
# ('blue_cheese', 0.9928322434425354)
# ('boiled_chicken', 0.9917547702789307)
# ('blackberry', 0.9916820526123047)
# ('black_seabream', 0.9915711879730225)
# ('apple', 0.9888812303543091)
# ('black_currant', 0.9882968664169312)
# ('apricot', 0.986116886138916)
# ('boiled_pork', 0.9830864667892456)
# ('blueberry', 0.9825741052627563)
# ('black_raspberry', 0.980803370475769)
# ('botrytized_wine', 0.9803411960601807)
# ('bell_pepper', 0.9796779155731201)
# ('black_chokecherry', 0.9792163372039795)
# ('boiled_mutton', 0.978651762008667)
# ('asparagus', 0.9779929518699646)
# ('berry', 0.9764797687530518)
# ('bog_blueberry', 0.9764487147331238)
# ('boiled_meat', 0.9764404892921448)
# ('black_chokeberry', 0.9744359254837036)
# ('brewed_tea', 0.9742902517318726)
# ('bartlett_pear', 0.9703357219696045)
# ('bread', 0.9681622385978699)
# ('brown_rice', 0.9676579236984253)
# ('apple_juice', 0.9660767316818237)
# ('butter', 0.9630687236785889)
# ('boiled_crab', 0.960349440574646)
# ('cabernet_sauvignon_grape', 0.9583876132965088)
# ('buckwheat', 0.9569962620735168)
# ('california_orange', 0.9520832896232605)
# ('brandy', 0.9520440101623535)
# ('cabernet_sauvignon_wine', 0.9505067467689514)
# ('avocado', 0.9424412250518799)
# ('apple_brandy', 0.936455249786377)
# ('cantaloupe', 0.934855043888092)
# ('black_pepper', 0.934587836265564)
# ('bilberry_wine', 0.9332782030105591)
# ('beet_root', 0.9330382347106934)
# ('camembert_cheese', 0.9295427799224854)
# ('cabbage', 0.9256010055541992)
# ('barley', 0.9192816019058228)
# ('cape_gooseberry', 0.9192367792129517)
# ('almond', 0.918053150177002)
# ('artichoke', 0.917003870010376)
# ('bourbon_whiskey', 0.9126919507980347)
# ('bitter_orange', 0.9116309881210327)
# ('catfish', 0.9093884825706482)
# ('ashanti_pepper', 0.9069652557373047)
# ('brazil_nut', 0.9053386449813843)
# ('buttermilk', 0.8987945914268494)
# ('ceylon_tea', 0.8957666158676147)
# ('champagne_wine', 0.887343168258667)
# ('california_orange_peel', 0.884520411491394)
# ('calamus', 0.8840618133544922)
# ('blenheim_apricot', 0.8816673755645752)
# ('california_pepper', 0.8777609467506409)
# ('cardamom', 0.8752155303955078)
# ('caviar', 0.8750960826873779)
# ('cheddar_cheese', 0.8750200271606445)
# ('celery', 0.8721029758453369)
# ('banana_passion_fruit', 0.8701200485229492)
# ('cherimoya', 0.8687617778778076)
# ('chicken', 0.8681807518005371)
# ('carrot', 0.8657985925674438)
# ('american_cranberry', 0.8649457693099976)
# ('cashew', 0.8638478517532349)
# ('cassia', 0.8616089820861816)
# ('brussels_sprout', 0.8608876466751099)
# ('cherry', 0.8534572720527649)
# ('black_sesame_seed', 0.8534525632858276)
# ('chinese_quince', 0.8529177904129028)
# ('capsicum', 0.851650059223175)
# ('cider', 0.8513717651367188)
# ('chicory_root', 0.8503803014755249)
# ('broccoli', 0.8500304222106934)
# ('babaco', 0.8498321175575256)
# ('cauliflower', 0.8444886207580566)
# ('cassava', 0.8406820297241211)
# ('buchu', 0.8393088579177856)
# ('cheese', 0.8389958739280701)
# ('anise_hyssop', 0.8338608741760254)
# ('capsicum_annuum', 0.833172082901001)
# ('bergamot', 0.8330681324005127)
# ('caja_fruit', 0.8306474685668945)
# ('chokeberry', 0.8285785913467407)
# ('cocoa', 0.8237601518630981)
# ('cayenne', 0.8219156861305237)
# ('clam', 0.8180853128433228)
# ('brazil_rosewood', 0.8153786063194275)
# ('basil', 0.8141719698905945)
# ('butterfat', 0.814103364944458)
