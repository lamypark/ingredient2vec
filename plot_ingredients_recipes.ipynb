# %%
import sys
print(sys.version)
# Out:
# 2.7.13 |Anaconda 4.4.0 (x86_64)| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %% [markdown]
# ## 구현에 필요한 함수 모듈들 구축
#
# #### load_embeddings(path), nemb[1:]
# #### load_vocab(path), vocab[1:]
# #### load_recipes(path), recipes
# #### run_tsne(nemb,multicore), tsne.fit_transform(nemb)
# #### build_food2cusine(recipes, vocab)
# #### make_plot(name, points, labels, legend_labels, legend_order, legend_label_to_color, pretty_legend_label, publish)

# %%
import os
import sklearn.manifold
import matplotlib.pyplot as plt
import h5py
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.offline as offline
import numpy as np
import collections
import pandas as pd
import itertools
import seaborn as sns
import time
import json
import re
from MulticoreTSNE import MulticoreTSNE as TSNE
# %load_ext wurlitzer

offline.init_notebook_mode()

flatten = lambda l: [item for sublist in l for item in sublist]

def load_embeddings(path):
    f = h5py.File(path, 'r')
    nemb = f['nemb'][:]
    f.close()
    return nemb[1:]


def load_vocab(path):
    vocab = []
    with open(path, 'r') as f:
        for line in f.readlines():
            split = line.split(' ')
            vocab.append((split[0].replace('\'', ''), int(split[1].rstrip())))
    # ignore UNK at position 0
    return vocab[1:]

def load_recipes(path):
    recipes = []
    with open(path, 'r') as f:
        for line in f:
            if line[0] == '#':
                pass
            else:
                recipes.append(line.rstrip().split(','))
    return recipes

def run_tsne(nemb, multicore=True):
    if multicore:
        tsne = TSNE(n_jobs=4)
    else:
        tsne = sklearn.manifold.TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, verbose=1)
    return tsne.fit_transform(nemb)
    
def build_food2cuisine(recipes, vocab):
    foods = [tup[0] for tup in vocab]
    food_counters = {food: collections.Counter() for food in foods}
    cuisine_counter = collections.Counter()
    for line in recipes:
            cuisine = line[0]
            cuisine_counter.update([cuisine])
            for food in line[1:]:
                if food in foods:
                    food_counters[food].update([cuisine])
    food2cuisine = {}
    for food, food_counter in food_counters.items():
        for cuisine in cuisine_counter.keys():
            food_counter[cuisine] = np.float32(food_counter[cuisine]) / np.float32(cuisine_counter[cuisine])
        sorted_food_counter = sorted(food_counter.items(), key=lambda a: a[1])[::-1]
        print(food, sorted_food_counter[0:2])
        food2cuisine.update({food: sorted_food_counter[0][0]})
    return food2cuisine


# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
tableau20_rgb = ['rgb' + str(triplet) for triplet in tableau20]

# Prettify ingredients
pretty_food = lambda s: ' '.join(s.split('_')).capitalize().lstrip()
# Prettify cuisine names
pretty_cuisine = lambda s: ''.join(map(lambda x: x if x.islower() else " "+x, s)).lstrip()


def make_plot(name, points, labels, legend_labels, legend_order, legend_label_to_color, pretty_legend_label, publish):
    lst = zip(points, labels, legend_labels)
    full = sorted(lst, key=lambda x: x[2])
    traces = []
    for legend_label, group in itertools.groupby(full, lambda x: x[2]):
        group_points = []
        group_labels = []
        for tup in group:
            point, label, _ = tup
            group_points.append(point)
            group_labels.append(label)
        group_points = np.stack(group_points)
        traces.append(go.Scattergl(
            x = group_points[:, 0],
            y = group_points[:, 1],
            mode = 'markers',
            marker = dict(
                color = legend_label_to_color[legend_label],
                size = 8,
                opacity = 0.6,
                #line = dict(width = 1)
            ),
            text = ['{} ({})'.format(label, pretty_legend_label(legend_label)) for label in group_labels],
            hoverinfo = 'text',
            name = legend_label
        )
        )
    # order the legend
    ordered = [[trace for trace in traces if trace.name == lab] for lab in legend_order]
    traces_ordered = flatten(ordered)
    def _set_name(trace):
        trace.name = pretty_legend_label(trace.name)
        return trace
    traces_ordered = list(map(_set_name, traces_ordered))
    layout = go.Layout(
        xaxis=dict(
            autorange=True,
            showgrid=False,
            zeroline=False,
            showline=False,
            autotick=True,
            ticks='',
            showticklabels=False
        ),
        yaxis=dict(
            autorange=True,
            showgrid=False,
            zeroline=False,
            showline=False,
            autotick=True,
            ticks='',
            showticklabels=False
        )
    )
    fig = go.Figure(data=traces_ordered, layout=layout)
    if publish:
        plotter = py.iplot
    else:
        plotter = offline.plot
    plotter(fig, filename=name + '.html')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Load Data

# %%
# path = '/home/jaan/fit/food2vec/2017-01-24'
path = '../fit/'

# 104534 embedded vectors - unique recipes?
nemb = load_embeddings(os.path.join(path, 'embeddings.h5'))

# 2088 vocabs - unique ingredients
vocab = load_vocab(os.path.join(path, 'vocab.txt'))

food2id = {tup[0]: i for i, tup in enumerate(vocab)}

for i in food2id:
    print i, food2id[i]
# Out:
# equal_sweetener 1306
# roasted_tomatoes 672
# mackerel 670
# stone_ground_cornmeal 1235
# tartar_sauce 1081
# bucatini 1210
# flanken_short_ribs 1751
# linguini 1402
# sweet_pickle_relish 1498
# pizza_doughs 466
# pancetta 373
# chat_masala 1244
# candied_cherries 1593
# baking_powder 99
# smoked_gouda 954
# unsalted_dry_roast_peanuts 666
# chocolate_chips 1184
# old_el_paso_flour_tortillas 2018
# serrano_chilies 564
# baby_greens 1121
# mild_green_chiles 1384
# black_pepper 18
# frozen_peaches 1589
# flounder_fillets 1419
# garden_peas 1179
# gremolata 1995
# peanut_butter 143
# cooking_oil 211
# pak_choi 1460
# tilapia_fillets 587
# low_sodium_taco_seasoning 1642
# chambord 1770
# idaho_potatoes 1219
# jamaican_jerk_spice 1978
# yellow_chives 1825
# orzo 535
# blackening_seasoning 1936
# black_mustard_seed_oil 919
# water_chestnuts 341
# celery_oil 142
# red_bean 864
# ravva 1437
# almond 80
# bacon 63
# lavender 559
# millet 2019
# soppressata 1185
# chinese_chives 811
# powdered_sugar 207
# mascarpone 415
# milk_fat 149
# galangal 550
# lima_beans 869
# croutons 777
# old_el_paso_taco_seasoning_mix 1307
# hot_curry_powder 1552
# kefalotyri 1553
# jasmine 384
# ramps 1445
# broccolini 1032
# pickling_salt 1380
# vine_ripened_tomatoes 841
# snappers 1548
# swordfish_steaks 1028
# leaves 525
# stevia 1275
# maple_syrup 188
# chow_mein_noodles 866
# smoke 210
# canola 835
# hot_dog_bun 1508
# red_kidnei_beans 1131
# whitefish_fillets 1047
# shiso_leaves 1626
# gochujang_base 428
# herbes_de_provence 623
# soybean 138
# shoyu 1041
# pasta_shell_small 1910
# frozen_green_beans 1623
# sazon_seasoning 2011
# queso_anejo 1861
# neutral_oil 796
# golden_brown_sugar 558
# blueberry 214
# baby_arugula 728
# anchovy_paste 617
# toasted_sesame_seeds 277
# red_beans 608
# pecan 83
# fajita_size_flour_tortillas 1363
# nori 520
# hungarian_paprika 981
# _cooked_and_drained 955
# refrigerated_pizza_dough 837
# smoked_sausage 232
# pastry_dough 940
# crackers 803
# root 539
# guajillo_chiles 680
# vodka 585
# chayote 963
# honey 52
# veggies 949
# cotija 434
# waxy_potatoes 880
# suet 1123
# cocktail_cherries 888
# chanterelle 1238
# nuts 839
# cottage_cheese 250
# buns 1165
# asian_eggplants 1215
# white_mushrooms 648
# piecrust 1469
# reduced_sodium_tamari_sauce 1755
# toasted_cashews 1927
# sandwich_buns 1893
# parsnips 613
# rock_sugar 1134
# salsa 147
# peeled_prawns 2081
# wish_bone_italian_dressing 1519
# prepar_pesto 1090
# pigeon_peas 1412
# pound_cake 1225
# frozen_chopped_spinach 320
# oysters 650
# wine 44
# cointreau_liqueur 1670
# orange_juice 101
# jumbo_pasta_shells 757
# chocolate_bars 1615
# crumbs 1097
# hot_italian_sausages 724
# caster 1973
# soba_noodles 609
# roasted_sesame_seed 192
# plantains 801
# bass_fillets 1788
# avocado 95
# beaten_eggs 663
# short_pasta 1779
# green_chilies 166
# tomato_juice 376
# fig 380
# savory 422
# fregola 2002
# coffee 148
# table_salt 570
# caramels 1512
# nonstick_spray 710
# yardlong_beans 1033
# silver 1720
# bread 34
# meat 124
# thyme 41
# potatoes 140
# gingerroot 462
# baby_lima_beans 862
# chuck 614
# roast 1014
# vinaigrette_dressing 1607
# roasted_white_sesame_seeds 1844
# rosemary 77
# cornbread 1092
# sausage_links 662
# allspice 449
# sugar_substitute 1717
# prawn 659
# adobo 1233
# waffle 2004
# turnip 334
# sweet_potato 204
# papaya 490
# dried_pinto_beans 887
# black_sesame_seed 964
# extract 1239
# genoa_salami 915
# sesame_oil 55
# sliced_carrots 505
# grapes 1169
# split_peas 1818
# semolina_flour 658
# serrano_peppers 496
# light_brown_sugar 229
# crme_de_cassis 1953
# raisin 96
# seafood_stock 1206
# garbanzo_beans 418
# soda 1048
# chili_beans 980
# fresh_tomatoes 420
# large_eggs 71
# tilapia 912
# dark_chocolate_chip 1933
# lettuce 85
# tzatziki 1164
# tamarind 98
# lumpia_skins 1453
# borlotti_beans 1948
# chipotle_sauce 1592
# spinach 245
# bonito 1501
# licorice 1019
# pickled_jalapenos 944
# caster_sugar 447
# kiwi 430
# cornichons 865
# grit_quick 1682
# pickle_juice 1763
# canela 1197
# cornflour 501
# dried_guajillo_chiles 1069
# sliced_olives 1450
# cereal 332
# hazelnut 265
# masa_dough 1385
# enokitake 730
# black_fungus 1950
# no_salt_added_diced_tomatoes 1144
# mochiko 1530
# self_raising_flour 1908
# perilla 1349
# luke_warm_water 1727
# thai_red_curry_paste 453
# taco_seasoning_reduced_sodium 1729
# ginger 21
# seed 119
# poblano_chilies 858
# dried_chile_peppers 1993
# hard_shelled_clams 1645
# mint 84
# brine_cured_green_olives 1659
# spicy_sausage 1499
# striped_bass 1633
# haas_avocados 1790
# broiler_fryers 1871
# shredded_colby 1907
# smoked_sweet_spanish_paprika 1527
# goat_cheese 297
# tostada_shells 991
# baby_portobello_mushrooms 1248
# refrigerated_biscuits 1354
# oil_cured_black_olives 1056
# gravy 992
# grenadine 1938
# mixed_nuts 1740
# italian_salad_dressing_mix 1664
# chipotle_paste 1692
# shallots 111
# khoa 1549
# watercress 307
# fried_eggs 1286
# macadamia_nut 503
# ditalini 1440
# jerk_marinade 2047
# epazote 769
# pineapple 92
# taco_shells 638
# creole_seasoning 285
# snapper_fillets 1547
# food_colouring 867
# armagnac 972
# coarse_sea_salt 611
# sago 1951
# red_chile_sauce 1590
# tequila 273
# sage 116
# lardons 1746
# chile_powder 459
# fennel 104
# madeira 856
# sub_buns 1634
# leg_quarters 1706
# spike_seasoning 1352
# yellow_split_peas 966
# pernod 1070
# toast 1150
# skirt_steak 589
# sunflower_seeds 1254
# shellfish 891
# frozen_lemonade_concentrate 1312
# jeera 951
# sugar 35
# celery 40
# boneless_sirloin_steak 1316
# porridge_oats 2041
# polenta 419
# brussels_sprouts 834
# mung_bean 1117
# chipotle 976
# rice 20
# mesclun 1617
# sour_milk 739
# fudge_brownie_mix 1884
# pepitas 1053
# watermelon 407
# chutney 685
# small_pasta 1649
# splenda_no_calorie_sweetener 1900
# rajma 1596
# arrowroot_powder 1267
# greens 517
# ragu_old_world_style_pasta_sauc 1151
# bay 58
# whitefish 850
# pressed_tofu 1738
# tapioca_flour 718
# dashi_powder 1191
# grape_juice 162
# sweet_potatoes_&_yams 1644
# baby_back_ribs 1136
# nut 129
# lemonade 1803
# emerils_original_essence 2063
# field_peas 1543
# muscovado_sugar 1057
# chile_paste 752
# swiss_chard 497
# cocktail_sauce 2077
# green_apples 1667
# yogurt 89
# lemon_peel 173
# club_soda 751
# roasted_cashews 817
# unsalted_roasted_peanuts 1110
# sesame_seeds 177
# ancho 1408
# soaking_liquid 2029
# brine_cured_black_olives 1091
# mahimahi 1916
# curry_powder 175
# huckleberry 1473
# fresh_red_chili 857
# raw_cane_sugar 1956
# _well_scrub 1872
# seedless_red_grapes 988
# jelly 1040
# hummus 1023
# cake_flour 370
# cod 280
# cherry 103
# jack 974
# cube_steaks 2022
# pepperoncini 1018
# french_baguette 754
# raita 1595
# marmite 1438
# fleur_de_sel 977
# beef 28
# sauterne 1847
# shiitake 132
# parsley 23
# basmati 2054
# cornflake_crumbs 1845
# beer 191
# grapefruit 378
# beet 311
# gyoza 1317
# pinto_beans 382
# basil 33
# roasted_beef 326
# cranberries 889
# low_sodium_worcestershire_sauce 1325
# rotelle 881
# sprite 1334
# mushroom 59
# bawang_goreng 1051
# baked_potato 1584
# dried_tart_cherries 1175
# extra_firm_tofu 438
# chili 362
# ritz_crackers 1868
# sweet_vermouth 1444
# fresh_curry_leaves 604
# fresh_raspberries 528
# uncooked_vermicelli 2075
# whipped_topping 791
# shirataki 1601
# red_chili_peppers 180
# angel_food_cake 1969
# pitted_kalamata_olives 342
# kimchi_juice 1920
# pitas 735
# dumplings 896
# quinces 1358
# chervil 555
# mixed_mushrooms 1666
# jerk_sauce 1904
# red_kidney_beans 522
# medium_tomatoes 1695
# fava_beans 941
# pizza_sauce 565
# sliced_green_onions 213
# carnation 2084
# vegetable 32
# top_sirloin_steak 929
# pomegranate_molasses 1784
# yellow_peppers 700
# hand 1203
# passata 996
# aai_powder 2030
# garlic 0
# tuna 182
# butter 2
# chocolate_candy_bars 1855
# sirloin_tip_roast 2045
# condiments 1488
# chopped_fresh_herbs 1133
# creole_style_seasoning 1599
# carnitas 1494
# udon 729
# burgers 2072
# chili_powder 90
# fideos 1909
# dungeness_crabs 1361
# orange_peel 196
# kale 271
# satsuma_imo 1827
# pink_beans 2040
# ham 94
# chopped_green_chilies 665
# dried_black_beans 820
# cognac 399
# kelp 344
# mexicorn 1083
# galanga 825
# green_tomatoes 483
# pillsbury_refrigerated_crescent_dinner_rolls 1506
# campanelle 1838
# sweet_peas 1375
# chives 340
# andouille_sausage 293
# heinz_chili_sauce 2048
# urad_dal 607
# fresh_mozzarella_balls 2034
# himalayan_salt 1417
# flavoring 965
# mirin 206
# toasted_pecans 975
# chilli_paste 993
# hominy 578
# meringue 1575
# herdez_salsa_verde 1882
# phyllo_dough 618
# sponge 1834
# frozen_vegetables 1777
# ground_cloves 242
# cavatelli 1480
# asafoetida 591
# okra 226
# mexican_chorizo 860
# black_olives 317
# ice 477
# hellmanns_real_mayonnaise 1848
# bartlett_pear 1006
# asafetida 763
# corn 16
# flour_for_dusting 753
# file_powder 717
# rump_roast 1281
# pepperidge_farm_puff_pastry 1930
# frangelico 1415
# breakfast_sausages 900
# ricotta_salata 959
# prepar_salsa 903
# lingonberry 1636
# plum 130
# turbinado 701
# sushi_nori 2007
# half_&_half 255
# baked_beans 1540
# octopus 750
# flatbread 939
# sliced_mushrooms 306
# beefsteak_tomatoes 983
# hoagie_rolls 1211
# sofrito 2008
# grated_pecorino 1732
# loin 1605
# soy 1369
# rounds 2020
# tomatillo_salsa 1497
# maldon_sea_salt 1610
# amchur 543
# low_fat_mayonnaise 1088
# amaretti_cookies 1397
# gin 554
# sweet_potatoes 218
# diced_tomatoes_and_green_chilies 1647
# pinenuts 251
# soft_taco_size_flour_tortillas 2033
# panettone 1873
# pitted_black_olives 731
# tempeh 1163
# cremini_mushrooms 435
# paprika 122
# whiskey 230
# atta 1464
# kosher_salt 67
# parmagiano_reggiano 1313
# splenda_brown_sugar_blend 2062
# hot_water 247
# short_rib 925
# rolled_oats 861
# chinese_sesame_paste 1966
# dinner_rolls 1520
# sprouts 1217
# cacao 756
# dashi_kombu 1178
# saltines 797
# mole_sauce 1335
# baguette 290
# kaiser_rolls 1430
# mini_chocolate_chips 1757
# sweet_gherkin 1896
# venison 1862
# baking_spray 1992
# chocolate_syrup 1243
# leek 231
# truffles 2015
# campari 1570
# blue_crabs 1389
# sesame 967
# fat_free_mayonnaise 973
# gala_apples 1297
# chaat_masala 748
# sea_scallops 469
# mahi_mahi_fillets 1468
# _drained_and_chopped 1495
# caraway 262
# _well_scrubbed 1888
# potato 49
# monterey_jack 313
# monkfish_fillets 1724
# cherry_brandy 844
# chopped_pecans 282
# whole_allspice 961
# fusilli 687
# lemon_juice 43
# sauvignon_blanc 2067
# dried_cornhusks 1632
# sunflower_oil 492
# chilegarlic_sauce 1336
# guava 1112
# anise_seed 553
# milk 7
# granulated_white_sugar 1072
# grape 181
# camembert_cheese 1360
# accent_seasoning 1823
# canola_mayonnaise 1471
# couscous 358
# globe_eggplant 1982
# thai_pepper 545
# frozen_pizza_dough 1990
# cold_water 205
# icing 1781
# yeast 48
# pan_drippings 1331
# seasoned_flour 1830
# grape_brandy 1629
# farro 1071
# brewed_espresso 1204
# ground_paprika 1016
# marinara_sauce 315
# catalina_dressing 1655
# peaches 296
# bouquet_garni 1100
# tortillas 325
# teas 814
# biryani_masala 1436
# cane_sugar 1096
# peeled_tomatoes 590
# triple_sec 838
# pepperoni_slices 824
# soft_tofu 733
# pork 46
# kraft_zesty_italian_dressing 2032
# seasoning 437
# currant 270
# frankfurter 819
# flour_tortillas 155
# port 1082
# gnocchi 780
# tapioca 2001
# channa_dal 1571
# dried_mixed_herbs 1577
# chip_plain_tortilla 1467
# mussels 368
# corn_flake 321
# cake_mix 1793
# water 31
# light_red_kidney_beans 2050
# biscuit_dough 1388
# bisquick 1411
# fine_granulated_sugar 1958
# frosting 1101
# _cook_and_drain 997
# ancho_powder 573
# crumbles 1404
# jalapeno_chilies 100
# sweet_and_sour_sauce 1333
# cornbread_stuffing_mix 1805
# cinnamon 24
# green_peas 336
# radish 201
# crumbled_cornbread 1865
# cajun_seasoning 241
# gyoza_wrappers 1126
# reduced_fat_mayonnaise 1015
# red_chile_powder 1099
# sake 145
# chees_fresco_queso 845
# ground_tumeric 978
# cooking_apples 1554
# yellow_lentils 1314
# flank_steak 298
# lily_buds 1637
# msg 909
# fine_sea_salt 279
# yoghurt 303
# thai_green_curry_paste 703
# cool_whip 1353
# brown_gravy_mix 1989
# white_sesame_seeds 581
# vin_santo 1787
# chocolate 759
# green_split_peas 1741
# olive 11
# spearmint 1447
# peaches_in_heavy_syrup 1885
# ice_cubes 448
# green_olives 375
# kefir 1996
# steak_seasoning 1581
# soup 843
# wonton_wrappers 402
# boiling_potatoes 511
# dried_chickpeas 1013
# mayonaise 165
# jerk_seasoning 1586
# hemp_seeds 1870
# dried_fettuccine 1269
# cornflakes 2046
# harissa 772
# top_round_steak 945
# heirloom_tomatoes 836
# pomegranate_seeds 916
# petite_peas 2042
# guanciale 1042
# loaves 1730
# oil_cured_olives 1475
# pot_roast 2012
# foie_gras 1373
# crushed_pineapples_in_juice 1517
# kumquats 1201
# gelatin 106
# red_food_coloring 597
# demi_glace 1931
# date 222
# liquid 651
# curry 610
# fronds 882
# diced_green_chilies 484
# fresh_peas 829
# mango 169
# tahini 639
# coconut_oil 1177
# harissa_sauce 1841
# chickpea 217
# white_cake_mix 1168
# marshmallows 1688
# dried_salted_codfish 1086
# prosecco 1368
# confit 1677
# green_beans 253
# pappardelle_pasta 1752
# allspice_berries 894
# frozen_sweet_peas 1690
# carbonated_water 1291
# lasagna_noodles 312
# yams 782
# new_potatoes 749
# lo_mein_noodles 923
# red_lentils 479
# red_enchilada_sauce 627
# roasting_chickens 644
# ahi 2051
# japanese_turnips 1359
# green_curry_paste 743
# black_mission_figs 1541
# prebaked_pizza_crusts 1237
# baby_carrots 593
# prunes 646
# ketchup 227
# gemelli 1257
# chopped_tomatoes 274
# pinot_noir 1680
# collard_greens 385
# crushed_ice 702
# beef_broth 161
# stir_fry_sauce 1259
# chinese_five_spice_powder 300
# chipotle_chile 413
# amaretto 926
# hatch_green_chiles 1715
# french_rolls 1452
# all_purpose_flour 45
# and_fat_free_half_half 958
# free_range_chickens 1762
# leeks 224
# horseradish 203
# rye_flour 440
# tomatoes_with_juice 546
# linguine 302
# tart_shells 1643
# chiles 259
# walnuts 470
# mixed_peel 1901
# aioli 1465
# anjou_pears 1759
# thai_noodles 1461
# mission_figs 1791
# fettucine 401
# flora_cuisine 1442
# crescent_rolls 1524
# balsamic_vinaigrette 1485
# assorted_fresh_vegetables 2035
# pepperoni 691
# cheese 10
# graham_crackers 1195
# collard_green_leaves 2058
# parsnip 433
# roasted_sesame_seeds 933
# salsa_verde 442
# cassava 876
# salad_dressing 606
# cannellini_beans 343
# piment_despelette 1985
# chayotes 877
# groundnut 1466
# masala 603
# rouille 1852
# baked_pizza_crust 1390
# miniature_semisweet_chocolate_chips 1975
# vermicelli 783
# dried_currants 521
# tortilla_chips 269
# pierogi 1709
# jaggery 784
# oats 1226
# breadstick 1223
# oreo_cookies 1761
# browning 1075
# spareribs 1264
# rioja 2005
# apples 388
# fresh_herbs 690
# cane_syrup 1578
# cane_molasses 30
# coconut 50
# filet_mignon 1451
# ras_el_hanout 760
# slaw 1058
# port_wine 716
# baby_potatoes 1111
# stewed_tomatoes 377
# pastry 741
# manicotti 1919
# italian_eggplant 1483
# toasted_almonds 790
# filet_mignon_steaks 1864
# italian_sausage 436
# small_new_potatoes 1365
# quickcooking_grits 548
# mature_cheddar 1799
# halibut 956
# chocolate_curls 1846
# plain_breadcrumbs 1241
# pearl_onions 552
# enchilada_sauce 276
# button_mushrooms 392
# dried_dates 1819
# pizza_crust 764
# dried_kidney_beans 1249
# beef_liver 1459
# seafood 1345
# toasted_pine_nuts 787
# crme_frache 423
# nioise_olives 947
# roasted_pistachios 1783
# radicchio 664
# salt 6
# angostura_bitters 1308
# porterhouse_steaks 1814
# banger 1718
# green_peppercorns 1141
# diced_onions 308
# rye_bread 537
# roast_red_peppers 738
# calamari 1190
# chocolate_sprinkles 1125
# queso_fresco 431
# dried_dillweed 846
# gold_potatoes 1343
# nectarine 704
# celtic_salt 1582
# fajita_seasoning_mix 1061
# bamboo_shoots 439
# wood 601
# black 1794
# daal 1537
# cornish_game_hens 1309
# plums 619
# pumpkin 144
# sun_dried_tomatoes_in_oil 828
# chillies 458
# green_chile 268
# furikake 1631
# fatback 1420
# chop_green_chilies 2086
# bitters 1304
# baby_eggplants 1832
# red_vermouth 2031
# ground_round 721
# cumin 29
# poultry_seasoning 642
# dulce_de_leche 1965
# fresh_chives 473
# vermicelli_noodles 1105
# chinese_black_mushrooms 1362
# masa_harina 510
# sesame_paste 1128
# curry_paste 487
# baking_soda 151
# mutton 938
# roasted_peanut 390
# white_sugar 135
# herb_seasoning 1382
# crawfish 465
# glaze 1036
# roasted_meat 1227
# roasted_red_peppers 310
# calvados 1043
# mandarin 260
# edamame 694
# cantaloupe 984
# unsweetened_soymilk 1815
# spring_roll_wrappers 667
# chili_oil 480
# brassica 481
# gran_marnier 1295
# dates 669
# sweet_paprika 443
# kidney_beans 400
# berry 369
# kahla 1066
# chorizo 612
# wheels 1463
# hot_dogs 998
# tabasco_pepper 146
# sugar_syrup 1656
# canned_tomatoes 583
# boar 2027
# hoisin_sauce 228
# sliced_black_olives 396
# brats 1753
# turkey 107
# olives 408
# ground_sausage 1522
# artichokes 584
# chopped_nuts 1284
# shortening 316
# hamburger_buns 682
# vegan_worcestershire_sauce 2079
# mashed_potatoes 641
# ravioli 1209
# pace_chunky_salsa 1628
# cooked_meatballs 1737
# graham_cracker_crusts 1441
# seasoning_salt 445
# red_wine 114
# squash 141
# arrowroot 1253
# pickling_spices 1068
# elbow_pasta 1807
# sweet_chili_sauce 475
# chunky_pasta_sauce 1742
# coco 1728
# chocolate_shavings 1149
# passion_fruit 1087
# twists 1962
# tortilla_wraps 1952
# shredded_carrots 404
# casings 1821
# red_kidney_bean 660
# frozen_mixed_berries 1434
# dry_rub 1795
# lumpia_wrappers 1199
# mild_salsa 1863
# dri_leav_rosemari 1869
# bows 1877
# macaroni 65
# catfish 347
# queso_asadero 1567
# oil 93
# canned_chopped_tomatoes 1580
# merguez_sausage 1691
# fruit 189
# tortilla_shells 1521
# taro 1378
# salmon_roe 1298
# southern_comfort 1859
# brown_rice 254
# flaked 1939
# broth 516
# tapenade 1311
# veal 239
# grappa 1546
# curry_leaves 330
# figs 853
# blanched_almonds 524
# fresh_green_peas 1503
# posole 1835
# old_el_paso_enchilada_sauce 1531
# cockles 1585
# other_vegetables 1946
# steamer 1470
# cabernet_sauvignon 1588
# cilantro 25
# rose 504
# gram_flour 859
# cayenne 15
# chinese_sausage 946
# diced_tomatoes 102
# nectarines 969
# refrigerated_fettuccine 1602
# pasta_shells 897
# curry_sauce 1260
# dipping_sauces 661
# endive 394
# broad_beans 2028
# splenda 1220
# uncooked_ziti 1839
# slivered_almonds 387
# spring!_water 2069
# dal 1262
# wax_beans 1915
# nuoc_cham 1532
# clam 187
# whole_kernel_corn 488
# crostini 1802
# frozen_limeade 1774
# tandoori_paste 2049
# _slice 719
# hog_casings 1980
# _sliced 1778
# liquid_aminos 1684
# kraft_miracle_whip_dressing 1994
# straw_mushrooms 883
# espresso_beans 1963
# naan 807
# lobster 353
# spring_onions 233
# sweet_cherries 1065
# pickles 833
# lentils 542
# baby_spinach 299
# russet_potatoes 295
# chicken_liver 692
# sweet_mini_bells 1296
# chips 684
# calamansi_juice 1188
# spelt_flour 2059
# mild_italian_sausage 1130
# coarse_salt 193
# grill_seasoning 1986
# harissa_paste 1046
# zest 1479
# smoked_kielbasa 1977
# 40_less_sodium_taco_seasoning_mix 2071
# taco_bell_home_originals 1981
# dark_chocolate 781
# pita_chips 1568
# haricots_verts 683
# sliced_shallots 1035
# piloncillo 1012
# chile_sauce 793
# thin_spaghetti 1338
# fresh_mozzarella 515
# chinese_eggplants 1487
# chvre 1566
# shrimp 51
# pistachio 305
# swiss_cheese 202
# great_northern_beans 708
# chive 120
# starchy_potatoes 1968
# small_white_beans 1207
# tawny_port 1045
# gari 711
# dumpling_wrappers 902
# chenpi 1754
# white_bread 243
# yam 526
# country_crock_spread 1062
# shells 773
# anise 186
# sponge_cake 1472
# _cut_into_italian_loaf 1621
# frozen_shelled_edamame 1329
# sorrel 1324
# chili_sauce 421
# brown_lentils 918
# radishes 283
# taco_sauce 637
# brine_cured_olives 1160
# tripe 1766
# nilla_wafers 1510
# anchovies 689
# bouillon 1193
# cornmeal 244
# maida_flour 1162
# sanding_sugar 1535
# freshly_grated_parmesan 493
# black_salt 1383
# boiling_water 248
# russet 1525
# tostadas 1240
# spaghettini 986
# edam 2061
# bartlett_pears 1287
# semi_sweet_chocolate_morsels 577
# nori_sheets 1108
# top_sirloin 1127
# seitan 2024
# natural_pistachios 1560
# navel_oranges 668
# tagliatelle 1044
# salted_peanuts 798
# branzino 1704
# pear 200
# peas 356
# dashi 451
# herbs 544
# brandy 197
# diced_pimentos 1780
# light_mayonnaise 647
# chili_paste 456
# bocconcini 1187
# masa 971
# giardiniera 1421
# golden_raisins 309
# (10_oz.)_frozen_chopped_spinach 1949
# chana_dal 1008
# extra_large_eggs 874
# pancake_mix 2074
# brussels_sprout 533
# ale 1319
# juniper_berries 1049
# frozen_blueberries 1140
# rock_salt 1294
# fat_free_frozen_top_whip 1416
# porcini 328
# crushed_graham_crackers 1798
# preserves 1377
# blueberries 873
# bertolli_alfredo_sauce 1679
# rib_eye_steaks 745
# anchovy_fillets 360
# french_dressing 1675
# chorizo_sausage 499
# dressing 636
# bow_tie_pasta 498
# pickle_relish 879
# turnips 472
# dried_udon 1923
# sugar_cane 1945
# lima_bean 416
# fat 530
# baton 1731
# yukon_gold_potatoes 333
# jalape 1348
# kidney_bean 223
# apple_brandy 809
# ramen 1665
# baby_bok_choy 547
# roma_tomatoes 318
# egg_noodle 266
# prosciutto 281
# _thaw 1812
# medium_salsa 1897
# cookies 931
# tea 291
# sirloin_tip 1745
# decorating_sugars 1561
# yellow_rock_sugar 1258
# bergamot 1705
# tom_yum_paste 2083
# bird_chile 656
# refrigerated_crescent_rolls 968
# crust 924
# mitsuba 1796
# scallops 799
# ground_chile 2060
# nopalitos 2009
# new_york_strip_steaks 1103
# madras_curry_powder 823
# sardines 1214
# asadero 1145
# boiling_onions 1224
# italian_herbs 1663
# hot_green_chile 1797
# smoked_paprika 252
# lasagne 1886
# base 810
# taco_seasoning 289
# salad_greens 715
# orecchiette 765
# guacamole 364
# grapeseed_oil 571
# bonito_flakes 795
# sweet_italian_sausage 575
# roquefort_cheese 1009
# pie_filling 1856
# chunky 1638
# matzo_meal 1550
# white_beans 572
# herring 1327
# chunky_salsa 598
# scotch_bonnet_chile 737
# bottle_gourd 1911
# worcestershire_sauce 176
# pears 514
# masoor_dal 1435
# red_miso 910
# boiled_eggs 1208
# garnish 1678
# coarse_kosher_salt 631
# jamaican_jerk_season 1022
# scallions 97
# melon 359
# pectin 1635
# won_ton_wrappers 771
# toasted_peanuts 1476
# sweet_pickle 1423
# unbaked_pie_crusts 1180
# chardonnay 1489
# flavored_syrup 1959
# malt 519
# enokidake 489
# diced_red_onions 734
# frozen_whip_topping 1843
# toasted_slivered_almonds 1265
# manioc_flour 1387
# rotini 655
# dried_lentils 747
# chinese_noodles 1027
# hamburger 1143
# penne_rigate 1154
# white_peaches 1800
# white_peppercorns 930
# bulk_italian_sausag 1060
# fingerling_potatoes 1077
# low_fat_mozzarella 1398
# greek_seasoning 767
# _peel_and_devein 1107
# goat 1744
# refried_beans 301
# char_siu 1686
# low_sodium_teriyaki_sauce 1854
# patis 1572
# cheddar_cheese 70
# doritos 1370
# fromage_blanc 1837
# dark_brown_sugar 261
# tentacles 1322
# rocket_leaves 713
# confectioners_sugar 237
# amaretto_liqueur 1668
# egg 4
# ripe_olives 529
# turmeric 86
# toasted_walnuts 979
# essence 1152
# limoncello 1921
# shichimi_togarashi 1142
# dough 495
# chipotle_peppers 615
# dark_leafy_greens 1735
# katsuobushi 722
# artichok_heart_marin 697
# hearts_of_romaine 1230
# bisquick_baking_mix 1653
# smoked_fish 1817
# ground_chuck 732
# prego_traditional_italian_sauce 1961
# pink_peppercorns 1347
# peanuts 234
# pesto 464
# sauce 216
# medium_eggs 995
# coca_cola 1386
# wasabi 345
# crimini_mushrooms 633
# ramen_noodles 649
# whole_peeled_tomatoes 452
# juniper_berry 854
# chicken_broth 61
# cointreau 1344
# english_muffins 1418
# red_curry_paste 457
# maltose 1551
# polish_sausage 1713
# dende_oil 1716
# flaxseed 1970
# biscuits 678
# five_spice 1095
# calamata_olives 1874
# clams 509
# mild_curry_powder 1277
# fish 53
# sole_fillet 1491
# lemongrass 209
# pepperoni_turkei 1672
# flower 818
# red_beets 1433
# granola 1425
# quince 932
# kalonji 1811
# _rins_and_drain 1003
# fresh_chevre 1124
# roasted_chestnuts 1809
# spanish_chorizo 709
# self_rising_cornmeal 804
# caramel_sauce 1114
# baked_tortilla_chips 885
# single_crust_pie 1340
# adzuki_beans 1935
# concord_grape 1427
# color_food_green 1176
# calamansi 1221
# glass_noodles 786
# chia_seeds 1661
# free_range_eggs 1529
# balsamico_bianco 1789
# miso 727
# rotel_tomatoes 962
# zinfandel 1502
# sooji 2070
# silken_tofu 755
# serrano_chile 272
# grand_marnier 898
# black_tea 805
# grenadine_syrup 1701
# red_capsicum 1228
# canola_oil 128
# sliced_tomatoes 999
# orange_flower 1129
# tapioca_pearls 1957
# brisket 1558
# scallion 47
# lotus_roots 1612
# methi 1166
# prepared_lasagne 1381
# syrup 892
# banana 136
# gochugaru 906
# goji_berries 1786
# mild_curry_paste 1851
# black_peppercorns 221
# kecap_manis 1159
# reduced_sodium_black_beans 1725
# creme_anglaise 1622
# gruyere_cheese 761
# tortellini 1030
# aai 1255
# sea_salt_flakes 1189
# pie_crust 653
# haddock 673
# sambal_chile_paste 1902
# olive_oil 17
# firm_tofu 339
# corn_grit 395
# hard_salami 1942
# fillets 576
# shucked_oysters 935
# wakame 1120
# juice 284
# fettuccine_pasta 907
# pappadams 2010
# jack_daniels 1891
# kewpie_mayonnaise 1826
# puff_pastry 696
# gai_lan 800
# italian_salad_dressing 620
# white_button_mushrooms 950
# confit_duck_leg 1609
# cooking_fat 1702
# sandwiches 1808
# sherry 125
# sliced_green_olives 2023
# zucchini 91
# fresca 1545
# eggs 62
# salmon 167
# brioche 1396
# fine_salt 990
# mixed_greens 635
# chocolate_morsels 1064
# bittersweet_chocolate 432
# chard 1456
# oyster 156
# pean 1898
# fines_herbes 1926
# hot_chili_paste 1703
# toasted_baguette 1559
# neufchtel 1858
# miso_paste 588
# vine_tomatoes 1509
# frozen_pastry_puff_sheets 485
# callaloo 1597
# burrata 1743
# instant_espresso_powder 643
# sausage_casings 482
# roasted_almonds 2055
# fritos 1528
# pitted_green_olives 778
# buttercream_frosting 2025
# poppy_seeds 600
# sambal_ulek 688
# squirt 1850
# batter 1555
# littleneck_clams 640
# xanthan_gum 1094
# fryer_chickens 1135
# crabmeat 567
# gaeta_olives 1698
# kasuri_methi 695
# dried_pappardelle 1726
# fresh_cranberries 1326
# crema_mexicana 1031
# sirloin_steak 602
# gouda 2026
# anaheim_chile 693
# dried_pasta 1292
# achiote_paste 1446
# dandelion_greens 1654
# nutella 1462
# elderberry 1954
# rome_apples 2037
# crema 826
# dark_molasses 1318
# tri_tip_roast 1857
# varnish_clams 1271
# hot_chili_sauce 822
# pico_de_gallo 568
# bulgur 987
# dried_scallops 1918
# shortbread_cookies 2043
# herdez_salsa_casera 1998
# frozen_spinach 712
# double_crust_pie 1710
# wonton_skins 1669
# chopped_walnuts 450
# yuzu 1932
# low_moisture_mozzarella 2085
# idli 1988
# eggplant 208
# blue_cheese 236
# raw_sugar 908
# shanks 1606
# chapati_flour 1662
# kirsch 1157
# pimentos 444
# prepared_guacamole 1890
# ground_walnuts 1511
# bosc_pears 1004
# scallop 292
# pear_brandy 1393
# pimenton 1648
# instant_espresso_granules 1881
# provolone_cheese 386
# coleslaw 1017
# yakisoba_noodles 1681
# warm_water 195
# dry_pasta 1364
# velveeta 895
# ciabatta 1000
# buttermilk 79
# sourdough_baguette 1443
# ragu_cheesi_classic_alfredo_sauc 1991
# panko 556
# pickling_cucumbers 1351
# raw_cashews 868
# granulated_sugar 157
# golden_delicious_apples 875
# sliced_almonds 361
# boston_butt 1976
# peppercorns 424
# part_skim_mozzarella 970
# white_miso 596
# soba 884
# french_fries 1685
# capsicum 707
# fontina 914
# potato_chip 624
# granny_smith_apples 460
# sriracha 275
# black_currant 1486
# chees_fresh_mozzarella 579
# frozen_mixed_thawed_vegetables 2053
# quail 1406
# rib 657
# firmly_packed_brown_sugar 527
# chestnuts 890
# tandoori_seasoning 2016
# duck_breast_halves 1849
# no_salt_added_black_beans 1153
# chicory 409
# dried_cranberries 698
# szechwan_peppercorns 429
# pasilla_chiles 913
# pomegranate 1620
# ziti 911
# king_prawns 1603
# riesling 1355
# cucumber 72
# pimento 256
# sandwich_rolls 1413
# chopped_almonds 726
# pie_dough 960
# picholine_olives 1293
# cooked_rigatoni 1569
# sumac 1067
# mixed_spice 851
# thai_chile 324
# somen 1687
# _undrain 2065
# sweet_potatoes_or_yams 2057
# jerusalem_artichokes 2068
# gumbo_file 1657
# roasted_pork 455
# peppermint_oil 1583
# uncook_medium_shrimp 1104
# margarine 329
# poha 1337
# alfredo_sauce 723
# pasta_sheets 1536
# cooked_vermicelli 1866
# yellow_curry_paste 1405
# fire_roasted_diced_tomatoes 1198
# lime_juice 112
# dhal 1399
# cherries 744
# kumquat 942
# massaman_curry_paste 1824
# arbol_chile 1505
# rigatoni 626
# italian_style_stewed_tomatoes 1181
# adobo_seasoning 1496
# boneless_chuck_roast 1011
# non_stick_spray 1379
# semolina 654
# polenta_prepar 1822
# queso_blanco 1477
# jackfruit 1200
# refrigerated_piecrusts 595
# eel 989
# pickled_vegetables 1246
# custard_powder 2078
# sorbet 1699
# yolk 1270
# palm 351
# schmaltz 1984
# green_onions 68
# lard 64
# pea 126
# blackberry 379
# rum 160
# rub 1171
# ground_allspice 246
# carob 1700
# stew 1625
# dried_red_chile_peppers 500
# raspberry 159
# smoked_salmon 513
# pastry_shell 1002
# fresh_pasta 1696
# unsalted_pistachios 1328
# mace 348
# oatmeal 582
# mulato_chiles 1424
# beans 506
# gherkins 1646
# hot_smoked_paprika 1330
# red_gold_diced_tomatoes 1983
# tart_apples 1216
# relish 1301
# tofu 441
# kirby_cucumbers 952
# fresh_mushrooms 288
# kielbasa 927
# maple_sugar 1768
# rolls 540
# dried_navy_beans 1707
# edible_flowers 1604
# spam 1944
# thai_chili_paste 1449
# bitter_orange 557
# ranch_style_beans 1563
# vegetable_oil 14
# green_bell_pepper 81
# filet 842
# raisins 215
# shredded_coleslaw_mix 1323
# paneer 478
# shiro_miso 1409
# oxtails 831
# cream_cheese 74
# navy_beans 1026
# margarita_mix 2066
# guajillo 1341
# apricot 158
# cavatappi 1422
# peppermint 417
# light_molasses 1089
# korean_chile_flakes 1024
# frozen_limeade_concentrate 1410
# dill 105
# sorghum_syrup 2073
# wholemeal_flour 2017
# crepes 1137
# old_fashioned_oats 1251
# kidney 1564
# meatloaf 2056
# lemon 22
# peach 190
# grouper 1212
# mixed_vegetables 1021
# saffron 171
# seasoning_mix 1773
# drippings 1611
# 40_less_sodium_taco_seasoning 1714
# long_beans 1147
# tart 1829
# achiote 1674
# mustard 38
# gardenia 1579
# quinoa 467
# bone_broth 2021
# white_cornmeal 549
# wafer 1875
# scotch 1474
# toor_dal 1192
# daikon 414
# wheat_bread 560
# sour_cherries 1290
# pomegranate_juice 1247
# berries 815
# chipotle_chile_powder 774
# grana_padano 1614
# hot_chili 1116
# cabernet_sauvignon_wine 1172
# dried_black_mushrooms 1608
# sea_bass_fillets 848
# morel 1276
# peanut 115
# frozen_mixed_vegetables 1119
# dried_chile 742
# curds 616
# flavored_oil 1458
# graham_cracker_crumbs 812
# taco_toppings 1694
# shell_pasta 1482
# truffle 512
# ouzo 1106
# asparagus 163
# ground_sirloin 625
# picante_sauce 676
# puff_pastry_sheets 1526
# snails 1782
# shiso 1102
# tandoori_spices 1098
# sultana 1158
# pie_shell 872
# roasted_hazelnuts 1025
# frisee 1109
# champagne 920
# wild_mushrooms 706
# marinade 563
# wheat 5
# poblano_peppers 461
# spaghetti 249
# giblet 1357
# chili_flakes 403
# sauerkraut 335
# tarragon 172
# chili_seasoning 2080
# soy_sauce 26
# espresso 1213
# challa 1828
# golden_caster_sugar 1303
# applesauce 1054
# chickpeas 235
# mini_marshmallows 816
# dry_roasted_peanuts 630
# gyoza_skins 1836
# red_apples 1941
# plain_flour 411
# kalamata 350
# raspberries 562
# hot_chili_powder 1038
# pancake 1776
# stuffing_mix 1619
# panko_breadcrumbs 426
# vinegar 19
# asiago 551
# cooking_spray 109
# mung_beans 840
# nopales 1037
# medium_curry_powder 1689
# buckwheat 468
# popcorn 476
# mussel 393
# spices 383
# white_hominy 605
# low_fat_spaghetti_sauce 1712
# baking_mix 1148
# apple 73
# whole_peppercorn 1063
# liqueur 776
# low_sodium_black_beans 1887
# italian_seasoned_breadcrumbs 905
# salted_cashews 1618
# duck 720
# lime 36
# rutabaga 699
# five_spice_powder 1076
# crab 164
# fresh_leav_spinach 671
# black_treacle 1785
# mexican_chocolate 878
# chestnut_mushrooms 1429
# pastry_flour 1999
# black_truffles 1394
# tangerine 574
# canned_black_beans 569
# rabbit 994
# white_chocolate_chips 1391
# black_beans 154
# salad 645
# andouille_sausage_links 1676
# chianti 1507
# baby_spinach_leaves 502
# cachaca 599
# vegetarian_refried_beans 1401
# yellow_miso 1078
# diced_potatoes 1820
# unsalted_cashews 937
# pappardelle 1400
# red_swiss_chard 1964
# old_el_paso_chopped_green_chiles 1366
# peperoncini 1650
# carrot 56
# peperoncino 1880
# fresno_chiles 1310
# onions 27
# lamb 137
# chocolate_sauce 1576
# rhubarb 357
# kewra_water 1928
# crema_mexican 917
# merlot 1613
# pasilla 1979
# stock 538
# kohlrabi 1523
# cardamom 133
# cardamon 1196
# pickled_beets 1914
# buffalo_sauce 1392
# mandarin_peel 1515
# simple_syrup 770
# frozen_peas 240
# mozzarella_cheese 121
# collards 1289
# cabbage 87
# pork_sausage 117
# tomato 12
# prawns 531
# serrano 871
# pasta_sauce 294
# peanut_oil 337
# safflower 1853
# white_chocolate 802
# rapeseed_oil 1274
# octopuses 1432
# pickled_carrots 1167
# refried_black_beans 1538
# artichoke 198
# yellow_cake_mix 1202
# sun_dried_tomatoes 398
# walnut 76
# dry_vermouth 789
# orange 60
# steak_sauce 1263
# moong_dal 1010
# lychees 1842
# large_flour_tortillas 1115
# macadamia_nuts 1431
# pecans 425
# blackberries 536
# citrus 381
# flour 118
# spelt 1867
# stout 953
# round_loaf 1929
# perciatelli 1750
# coriander 54
# mushrooms 194
# quick_cooking_oats 1113
# risotto 1376
# cider 110
# penne_pasta 372
# zesty_italian_dressing 1156
# tonkatsu_sauce 1272
# shaoxing 1600
# old_el_paso_thick_n_chunky_salsa 1739
# chopped_leaves 1772
# florets 762
# dijon 1940
# mincemeat 1395
# pistachios 632
# string_beans 1245
# escarole 652
# bbq_sauce 943
# lentil 286
# frozen_whipped_topping 1278
# whole_grain_wheat_flour 170
# chuck_steaks 1428
# cubed_potatoes 1719
# barley 278
# grits 365
# red 1455
# nam_pla 1640
# caper_berries 1831
# quail_eggs 1733
# ackee 1594
# louisiana_hot_sauce 1073
# tumeric 168
# salami 681
# spinach_leaves 594
# fresh_angel_hair 1960
# golden_beets 1905
# nigella_seeds 985
# crushed_tomatoes 220
# unbleached_flour 1639
# steak 634
# compote 2014
# johnsonville_andouille 1903
# chicken 8
# bell_pepper 39
# golden_syrup 901
# chinese_rock_sugar 2064
# bouquet 1972
# double_acting_baking_powder 1055
# romano_cheese 287
# frozen_hash_browns 1974
# adobo_sauce 523
# ponzu 1034
# chinese_cabbage 397
# frozen_pound_cake 1813
# dried_mushrooms 1122
# shallot 131
# sourdough_loaf 1947
# yukon_gold 1760
# hot_sauce 178
# ground_almonds 705
# drumstick 1775
# seafood_seasoning 1186
# capellini 1372
# italian_tomatoes 1050
# pesto_sauce 934
# hellmann_or_best_food_light_mayonnais 1346
# light_pancake_syrup 1500
# dried_thai_chili 2052
# light_alfredo_sauce 1542
# mortadella 1504
# carrots 75
# vegan_mayonnaise 1883
# clove 184
# noodles 322
# sprinkles 785
# roux 1516
# min 1268
# uncooked_rigatoni 1922
# bone_oil 714
# fermented_black_beans 821
# crisco 1711
# mo_hanh 1955
# yellow_food_coloring 1029
# frying_oil 1895
# duck_drumsticks 1194
# boneless_rib_eye_steaks 1356
# manicotti_shells 1079
# hanger_steak 1478
# beets 486
# frozen_edamame_beans 1139
# flat_anchovy 1723
# fresh_chile 1889
# soft_shelled_crabs 1734
# satsumas 1913
# matsutake 674
# unsweetened_chocolate 832
# fresh_chili 1804
# bittersweet_chocolate_chips 1591
# brine 1182
# seaweed 304
# sour_cherry 725
# all_purpose_unbleached_flour 371
# agave_nectar 561
# angel_hair 534
# vegan_margarine 1810
# tomatillos 257
# litchi 1562
# jam 928
# shelled_pistachios 1279
# whole_cloves 580
# chipotle_salsa 1302
# sweetener 1234
# baking_potatoes 338
# chile_de_arbol 788
# starch 78
# calimyrna_figs 1231
# bean 82
# molasses 491
# jicama 541
# pitted_olives 899
# self_rising_cake_flour 2039
# bourbon_whiskey 405
# hot_chili_oil 1252
# sea_bass 1118
# bengal_gram 1350
# annatto_seeds 1374
# prepared_pasta_sauce 1878
# nutmeg 57
# espresso_powder 1934
# cajun_spice_mix 1641
# violet 1840
# tubetti 1756
# kimchi 474
# organic_sugar 1736
# hungarian_sweet_paprika 813
# salted_roast_peanuts 849
# strawberry 134
# red_bell_pepper 1767
# meatballs 1052
# black_eyed_peas 349
# greek_style_vinaigrette 2036
# gluten_free_all_purpose_flour 1987
# _thawed_and_squeezed_dry 1007
# halibut_fillets 628
# cornbread_mix 1280
# cola 1765
# cooked_quinoa 922
# cauliflower 183
# cracker_crumbs 1266
# ragu 1671
# habanero 1205
# pita_rounds 1574
# sassafras 1173
# prickly_pear 1093
# maggi 1039
# black_raspberry 1769
# frozen_strawberries 1283
# ajwain 1250
# marjoram 174
# pita_loaves 1967
# burger_buns 1937
# arugula 374
# red_chili_powder 327
# frozen_raspberries 1652
# shimeji_mushrooms 1917
# oregano 37
# nuoc_nam 2006
# round_steaks 921
# cornish_hens 1320
# duck_breasts 1059
# italian_seasoning 238
# asafoetida_powder 852
# pitted_prunes 1084
# salted_dry_roasted_peanuts 1658
# english_toffee_bits 1598
# mexican_seasoning_mix 1218
# promise_buttery_spread 2044
# snow_peas 366
# halibut_steak 1721
# cured_pork 263
# white_kidney_beans 1256
# kochujang 1747
# hellmann_or_best_food_real_mayonnais 806
# instant_espresso 1315
# reduced_fat_firm_tofu 1565
# sausages 363
# pace_picante_sauce 1261
# ricotta 494
# bulb 2076
# salad_oil 675
# phyllo_pastry 830
# stilton 1544
# red_radishes 1534
# garam_masala 153
# chuck_roast 622
# vanilla 13
# focaccia 1490
# parmesan_cheese 66
# agar 1792
# beansprouts 219
# pork_liver 2003
# bouillon_cube 1407
# capicola 1801
# french_fried_onions 1161
# fresh_spinach 314
# stuffing 1170
# whole_nutmegs 1222
# squid 264
# black_gram 1624
# pickled_jalapeno_peppers 1758
# italian_style_seasoning 1342
# apricots 847
# sesame_seed 179
# shredded_nori 2082
# phyllo 1138
# cream 9
# tomatoes 69
# poblano 1232
# fenugreek 139
# balm 1879
# cuban_peppers 1371
# croissants 1557
# konbu 621
# broccoli 113
# poblano_chiles 410
# pasta_water 1414
# feta_cheese 185
# toasted_pumpkinseeds 1924
# barbecue_sauce 454
# vinaigrette 766
# gluten_free_tamari 1876
# bananas 323
# mirlitons 1513
# split_black_lentils 1285
# white_wine 88
# sea_salt 152
# habanero_chile 1074
# fat_free_refried_beans 1305
# i_cant_believe_its_not_butter!_spread 1146
# medium_firm_tofu 1321
# nira 629
# ghee 267
# persimmon 2013
# toasted_nori 1273
# small_capers 1971
# bok_choy 463
# japanese_eggplants 686
# marzipan 1708
# pearl_couscous 1925
# korean_chile_paste 1492
# ruby_port 1448
# pies 1673
# marshmallow_creme 1236
# lovage 427
# safflower_oil 827
# white_flour 904
# onion 3
# fresh_blueberries 792
# vermouth 1894
# candy 957
# crumbled_gorgonzola 808
# cutlet 1132
# sourdough 1481
# black_sesame_seeds 740
# lager 1282
# crisps 1651
# semisweet_chocolate 389
# red_delicious_apples 1616
# almonds 352
# chocolate_instant_pudding 1457
# trout_fillet 1299
# bicarbonate_of_soda 1174
# leaf 127
# green_enchilada_sauce 893
# portobello_caps 1697
# diced_tomatoes_in_juice 948
# ladyfingers 736
# trout 1533
# pepper 1
# frozen_peas_and_carrots 1085
# champagne_wine 518
# pasta 258
# crusty_rolls 1833
# sicilian_olives 1749
# biscuit_mix 1627
# thin_pizza_crust 1288
# black_bean 212
# superfine_sugar 592
# smoked_sea_salt 1912
# seeds 446
# emmenthal 1630
# cranberry 150
# ditalini_pasta 1183
# red_snapper 1020
# teriyaki_sauce 677
# steel_cut_oats 1693
# lea_&_perrins_worcestershire_sauce 2038
# citron 1493
# green_tea 870
# tenderloin 1806
# cocoa 42
# balsamic_reduction 1899
# shahi_jeera 1080
# choy_sum 1367
# small_red_beans 1484
# custard 1683
# dried_chives 1816
# bechamel 1943
# vegetables 346
# duck_fat 1229
# caviar 779
# _drain 412
# orzo_pasta 855
# nuoc_mam 1892
# ice_water 391
# oven_ready_lasagna_noodles 746
# ranch_dressing 586
# gluten 1001
# catsup 1764
# hash_brown 1660
# demerara_sugar 1439
# strawberries 331
# firm_silken_tofu 1556
# liquor 1906
# fillet_red_snapper 794
# lime_peel_oil 508
# artemisia 1339
# chopped_fresh_chives 319
# chipotles_in_adobo 354
# japanese_plum 1403
# flat_iron_steaks 1587
# seltzer_water 1722
# cake 758
# condiment 1539
# taco_seasoning_mix 367
# self_rising_flour 355
# yellow_hominy 1454
# spanish_paprika 863
# roasted_peanuts 406
# soda_water 1426
# sirloin 982
# pig 1242
# doenzang 1860
# penne 471
# firmly_packed_light_brown_sugar 679
# fishcake 1518
# hazelnuts 507
# cashew 225
# amaretti 1748
# fresh_udon 1514
# oat 123
# whole_almonds 1155
# caesar_salad_dressing 1300
# star_anise 532
# brown_sugar 108
# slaw_mix 768
# dried_bonito_flakes 775
# deep_dish_pie_crust 1771
# gorgonzola 886
# tasso 1005
# capers 199
# togarashi 1332
# chiffonade 1997
# french_lentils 1573
# cooking_liquid 2000
# munster_cheese 936
# liver 566

# %% [markdown]
# ## Plot ingredients
# Using tnse, dimention reduction

# %%
# don't plot UNK at position 0
low_dim_embs = run_tsne(nemb.astype(np.float64), multicore=False)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2087
# [t-SNE] Computed conditional probabilities for sample 2000 / 2087
# [t-SNE] Computed conditional probabilities for sample 2087 / 2087
# [t-SNE] Mean sigma: 0.281192
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.272252
# [t-SNE] Error after 200 iterations: 1.272252

# %%
recipes = load_recipes('../dat/kaggle_and_nature.csv')

for i in recipes[:10]:
    print i
# Out:
# ['African', 'chicken', 'cinnamon', 'soy_sauce', 'onion', 'ginger']
# ['African', 'cane_molasses', 'ginger', 'cumin', 'garlic', 'tamarind', 'bread', 'coriander', 'vinegar', 'onion', 'beef', 'cayenne', 'parsley', 'wheat_bread', 'yogurt', 'vegetable_oil', 'egg']
# ['African', 'butter', 'pepper', 'onion', 'cardamom', 'cayenne', 'ginger', 'cottage_cheese', 'garlic', 'brassica']
# ['African', 'olive_oil', 'pepper', 'wheat', 'beef', 'onion', 'cardamom', 'cumin', 'garlic', 'rice', 'leek']
# ['African', 'honey', 'wheat', 'yeast']
# ['African', 'tomato', 'cilantro', 'lemon_juice', 'onion', 'cayenne', 'scallion']
# ['African', 'wheat', 'cassava']
# ['African', 'olive_oil', 'onion', 'potato', 'black_pepper', 'cumin', 'carrot', 'cabbage', 'turmeric']
# ['African', 'tomato', 'fenugreek', 'pepper', 'onion', 'potato', 'black_pepper', 'ginger', 'carrot', 'garlic', 'vegetable_oil', 'cabbage', 'turmeric']
# ['African', 'banana']

# %%
food2cuisine = build_food2cuisine(recipes, vocab)

for i in food2cuisine[:10]:
    print i
# Out:
# ('equal_sweetener', [('SoutheastAsian', 0.00083986565), ('WesternEuropean', 0.00044286979)])
# ('roasted_tomatoes', [('LatinAmerican', 0.0031954255), ('African', 0.0025575447)])
# ('mackerel', [('EastAsian', 0.0056489576), ('WesternEuropean', 0.0011809862)])
# ('stone_ground_cornmeal', [('LatinAmerican', 0.00025227043), ('NorthAmerican', 0.00021813581)])
# ('tartar_sauce', [('WesternEuropean', 0.00059049309), ('LatinAmerican', 0.00033636056)])
# ('bucatini', [('SouthernEuropean', 0.0011285089), ('EastAsian', 0.0)])
# ('flanken_short_ribs', [('NorthernEuropean', 0.0027063598), ('EastAsian', 0.00067249493)])
# ('linguini', [('SouthernEuropean', 0.00063478627), ('SoutheastAsian', 0.00027995522)])
# ('sweet_pickle_relish', [('SoutheastAsian', 0.00055991043), ('WesternEuropean', 0.00014762327)])
# ('pizza_doughs', [('SouthernEuropean', 0.0075469036), ('LatinAmerican', 0.00058863102)])
# ('pancetta', [('SouthernEuropean', 0.011144026), ('WesternEuropean', 0.0014762327)])
# ('chat_masala', [('SouthAsian', 0.0033167496), ('NorthernEuropean', 0.0013531799)])
# ('candied_cherries', [('WesternEuropean', 0.00044286979), ('SoutheastAsian', 0.00027995522)])
# ('baking_powder', [('NorthernEuropean', 0.047361299), ('WesternEuropean', 0.043105993)])
# ('smoked_gouda', [('SouthernEuropean', 0.00098744535), ('LatinAmerican', 0.00075681129)])
# ('unsalted_dry_roast_peanuts', [('SoutheastAsian', 0.010638298), ('EastAsian', 0.002017485)])
# ('chocolate_chips', [('WesternEuropean', 0.0011809862), ('LatinAmerican', 0.00033636056)])
# ('old_el_paso_flour_tortillas', [('LatinAmerican', 0.00033636056), ('SouthernEuropean', 7.0531809e-05)])
# ('serrano_chilies', [('SoutheastAsian', 0.0058790594), ('SouthAsian', 0.0046987287)])
# ('baby_greens', [('African', 0.00085251493), ('SoutheastAsian', 0.00055991043)])
# ('mild_green_chiles', [('African', 0.00085251493), ('LatinAmerican', 0.00084090146)])
# ('black_pepper', [('EasternEuropean', 0.23097113), ('MiddleEastern', 0.2248062)])
# ('frozen_peaches', [('NorthAmerican', 0.00017450865), ('LatinAmerican', 8.4090141e-05)])
# ('flounder_fillets', [('SouthernEuropean', 0.00035265906), ('SouthAsian', 0.00027639579)])
# ('garden_peas', [('African', 0.00085251493), ('SouthernEuropean', 0.00063478627)])
# ('gremolata', [('SouthernEuropean', 0.00028212724), ('NorthAmerican', 2.1813581e-05)])
# ('peanut_butter', [('NorthAmerican', 0.020003054), ('African', 0.011082694)])
# ('cooking_oil', [('SoutheastAsian', 0.043113101), ('EastAsian', 0.01735037)])
# ('pak_choi', [('SoutheastAsian', 0.0016797313), ('EastAsian', 0.00053799595)])
# ('tilapia_fillets', [('LatinAmerican', 0.0036999665), ('SoutheastAsian', 0.0027995522)])
# ('low_sodium_taco_seasoning', [('LatinAmerican', 0.00067272113), ('EastAsian', 0.0)])
# ('chambord', [('WesternEuropean', 0.00073811633), ('NorthAmerican', 4.3627162e-05)])
# ('idaho_potatoes', [('WesternEuropean', 0.00059049309), ('SouthAsian', 0.00055279158)])
# ('jamaican_jerk_spice', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('yellow_chives', [('EastAsian', 0.00080699392), ('African', 0.0)])
# ('orzo', [('SouthernEuropean', 0.0057836082), ('African', 0.0025575447)])
# ('blackening_seasoning', [('LatinAmerican', 0.00033636056), ('NorthAmerican', 2.1813581e-05)])
# ('black_mustard_seed_oil', [('SouthAsian', 0.0069098948), ('NorthAmerican', 6.5440741e-05)])
# ('water_chestnuts', [('EastAsian', 0.02004035), ('SoutheastAsian', 0.0097984327)])
# ('celery_oil', [('NorthAmerican', 0.017996205), ('EasternEuropean', 0.015748031)])
# ('red_bean', [('EastAsian', 0.0043039676), ('WesternEuropean', 0.00014762327)])
# ('ravva', [('SouthAsian', 0.0027639579), ('EastAsian', 0.00013449899)])
# ('almond', [('MiddleEastern', 0.080620155), ('NorthernEuropean', 0.06901218)])
# ('bacon', [('EasternEuropean', 0.076115489), ('WesternEuropean', 0.058606435)])
# ('lavender', [('WesternEuropean', 0.0054620607), ('NorthernEuropean', 0.0013531799)])
# ('millet', [('SouthAsian', 0.0008291874), ('WesternEuropean', 0.00029524654)])
# ('soppressata', [('SouthernEuropean', 0.0011285089), ('LatinAmerican', 8.4090141e-05)])
# ('chinese_chives', [('EastAsian', 0.0034969738), ('SoutheastAsian', 0.0030795073)])
# ('powdered_sugar', [('NorthernEuropean', 0.035182681), ('WesternEuropean', 0.023472099)])
# ('mascarpone', [('SouthernEuropean', 0.0087459441), ('WesternEuropean', 0.0014762327)])
# ('milk_fat', [('EasternEuropean', 0.057742782), ('WesternEuropean', 0.021110127)])
# ('galangal', [('SoutheastAsian', 0.023516238), ('SouthAsian', 0.00027639579)])
# ('lima_beans', [('African', 0.0017050299), ('LatinAmerican', 0.00050454086)])
# ('croutons', [('SouthernEuropean', 0.0019043589), ('WesternEuropean', 0.00088573957)])
# ('old_el_paso_taco_seasoning_mix', [('LatinAmerican', 0.0010931719), ('EastAsian', 0.0)])
# ('hot_curry_powder', [('SouthAsian', 0.0011055832), ('African', 0.00085251493)])
# ('kefalotyri', [('SouthernEuropean', 0.00063478627), ('EastAsian', 0.0)])
# ('jasmine', [('SoutheastAsian', 0.025195969), ('EastAsian', 0.0048419638)])
# ('ramps', [('NorthernEuropean', 0.0013531799), ('EastAsian', 0.00053799595)])
# ('broccolini', [('SoutheastAsian', 0.0016797313), ('EastAsian', 0.0012104909)])
# ('pickling_salt', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00029524654)])
# ('vine_ripened_tomatoes', [('SouthernEuropean', 0.0010579771), ('LatinAmerican', 0.0010090817)])
# ('snappers', [('SouthAsian', 0.00027639579), ('LatinAmerican', 0.00025227043)])
# ('swordfish_steaks', [('African', 0.0042625745), ('SouthernEuropean', 0.00098744535)])
# ('leaves', [('SoutheastAsian', 0.011198209), ('SouthAsian', 0.0046987287)])
# ('stevia', [('NorthernEuropean', 0.0027063598), ('SoutheastAsian', 0.0013997761)])
# ('maple_syrup', [('NorthAmerican', 0.011015859), ('WesternEuropean', 0.0056096842)])
# ('chow_mein_noodles', [('EastAsian', 0.00403497), ('SoutheastAsian', 0.00027995522)])
# ('smoke', [('EasternEuropean', 0.023622047), ('MiddleEastern', 0.007751938)])
# ('canola', [('EastAsian', 0.0018829859), ('SoutheastAsian', 0.0013997761)])
# ('hot_dog_bun', [('SouthAsian', 0.00027639579), ('LatinAmerican', 0.00025227043)])
# ('red_kidnei_beans', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('whitefish_fillets', [('SouthAsian', 0.0016583748), ('SoutheastAsian', 0.0013997761)])
# ('shiso_leaves', [('EastAsian', 0.00080699392), ('SoutheastAsian', 0.00055991043)])
# ('gochujang_base', [('EastAsian', 0.018829858), ('SoutheastAsian', 0.00055991043)])
# ('herbes_de_provence', [('WesternEuropean', 0.0064954236), ('SouthernEuropean', 0.0010579771)])
# ('soybean', [('EastAsian', 0.088365838), ('SoutheastAsian', 0.0086786114)])
# ('shoyu', [('EastAsian', 0.0025554809), ('SoutheastAsian', 0.00055991043)])
# ('pasta_shell_small', [('SouthernEuropean', 0.00042319085), ('EastAsian', 0.0)])
# ('frozen_green_beans', [('WesternEuropean', 0.00029524654), ('SoutheastAsian', 0.00027995522)])
# ('sazon_seasoning', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('queso_anejo', [('LatinAmerican', 0.00050454086), ('EastAsian', 0.0)])
# ('neutral_oil', [('SouthAsian', 0.0027639579), ('SoutheastAsian', 0.0019596864)])
# ('golden_brown_sugar', [('WesternEuropean', 0.0036905815), ('NorthernEuropean', 0.0027063598)])
# ('blueberry', [('NorthAmerican', 0.0096197892), ('NorthernEuropean', 0.0027063598)])
# ('baby_arugula', [('SouthernEuropean', 0.0026802088), ('WesternEuropean', 0.00044286979)])
# ('anchovy_paste', [('SouthernEuropean', 0.0034560587), ('WesternEuropean', 0.0016238559)])
# ('toasted_sesame_seeds', [('EastAsian', 0.033221252), ('SoutheastAsian', 0.0086786114)])
# ('red_beans', [('LatinAmerican', 0.0045408676), ('EastAsian', 0.00080699392)])
# ('pecan', [('NorthAmerican', 0.047619049), ('MiddleEastern', 0.017054264)])
# ('fajita_size_flour_tortillas', [('LatinAmerican', 0.0010090817), ('EastAsian', 0.0)])
# ('nori', [('EastAsian', 0.012911903), ('African', 0.0)])
# ('hungarian_paprika', [('African', 0.0034100597), ('NorthernEuropean', 0.0013531799)])
# ('_cooked_and_drained', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('refrigerated_pizza_dough', [('SouthernEuropean', 0.0022570179), ('LatinAmerican', 0.00016818028)])
# ('smoked_sausage', [('EasternEuropean', 0.04199475), ('LatinAmerican', 0.010090818)])
# ('pastry_dough', [('WesternEuropean', 0.0025095956), ('NorthernEuropean', 0.0013531799)])
# ('crackers', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00088573957)])
# ('root', [('SoutheastAsian', 0.0055991043), ('MiddleEastern', 0.0046511628)])
# ('guajillo_chiles', [('LatinAmerican', 0.0043726875), ('SoutheastAsian', 0.00027995522)])
# ('vodka', [('NorthernEuropean', 0.0081190802), ('SouthernEuropean', 0.0019748907)])
# ('chayote', [('LatinAmerican', 0.00092499162), ('NorthAmerican', 0.00030539013)])
# ('honey', [('African', 0.13469736), ('EastAsian', 0.070073977)])
# ('veggies', [('SoutheastAsian', 0.0013997761), ('SouthAsian', 0.001381979)])
# ('cotija', [('LatinAmerican', 0.01168853), ('EastAsian', 0.0)])
# ('waxy_potatoes', [('NorthernEuropean', 0.0054127197), ('SouthAsian', 0.0019347706)])
# ('suet', [('WesternEuropean', 0.0026572188), ('EastAsian', 0.0)])
# ('cocktail_cherries', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00088573957)])
# ('chanterelle', [('SouthernEuropean', 0.00063478627), ('WesternEuropean', 0.00044286979)])
# ('nuts', [('SouthAsian', 0.0022111663), ('EastAsian', 0.0016139878)])
# ('cottage_cheese', [('EasternEuropean', 0.034120735), ('MiddleEastern', 0.0093023255)])
# ('buns', [('SouthAsian', 0.0008291874), ('LatinAmerican', 0.00033636056)])
# ('asian_eggplants', [('SoutheastAsian', 0.0019596864), ('African', 0.00085251493)])
# ('white_mushrooms', [('SoutheastAsian', 0.0027995522), ('SouthernEuropean', 0.001481168)])
# ('piecrust', [('WesternEuropean', 0.00029524654), ('LatinAmerican', 0.00016818028)])
# ('reduced_sodium_tamari_sauce', [('EastAsian', 0.00080699392), ('SoutheastAsian', 0.00027995522)])
# ('toasted_cashews', [('SoutheastAsian', 0.00083986565), ('SouthAsian', 0.0008291874)])
# ('sandwich_buns', [('SouthAsian', 0.00027639579), ('WesternEuropean', 0.00014762327)])
# ('parsnips', [('NorthernEuropean', 0.012178619), ('African', 0.0068201195)])
# ('rock_sugar', [('EastAsian', 0.0018829859), ('SoutheastAsian', 0.0011198209)])
# ('salsa', [('LatinAmerican', 0.078456104), ('SouthernEuropean', 0.00098744535)])
# ('peeled_prawns', [('SoutheastAsian', 0.0011198209), ('EastAsian', 0.00013449899)])
# ('wish_bone_italian_dressing', [('SouthernEuropean', 0.00056425447), ('SoutheastAsian', 0.00027995522)])
# ('prepar_pesto', [('SouthernEuropean', 0.0011990408), ('WesternEuropean', 0.00029524654)])
# ('pigeon_peas', [('SouthAsian', 0.0016583748), ('LatinAmerican', 0.00025227043)])
# ('pound_cake', [('WesternEuropean', 0.00073811633), ('SouthernEuropean', 0.00049372268)])
# ('frozen_chopped_spinach', [('SouthernEuropean', 0.010932431), ('SouthAsian', 0.0038695412)])
# ('oysters', [('EastAsian', 0.0017484869), ('LatinAmerican', 0.0016818029)])
# ('wine', [('SouthernEuropean', 0.14727043), ('WesternEuropean', 0.11824623)])
# ('cointreau_liqueur', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 0.00025227043)])
# ('orange_juice', [('MiddleEastern', 0.054263566), ('NorthAmerican', 0.031520624)])
# ('jumbo_pasta_shells', [('SouthernEuropean', 0.0026096769), ('LatinAmerican', 0.00058863102)])
# ('chocolate_bars', [('LatinAmerican', 0.00033636056), ('WesternEuropean', 0.00029524654)])
# ('crumbs', [('NorthernEuropean', 0.0013531799), ('SouthernEuropean', 0.00049372268)])
# ('hot_italian_sausages', [('SouthernEuropean', 0.0029623359), ('LatinAmerican', 0.00042045073)])
# ('caster', [('WesternEuropean', 0.00059049309), ('EastAsian', 0.00013449899)])
# ('soba_noodles', [('EastAsian', 0.0080699399), ('SoutheastAsian', 0.0022396417)])
# ('roasted_sesame_seed', [('EastAsian', 0.066173501), ('MiddleEastern', 0.040310077)])
# ('plantains', [('LatinAmerican', 0.0021022537), ('SoutheastAsian', 0.0013997761)])
# ('bass_fillets', [('SouthernEuropean', 0.00028212724), ('WesternEuropean', 0.00014762327)])
# ('avocado', [('LatinAmerican', 0.11831483), ('EastAsian', 0.012104909)])
# ('beaten_eggs', [('NorthernEuropean', 0.0040595401), ('EastAsian', 0.0014794889)])
# ('short_pasta', [('SouthernEuropean', 0.00049372268), ('EastAsian', 0.0)])
# ('green_chilies', [('SouthAsian', 0.13377556), ('LatinAmerican', 0.014463505)])
# ('tomato_juice', [('EasternEuropean', 0.0078740157), ('MiddleEastern', 0.0046511628)])
# ('fig', [('MiddleEastern', 0.015503876), ('African', 0.0042625745)])
# ('savory', [('EasternEuropean', 0.0078740157), ('WesternEuropean', 0.0048715677)])
# ('fregola', [('African', 0.00085251493), ('SouthernEuropean', 0.00028212724)])
# ('coffee', [('WesternEuropean', 0.015795689), ('MiddleEastern', 0.013953488)])
# ('table_salt', [('SouthernEuropean', 0.0015516998), ('LatinAmerican', 0.0015136226)])
# ('caramels', [('African', 0.00085251493), ('WesternEuropean', 0.00059049309)])
# ('nonstick_spray', [('LatinAmerican', 0.0018499832), ('NorthernEuropean', 0.0013531799)])
# ('yardlong_beans', [('SoutheastAsian', 0.0025195968), ('EastAsian', 0.0016139878)])
# ('silver', [('SouthAsian', 0.00027639579), ('LatinAmerican', 0.00025227043)])
# ('bread', [('SouthernEuropean', 0.11320356), ('MiddleEastern', 0.10852713)])
# ('meat', [('EasternEuropean', 0.036745407), ('MiddleEastern', 0.018604651)])
# ('thyme', [('WesternEuropean', 0.13817538), ('LatinAmerican', 0.073747054)])
# ('potatoes', [('NorthernEuropean', 0.089309879), ('SouthAsian', 0.069375344)])
# ('gingerroot', [('SoutheastAsian', 0.0067189252), ('EastAsian', 0.0065904506)])
# ('baby_lima_beans', [('African', 0.00085251493), ('WesternEuropean', 0.00073811633)])
# ('chuck', [('NorthernEuropean', 0.0054127197), ('SoutheastAsian', 0.0041993279)])
# ('roast', [('SoutheastAsian', 0.0011198209), ('African', 0.00085251493)])
# ('vinaigrette_dressing', [('SouthernEuropean', 0.00049372268), ('EastAsian', 0.00013449899)])
# ('roasted_white_sesame_seeds', [('EastAsian', 0.00080699392), ('African', 0.0)])
# ('rosemary', [('SouthernEuropean', 0.06792213), ('WesternEuropean', 0.03439622)])
# ('cornbread', [('NorthAmerican', 0.00037083088), ('LatinAmerican', 0.00025227043)])
# ('sausage_links', [('SouthernEuropean', 0.0025391451), ('LatinAmerican', 0.0010090817)])
# ('allspice', [('African', 0.0068201195), ('LatinAmerican', 0.0056340396)])
# ('sugar_substitute', [('EastAsian', 0.00040349696), ('SoutheastAsian', 0.00027995522)])
# ('prawn', [('SoutheastAsian', 0.0061590145), ('African', 0.0017050299)])
# ('adobo', [('LatinAmerican', 0.00067272113), ('SoutheastAsian', 0.00055991043)])
# ('waffle', [('SoutheastAsian', 0.00027995522), ('WesternEuropean', 0.00014762327)])
# ('turnip', [('MiddleEastern', 0.012403101), ('EasternEuropean', 0.0078740157)])
# ('sweet_potato', [('MiddleEastern', 0.023255814), ('African', 0.009377664)])
# ('papaya', [('SoutheastAsian', 0.011478163), ('LatinAmerican', 0.0016818029)])
# ('dried_pinto_beans', [('LatinAmerican', 0.0024386141), ('NorthAmerican', 4.3627162e-05)])
# ('black_sesame_seed', [('EastAsian', 0.0032279757), ('WesternEuropean', 0.00029524654)])
# ('extract', [('WesternEuropean', 0.00059049309), ('EastAsian', 0.00053799595)])
# ('genoa_salami', [('SouthernEuropean', 0.0015516998), ('LatinAmerican', 0.00050454086)])
# ('sesame_oil', [('EastAsian', 0.38991258), ('SoutheastAsian', 0.10582307)])
# ('sliced_carrots', [('SoutheastAsian', 0.0033594626), ('WesternEuropean', 0.0029524653)])
# ('grapes', [('African', 0.00085251493), ('SouthernEuropean', 0.00063478627)])
# ('split_peas', [('SouthAsian', 0.0008291874), ('WesternEuropean', 0.00044286979)])
# ('semolina_flour', [('African', 0.0068201195), ('NorthernEuropean', 0.0040595401)])
# ('serrano_peppers', [('LatinAmerican', 0.0060544903), ('SouthAsian', 0.0049751243)])
# ('light_brown_sugar', [('SoutheastAsian', 0.021836506), ('WesternEuropean', 0.0091526425)])
# ('crme_de_cassis', [('WesternEuropean', 0.00029524654), ('SouthernEuropean', 0.00021159543)])
# ('raisin', [('EasternEuropean', 0.078740157), ('MiddleEastern', 0.062015504)])
# ('seafood_stock', [('SoutheastAsian', 0.00055991043), ('LatinAmerican', 0.00050454086)])
# ('garbanzo_beans', [('African', 0.028985508), ('SouthAsian', 0.0099502485)])
# ('soda', [('SouthAsian', 0.0019347706), ('EastAsian', 0.00053799595)])
# ('chili_beans', [('LatinAmerican', 0.0020181634), ('NorthAmerican', 2.1813581e-05)])
# ('fresh_tomatoes', [('LatinAmerican', 0.0051294989), ('SouthAsian', 0.0046987287)])
# ('large_eggs', [('NorthernEuropean', 0.1150203), ('WesternEuropean', 0.088869207)])
# ('tilapia', [('SoutheastAsian', 0.0025195968), ('LatinAmerican', 0.0010931719)])
# ('dark_chocolate_chip', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 8.4090141e-05)])
# ('lettuce', [('LatinAmerican', 0.059283551), ('SoutheastAsian', 0.05487122)])
# ('tzatziki', [('African', 0.0017050299), ('SouthernEuropean', 0.0009169135)])
# ('tamarind', [('SoutheastAsian', 0.035554312), ('SouthAsian', 0.032614704)])
# ('lumpia_skins', [('SoutheastAsian', 0.0027995522), ('EastAsian', 0.0)])
# ('borlotti_beans', [('SouthernEuropean', 0.00035265906), ('EastAsian', 0.0)])
# ('chipotle_sauce', [('LatinAmerican', 0.00050454086), ('SouthernEuropean', 7.0531809e-05)])
# ('spinach', [('SouthAsian', 0.017412934), ('SouthernEuropean', 0.010438708)])
# ('bonito', [('EastAsian', 0.0012104909), ('LatinAmerican', 8.4090141e-05)])
# ('licorice', [('NorthernEuropean', 0.0013531799), ('NorthAmerican', 0.00041445805)])
# ('pickled_jalapenos', [('LatinAmerican', 0.0019340733), ('SoutheastAsian', 0.00027995522)])
# ('caster_sugar', [('EastAsian', 0.0072629456), ('NorthernEuropean', 0.0054127197)])
# ('kiwi', [('WesternEuropean', 0.0026572188), ('EastAsian', 0.0024209819)])
# ('cornichons', [('NorthernEuropean', 0.0054127197), ('WesternEuropean', 0.0029524653)])
# ('grit_quick', [('NorthAmerican', 0.00017450865), ('EastAsian', 0.0)])
# ('pickle_juice', [('NorthernEuropean', 0.0013531799), ('EastAsian', 0.00013449899)])
# ('canela', [('LatinAmerican', 0.0013454423), ('EastAsian', 0.0)])
# ('cornflour', [('EastAsian', 0.011163416), ('SouthAsian', 0.0016583748)])
# ('dried_guajillo_chiles', [('LatinAmerican', 0.0016818029), ('SoutheastAsian', 0.00027995522)])
# ('sliced_olives', [('LatinAmerican', 0.00092499162), ('EastAsian', 0.0)])
# ('cereal', [('NorthAmerican', 0.0045154113), ('NorthernEuropean', 0.0013531799)])
# ('hazelnut', [('EasternEuropean', 0.026246719), ('MiddleEastern', 0.013953488)])
# ('masa_dough', [('LatinAmerican', 0.0010090817), ('EastAsian', 0.0)])
# ('enokitake', [('EastAsian', 0.0055144588), ('SoutheastAsian', 0.0013997761)])
# ('black_fungus', [('EastAsian', 0.00067249493), ('African', 0.0)])
# ('no_salt_added_diced_tomatoes', [('NorthernEuropean', 0.0013531799), ('African', 0.00085251493)])
# ('mochiko', [('EastAsian', 0.0012104909), ('African', 0.0)])
# ('self_raising_flour', [('WesternEuropean', 0.00044286979), ('SoutheastAsian', 0.00027995522)])
# ('perilla', [('SoutheastAsian', 0.0019596864), ('EastAsian', 0.00067249493)])
# ('luke_warm_water', [('SouthAsian', 0.0008291874), ('WesternEuropean', 0.00014762327)])
# ('thai_red_curry_paste', [('SoutheastAsian', 0.034994401), ('SouthAsian', 0.00055279158)])
# ('taco_seasoning_reduced_sodium', [('LatinAmerican', 0.00058863102), ('EastAsian', 0.0)])
# ('ginger', [('SouthAsian', 0.4806523), ('EastAsian', 0.4145259)])
# ('seed', [('EasternEuropean', 0.094488189), ('MiddleEastern', 0.032558139)])
# ('poblano_chilies', [('LatinAmerican', 0.0027749748), ('EastAsian', 0.0)])
# ('dried_chile_peppers', [('African', 0.00085251493), ('SouthAsian', 0.00027639579)])
# ('hard_shelled_clams', [('SouthernEuropean', 0.00049372268), ('WesternEuropean', 0.00014762327)])
# ('mint', [('African', 0.12872975), ('SoutheastAsian', 0.11926091)])
# ('brine_cured_green_olives', [('African', 0.0017050299), ('WesternEuropean', 0.00029524654)])
# ('spicy_sausage', [('LatinAmerican', 0.00033636056), ('SouthernEuropean', 0.00021159543)])
# ('striped_bass', [('SouthernEuropean', 0.00035265906), ('WesternEuropean', 0.00014762327)])
# ('haas_avocados', [('LatinAmerican', 0.00033636056), ('EastAsian', 0.00013449899)])
# ('broiler_fryers', [('NorthAmerican', 8.7254324e-05), ('LatinAmerican', 8.4090141e-05)])
# ('shredded_colby', [('LatinAmerican', 0.00033636056), ('SoutheastAsian', 0.00027995522)])
# ('smoked_sweet_spanish_paprika', [('African', 0.00085251493), ('SouthernEuropean', 0.00035265906)])
# ('goat_cheese', [('SouthernEuropean', 0.0038087177), ('NorthAmerican', 0.0035556138)])
# ('tostada_shells', [('LatinAmerican', 0.0020181634), ('EastAsian', 0.0)])
# ('baby_portobello_mushrooms', [('SouthernEuropean', 0.00070531812), ('EastAsian', 0.00026899797)])
# ('refrigerated_biscuits', [('SoutheastAsian', 0.00055991043), ('NorthAmerican', 0.00019632223)])
# ('oil_cured_black_olives', [('African', 0.0042625745), ('WesternEuropean', 0.00073811633)])
# ('gravy', [('African', 0.00085251493), ('SouthAsian', 0.0008291874)])
# ('grenadine', [('LatinAmerican', 0.00016818028), ('WesternEuropean', 0.00014762327)])
# ('mixed_nuts', [('SouthAsian', 0.00027639579), ('SouthernEuropean', 0.00021159543)])
# ('italian_salad_dressing_mix', [('SouthernEuropean', 0.00049372268), ('LatinAmerican', 8.4090141e-05)])
# ('chipotle_paste', [('LatinAmerican', 0.00058863102), ('EastAsian', 0.0)])
# ('shallots', [('SoutheastAsian', 0.11310191), ('WesternEuropean', 0.051815767)])
# ('khoa', [('SouthAsian', 0.0022111663), ('EastAsian', 0.00013449899)])
# ('watercress', [('SoutheastAsian', 0.0064389696), ('EastAsian', 0.0045729657)])
# ('fried_eggs', [('SoutheastAsian', 0.0011198209), ('EastAsian', 0.0010759919)])
# ('macadamia_nut', [('NorthAmerican', 0.0021595445), ('SoutheastAsian', 0.00055991043)])
# ('ditalini', [('SouthernEuropean', 0.00077584991), ('EastAsian', 0.0)])
# ('jerk_marinade', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('epazote', [('LatinAmerican', 0.0036158762), ('EastAsian', 0.0)])
# ('pineapple', [('NorthAmerican', 0.033636544), ('SoutheastAsian', 0.022116462)])
# ('taco_shells', [('LatinAmerican', 0.0052135889), ('EastAsian', 0.00013449899)])
# ('creole_seasoning', [('LatinAmerican', 0.018836193), ('NorthAmerican', 0.0010034248)])
# ('snapper_fillets', [('African', 0.00085251493), ('WesternEuropean', 0.00029524654)])
# ('food_colouring', [('SouthAsian', 0.0022111663), ('African', 0.0017050299)])
# ('armagnac', [('WesternEuropean', 0.0028048421), ('SouthernEuropean', 0.00014106362)])
# ('coarse_sea_salt', [('African', 0.0025575447), ('WesternEuropean', 0.0017714791)])
# ('sago', [('SouthAsian', 0.0008291874), ('SoutheastAsian', 0.00055991043)])
# ('red_chile_sauce', [('LatinAmerican', 0.00067272113), ('EastAsian', 0.00013449899)])
# ('tequila', [('LatinAmerican', 0.01782711), ('NorthAmerican', 0.0016796457)])
# ('sage', [('SouthernEuropean', 0.028706446), ('NorthAmerican', 0.017647186)])
# ('lardons', [('WesternEuropean', 0.00088573957), ('NorthAmerican', 2.1813581e-05)])
# ('chile_powder', [('LatinAmerican', 0.006390851), ('SouthAsian', 0.004145937)])
# ('fennel', [('SouthAsian', 0.046434496), ('SouthernEuropean', 0.041190576)])
# ('madeira', [('WesternEuropean', 0.0031000886), ('SouthernEuropean', 0.00035265906)])
# ('sub_buns', [('SouthernEuropean', 0.00035265906), ('LatinAmerican', 0.00016818028)])
# ('leg_quarters', [('WesternEuropean', 0.00029524654), ('SoutheastAsian', 0.00027995522)])
# ('spike_seasoning', [('LatinAmerican', 0.00067272113), ('SouthernEuropean', 0.00028212724)])
# ('yellow_split_peas', [('SouthAsian', 0.0055279159), ('LatinAmerican', 0.00016818028)])
# ('pernod', [('WesternEuropean', 0.0023619724), ('SouthernEuropean', 0.00028212724)])
# ('toast', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00088573957)])
# ('skirt_steak', [('LatinAmerican', 0.0042885975), ('SoutheastAsian', 0.0019596864)])
# ('sunflower_seeds', [('EastAsian', 0.00040349696), ('LatinAmerican', 0.00033636056)])
# ('shellfish', [('EastAsian', 0.0030934769), ('WesternEuropean', 0.00029524654)])
# ('frozen_lemonade_concentrate', [('SouthernEuropean', 0.00028212724), ('LatinAmerican', 0.00016818028)])
# ('jeera', [('SouthAsian', 0.0058043119), ('NorthernEuropean', 0.0013531799)])
# ('sugar', [('SoutheastAsian', 0.22676371), ('NorthernEuropean', 0.20974289)])
# ('celery', [('NorthAmerican', 0.07268285), ('LatinAmerican', 0.072653882)])
# ('boneless_sirloin_steak', [('SoutheastAsian', 0.0011198209), ('EastAsian', 0.00053799595)])
# ('porridge_oats', [('WesternEuropean', 0.00073811633), ('EastAsian', 0.0)])
# ('polenta', [('SouthernEuropean', 0.0094512627), ('African', 0.00085251493)])
# ('brussels_sprouts', [('NorthernEuropean', 0.0027063598), ('SouthAsian', 0.0016583748)])
# ('mung_bean', [('EastAsian', 0.0018829859), ('SoutheastAsian', 0.00083986565)])
# ('chipotle', [('LatinAmerican', 0.0021022537), ('EastAsian', 0.0)])
# ('rice', [('EastAsian', 0.40766644), ('SoutheastAsian', 0.37206048)])
# ('mesclun', [('WesternEuropean', 0.00044286979), ('SoutheastAsian', 0.00027995522)])
# ('sour_milk', [('NorthAmerican', 0.0009816112), ('LatinAmerican', 8.4090141e-05)])
# ('fudge_brownie_mix', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 8.4090141e-05)])
# ('pepitas', [('LatinAmerican', 0.0015977127), ('SouthAsian', 0.00027639579)])
# ('watermelon', [('NorthAmerican', 0.0023122395), ('LatinAmerican', 0.0013454423)])
# ('chutney', [('SouthAsian', 0.011608624), ('WesternEuropean', 0.00073811633)])
# ('small_pasta', [('SouthernEuropean', 0.00049372268), ('LatinAmerican', 8.4090141e-05)])
# ('splenda_no_calorie_sweetener', [('SoutheastAsian', 0.00055991043), ('LatinAmerican', 0.00033636056)])
# ('rajma', [('SouthAsian', 0.0024875621), ('EastAsian', 0.0)])
# ('arrowroot_powder', [('SoutheastAsian', 0.00083986565), ('SouthAsian', 0.0008291874)])
# ('greens', [('SouthAsian', 0.0035931454), ('EastAsian', 0.0030934769)])
# ('ragu_old_world_style_pasta_sauc', [('SouthernEuropean', 0.00077584991), ('LatinAmerican', 0.00058863102)])
# ('bay', [('WesternEuropean', 0.084588133), ('SouthAsian', 0.075179659)])
# ('whitefish', [('SoutheastAsian', 0.0022396417), ('African', 0.0017050299)])
# ('pressed_tofu', [('SoutheastAsian', 0.0011198209), ('EastAsian', 0.00040349696)])
# ('tapioca_flour', [('SoutheastAsian', 0.0025195968), ('LatinAmerican', 0.0016818029)])
# ('dashi_powder', [('EastAsian', 0.0021519838), ('African', 0.0)])
# ('grape_juice', [('NorthAmerican', 0.012477368), ('MiddleEastern', 0.012403101)])
# ('sweet_potatoes_&_yams', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('baby_back_ribs', [('EastAsian', 0.00094149297), ('SoutheastAsian', 0.00027995522)])
# ('nut', [('MiddleEastern', 0.040310077), ('EastAsian', 0.022461332)])
# ('lemonade', [('LatinAmerican', 0.00016818028), ('SouthernEuropean', 7.0531809e-05)])
# ('emerils_original_essence', [('LatinAmerican', 0.00033636056), ('NorthAmerican', 2.1813581e-05)])
# ('field_peas', [('NorthAmerican', 0.00017450865), ('LatinAmerican', 8.4090141e-05)])
# ('muscovado_sugar', [('WesternEuropean', 0.0014762327), ('SoutheastAsian', 0.0013997761)])
# ('chile_paste', [('SoutheastAsian', 0.0053191488), ('EastAsian', 0.0028244788)])
# ('swiss_chard', [('SouthernEuropean', 0.0050782901), ('African', 0.0025575447)])
# ('cocktail_sauce', [('NorthAmerican', 8.7254324e-05), ('LatinAmerican', 8.4090141e-05)])
# ('green_apples', [('WesternEuropean', 0.00044286979), ('SouthernEuropean', 0.00021159543)])
# ('yogurt', [('SouthAsian', 0.18767275), ('MiddleEastern', 0.088372096)])
# ('lemon_peel', [('MiddleEastern', 0.040310077), ('EasternEuropean', 0.01312336)])
# ('club_soda', [('SouthernEuropean', 0.0011285089), ('EastAsian', 0.00080699392)])
# ('roasted_cashews', [('SouthAsian', 0.0038695412), ('SoutheastAsian', 0.0022396417)])
# ('unsalted_roasted_peanuts', [('SoutheastAsian', 0.0041993279), ('SouthAsian', 0.00027639579)])
# ('sesame_seeds', [('EastAsian', 0.068594486), ('SoutheastAsian', 0.013717805)])
# ('ancho', [('African', 0.00085251493), ('LatinAmerican', 0.00075681129)])
# ('soaking_liquid', [('EastAsian', 0.00053799595), ('SoutheastAsian', 0.00027995522)])
# ('brine_cured_black_olives', [('WesternEuropean', 0.0013286094), ('SouthernEuropean', 0.00077584991)])
# ('mahimahi', [('African', 0.0017050299), ('SouthAsian', 0.00027639579)])
# ('curry_powder', [('SouthAsian', 0.11138751), ('SoutheastAsian', 0.029395297)])
# ('huckleberry', [('NorthAmerican', 0.00019632223), ('SouthernEuropean', 7.0531809e-05)])
# ('fresh_red_chili', [('SoutheastAsian', 0.0044792835), ('SouthAsian', 0.0019347706)])
# ('raw_cane_sugar', [('EastAsian', 0.00026899797), ('WesternEuropean', 0.00014762327)])
# ('_well_scrub', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('seedless_red_grapes', [('African', 0.0017050299), ('SouthernEuropean', 0.00084638171)])
# ('jelly', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00088573957)])
# ('hummus', [('SouthernEuropean', 0.00098744535), ('LatinAmerican', 0.00058863102)])
# ('cake_flour', [('WesternEuropean', 0.0056096842), ('EastAsian', 0.0045729657)])
# ('cod', [('African', 0.008525149), ('WesternEuropean', 0.0063478006)])
# ('cherry', [('NorthAmerican', 0.0216827), ('SouthernEuropean', 0.019960502)])
# ('jack', [('LatinAmerican', 0.0020181634), ('EastAsian', 0.00013449899)])
# ('cube_steaks', [('NorthAmerican', 8.7254324e-05), ('LatinAmerican', 8.4090141e-05)])
# ('pepperoncini', [('SouthernEuropean', 0.0010579771), ('LatinAmerican', 0.00016818028)])
# ('french_baguette', [('SouthernEuropean', 0.0019043589), ('WesternEuropean', 0.0014762327)])
# ('raita', [('SouthAsian', 0.0022111663), ('SouthernEuropean', 7.0531809e-05)])
# ('marmite', [('WesternEuropean', 0.0013286094), ('LatinAmerican', 0.00016818028)])
# ('fleur_de_sel', [('WesternEuropean', 0.0017714791), ('SouthernEuropean', 0.00049372268)])
# ('beef', [('EasternEuropean', 0.12860893), ('LatinAmerican', 0.12470569)])
# ('sauterne', [('WesternEuropean', 0.00073811633), ('SouthernEuropean', 7.0531809e-05)])
# ('shiitake', [('EastAsian', 0.09899126), ('SoutheastAsian', 0.025475923)])
# ('parsley', [('African', 0.20971867), ('MiddleEastern', 0.20775194)])
# ('basmati', [('SouthAsian', 0.00027639579), ('LatinAmerican', 0.00016818028)])
# ('cornflake_crumbs', [('SouthernEuropean', 0.00014106362), ('NorthAmerican', 8.7254324e-05)])
# ('beer', [('WesternEuropean', 0.018452909), ('LatinAmerican', 0.014799866)])
# ('grapefruit', [('WesternEuropean', 0.0028048421), ('LatinAmerican', 0.0022704338)])
# ('beet', [('EasternEuropean', 0.057742782), ('NorthernEuropean', 0.013531799)])
# ('gyoza', [('EastAsian', 0.0013449899), ('SouthernEuropean', 0.00021159543)])
# ('pinto_beans', [('LatinAmerican', 0.012697612), ('African', 0.00085251493)])
# ('basil', [('SouthernEuropean', 0.2221752), ('SoutheastAsian', 0.16013438)])
# ('roasted_beef', [('EasternEuropean', 0.0078740157), ('MiddleEastern', 0.0046511628)])
# ('cranberries', [('WesternEuropean', 0.0017714791), ('SouthAsian', 0.0016583748)])
# ('low_sodium_worcestershire_sauce', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 0.00042045073)])
# ('rotelle', [('LatinAmerican', 0.0021863438), ('SouthernEuropean', 0.00028212724)])
# ('sprite', [('SoutheastAsian', 0.0022396417), ('NorthernEuropean', 0.0013531799)])
# ('mushroom', [('EasternEuropean', 0.062992126), ('NorthAmerican', 0.054773901)])
# ('bawang_goreng', [('SoutheastAsian', 0.0053191488), ('SouthAsian', 0.00027639579)])
# ('baked_potato', [('NorthAmerican', 0.00017450865), ('LatinAmerican', 8.4090141e-05)])
# ('dried_tart_cherries', [('WesternEuropean', 0.0014762327), ('NorthernEuropean', 0.0013531799)])
# ('extra_firm_tofu', [('SoutheastAsian', 0.014837626), ('EastAsian', 0.0079354402)])
# ('chili', [('SoutheastAsian', 0.0095184771), ('LatinAmerican', 0.0091658253)])
# ('ritz_crackers', [('LatinAmerican', 0.00025227043), ('NorthAmerican', 6.5440741e-05)])
# ('sweet_vermouth', [('WesternEuropean', 0.00059049309), ('SouthernEuropean', 0.00042319085)])
# ('fresh_curry_leaves', [('SouthAsian', 0.018518519), ('SoutheastAsian', 0.00027995522)])
# ('fresh_raspberries', [('WesternEuropean', 0.0073811631), ('SouthernEuropean', 0.0014106362)])
# ('uncooked_vermicelli', [('LatinAmerican', 0.00016818028), ('SouthernEuropean', 0.00014106362)])
# ('whipped_topping', [('WesternEuropean', 0.0017714791), ('SouthernEuropean', 0.00084638171)])
# ('shirataki', [('EastAsian', 0.00094149297), ('SoutheastAsian', 0.00055991043)])
# ('red_chili_peppers', [('SoutheastAsian', 0.052631579), ('SouthAsian', 0.045605306)])
# ('angel_food_cake', [('SouthernEuropean', 0.00028212724), ('WesternEuropean', 0.00014762327)])
# ('pitted_kalamata_olives', [('SouthernEuropean', 0.01170828), ('African', 0.0051150895)])
# ('kimchi_juice', [('EastAsian', 0.00080699392), ('African', 0.0)])
# ('pitas', [('African', 0.0025575447), ('SouthernEuropean', 0.0023980816)])
# ('dumplings', [('EastAsian', 0.0018829859), ('SoutheastAsian', 0.00083986565)])
# ('quinces', [('African', 0.0017050299), ('SouthAsian', 0.00055279158)])
# ('chervil', [('WesternEuropean', 0.0060525537), ('African', 0.0034100597)])
# ('mixed_mushrooms', [('EastAsian', 0.00067249493), ('SoutheastAsian', 0.00027995522)])
# ('jerk_sauce', [('LatinAmerican', 0.00050454086), ('EastAsian', 0.0)])
# ('red_kidney_beans', [('LatinAmerican', 0.006474941), ('SouthAsian', 0.0033167496)])
# ('medium_tomatoes', [('SouthAsian', 0.00055279158), ('LatinAmerican', 0.00033636056)])
# ('fava_beans', [('African', 0.0042625745), ('SouthernEuropean', 0.0010579771)])
# ('pizza_sauce', [('SouthernEuropean', 0.0050077583), ('LatinAmerican', 0.00075681129)])
# ('sliced_green_onions', [('SoutheastAsian', 0.020716686), ('EastAsian', 0.015467384)])
# ('carnation', [('LatinAmerican', 8.4090141e-05), ('SouthernEuropean', 7.0531809e-05)])
# ('vegetable', [('EastAsian', 0.21735036), ('SouthAsian', 0.20176893)])
# ('top_sirloin_steak', [('EastAsian', 0.0016139878), ('NorthernEuropean', 0.0013531799)])
# ('pomegranate_molasses', [('African', 0.0025575447), ('SouthAsian', 0.00027639579)])
# ('yellow_peppers', [('LatinAmerican', 0.0020181634), ('SoutheastAsian', 0.0011198209)])
# ('hand', [('African', 0.0017050299), ('SouthAsian', 0.0008291874)])
# ('passata', [('SouthAsian', 0.0035931454), ('NorthernEuropean', 0.0013531799)])
# ('aai_powder', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('garlic', [('SoutheastAsian', 0.64025754), ('LatinAmerican', 0.54515642)])
# ('tuna', [('WesternEuropean', 0.010038382), ('EastAsian', 0.0095494287)])
# ('butter', [('EasternEuropean', 0.52755904), ('NorthernEuropean', 0.50608933)])
# ('chocolate_candy_bars', [('SouthernEuropean', 0.00035265906), ('NorthAmerican', 2.1813581e-05)])
# ('sirloin_tip_roast', [('SoutheastAsian', 0.00027995522), ('LatinAmerican', 0.00016818028)])
# ('condiments', [('SoutheastAsian', 0.00055991043), ('LatinAmerican', 0.00050454086)])
# ('chopped_fresh_herbs', [('African', 0.00085251493), ('WesternEuropean', 0.00073811633)])
# ('creole_style_seasoning', [('LatinAmerican', 0.00042045073), ('SouthernEuropean', 0.00014106362)])
# ('carnitas', [('LatinAmerican', 0.00084090146), ('EastAsian', 0.0)])
# ('udon', [('EastAsian', 0.0057834568), ('SoutheastAsian', 0.0011198209)])
# ('burgers', [('WesternEuropean', 0.00029524654), ('EastAsian', 0.00013449899)])
# ('chili_powder', [('SouthAsian', 0.13405196), ('LatinAmerican', 0.11049445)])
# ('fideos', [('SouthernEuropean', 0.00042319085), ('EastAsian', 0.0)])
# ('dungeness_crabs', [('SouthernEuropean', 0.00035265906), ('SoutheastAsian', 0.00027995522)])
# ('orange_peel', [('MiddleEastern', 0.023255814), ('NorthAmerican', 0.0092271445)])
# ('kale', [('SouthernEuropean', 0.0080406265), ('NorthernEuropean', 0.0054127197)])
# ('satsuma_imo', [('EastAsian', 0.00067249493), ('SoutheastAsian', 0.00027995522)])
# ('pink_beans', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('ham', [('WesternEuropean', 0.026129318), ('NorthAmerican', 0.025434636)])
# ('chopped_green_chilies', [('LatinAmerican', 0.0046249582), ('SouthAsian', 0.00027639579)])
# ('dried_black_beans', [('LatinAmerican', 0.0029431551), ('EastAsian', 0.00013449899)])
# ('cognac', [('WesternEuropean', 0.015795689), ('NorthernEuropean', 0.0027063598)])
# ('kelp', [('EastAsian', 0.026899798), ('SoutheastAsian', 0.00055991043)])
# ('mexicorn', [('LatinAmerican', 0.0016818029), ('EastAsian', 0.0)])
# ('galanga', [('SoutheastAsian', 0.0083986558), ('SouthAsian', 0.00027639579)])
# ('green_tomatoes', [('NorthAmerican', 0.001875968), ('WesternEuropean', 0.00088573957)])
# ('pillsbury_refrigerated_crescent_dinner_rolls', [('LatinAmerican', 0.00050454086), ('SouthernEuropean', 0.00028212724)])
# ('campanelle', [('SouthernEuropean', 0.00042319085), ('EastAsian', 0.0)])
# ('sweet_peas', [('NorthernEuropean', 0.0054127197), ('SouthAsian', 0.00055279158)])
# ('chives', [('WesternEuropean', 0.0067906701), ('EastAsian', 0.0067249495)])
# ('andouille_sausage', [('LatinAmerican', 0.019004373), ('NorthAmerican', 0.00076347531)])
# ('heinz_chili_sauce', [('LatinAmerican', 0.00025227043), ('WesternEuropean', 0.00014762327)])
# ('urad_dal', [('SouthAsian', 0.018242123), ('EastAsian', 0.00026899797)])
# ('fresh_mozzarella_balls', [('SouthernEuropean', 0.00035265906), ('EastAsian', 0.0)])
# ('himalayan_salt', [('SouthAsian', 0.00055279158), ('LatinAmerican', 0.00042045073)])
# ('flavoring', [('SoutheastAsian', 0.00083986565), ('LatinAmerican', 0.00075681129)])
# ('mirin', [('EastAsian', 0.06563551), ('SoutheastAsian', 0.0036394177)])
# ('toasted_pecans', [('WesternEuropean', 0.00073811633), ('NorthAmerican', 0.00030539013)])
# ('chilli_paste', [('SouthAsian', 0.0030403538), ('EastAsian', 0.0012104909)])
# ('hominy', [('LatinAmerican', 0.0062226709), ('NorthAmerican', 6.5440741e-05)])
# ('meringue', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00044286979)])
# ('herdez_salsa_verde', [('LatinAmerican', 0.00050454086), ('EastAsian', 0.0)])
# ('phyllo_dough', [('African', 0.0051150895), ('SouthernEuropean', 0.0031033996)])
# ('sponge', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00044286979)])
# ('frozen_vegetables', [('SoutheastAsian', 0.00055991043), ('SouthAsian', 0.00055279158)])
# ('ground_cloves', [('SouthAsian', 0.017965727), ('African', 0.017902814)])
# ('cavatelli', [('SouthernEuropean', 0.00063478627), ('WesternEuropean', 0.00014762327)])
# ('asafoetida', [('SouthAsian', 0.018518519), ('EastAsian', 0.00080699392)])
# ('okra', [('LatinAmerican', 0.015893036), ('SouthAsian', 0.0093974574)])
# ('mexican_chorizo', [('LatinAmerican', 0.0027749748), ('EastAsian', 0.0)])
# ('black_olives', [('LatinAmerican', 0.0079044737), ('SouthernEuropean', 0.0071942448)])
# ('ice', [('LatinAmerican', 0.0043726875), ('SoutheastAsian', 0.0030795073)])
# ('hellmanns_real_mayonnaise', [('NorthernEuropean', 0.0013531799), ('SoutheastAsian', 0.00027995522)])
# ('bartlett_pear', [('NorthAmerican', 0.00037083088), ('WesternEuropean', 0.00029524654)])
# ('asafetida', [('SouthAsian', 0.010226645), ('EastAsian', 0.00080699392)])
# ('corn', [('LatinAmerican', 0.27556342), ('EastAsian', 0.17027572)])
# ('flour_for_dusting', [('NorthernEuropean', 0.0027063598), ('SouthernEuropean', 0.0016222317)])
# ('file_powder', [('LatinAmerican', 0.0038681466), ('NorthAmerican', 6.5440741e-05)])
# ('rump_roast', [('WesternEuropean', 0.00073811633), ('SouthernEuropean', 0.00042319085)])
# ('pepperidge_farm_puff_pastry', [('WesternEuropean', 0.00029524654), ('LatinAmerican', 0.00025227043)])
# ('frangelico', [('SouthernEuropean', 0.00063478627), ('WesternEuropean', 0.00029524654)])
# ('breakfast_sausages', [('LatinAmerican', 0.00050454086), ('WesternEuropean', 0.00044286979)])
# ('ricotta_salata', [('SouthernEuropean', 0.0016222317), ('African', 0.00085251493)])
# ('prepar_salsa', [('LatinAmerican', 0.0023545241), ('NorthAmerican', 4.3627162e-05)])
# ('lingonberry', [('NorthernEuropean', 0.0067658997), ('WesternEuropean', 0.00014762327)])
# ('plum', [('SouthernEuropean', 0.034137394), ('African', 0.028985508)])
# ('turbinado', [('WesternEuropean', 0.0022143489), ('NorthernEuropean', 0.0013531799)])
# ('sushi_nori', [('EastAsian', 0.00067249493), ('African', 0.0)])
# ('half_&_half', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('baked_beans', [('WesternEuropean', 0.00044286979), ('SouthAsian', 0.00027639579)])
# ('octopus', [('EastAsian', 0.0043039676), ('African', 0.00085251493)])
# ('flatbread', [('African', 0.0017050299), ('SouthAsian', 0.0016583748)])
# ('sliced_mushrooms', [('SouthernEuropean', 0.0095217945), ('SoutheastAsian', 0.0064389696)])
# ('beefsteak_tomatoes', [('SouthernEuropean', 0.0012695725), ('African', 0.00085251493)])
# ('hoagie_rolls', [('SouthernEuropean', 0.00056425447), ('LatinAmerican', 0.00033636056)])
# ('sofrito', [('LatinAmerican', 0.00033636056), ('SouthernEuropean', 7.0531809e-05)])
# ('grated_pecorino', [('SouthernEuropean', 0.00049372268), ('EastAsian', 0.0)])
# ('loin', [('WesternEuropean', 0.00059049309), ('SouthAsian', 0.00027639579)])
# ('soy', [('SoutheastAsian', 0.00083986565), ('EastAsian', 0.00080699392)])
# ('rounds', [('EastAsian', 0.00040349696), ('SouthAsian', 0.00027639579)])
# ('tomatillo_salsa', [('LatinAmerican', 0.00084090146), ('EastAsian', 0.0)])
# ('maldon_sea_salt', [('WesternEuropean', 0.00029524654), ('SouthernEuropean', 0.00021159543)])
# ('amchur', [('SouthAsian', 0.019071311), ('EastAsian', 0.0022864828)])
# ('low_fat_mayonnaise', [('NorthernEuropean', 0.0027063598), ('WesternEuropean', 0.00073811633)])
# ('amaretti_cookies', [('SouthernEuropean', 0.00070531812), ('WesternEuropean', 0.00014762327)])
# ('gin', [('NorthAmerican', 0.00146151), ('WesternEuropean', 0.0010333628)])
# ('sweet_potatoes', [('African', 0.030690538), ('SouthAsian', 0.015478165)])
# ('diced_tomatoes_and_green_chilies', [('LatinAmerican', 0.00067272113), ('EastAsian', 0.0)])
# ('pinenuts', [('SouthernEuropean', 0.020172097), ('African', 0.010230179)])
# ('soft_taco_size_flour_tortillas', [('LatinAmerican', 0.00042045073), ('EastAsian', 0.0)])
# ('panettone', [('NorthernEuropean', 0.0013531799), ('SouthernEuropean', 0.00028212724)])
# ('pitted_black_olives', [('African', 0.0034100597), ('SouthernEuropean', 0.0021159542)])
# ('tempeh', [('African', 0.00085251493), ('SoutheastAsian', 0.00083986565)])
# ('cremini_mushrooms', [('NorthernEuropean', 0.0067658997), ('SouthernEuropean', 0.004866695)])
# ('paprika', [('African', 0.12787724), ('SouthAsian', 0.052238807)])
# ('whiskey', [('EasternEuropean', 0.010498688), ('WesternEuropean', 0.010186005)])
# ('atta', [('SouthAsian', 0.0024875621), ('EastAsian', 0.00013449899)])
# ('kosher_salt', [('African', 0.078431375), ('SouthAsian', 0.069375344)])
# ('parmagiano_reggiano', [('SouthernEuropean', 0.0009169135), ('EastAsian', 0.0)])
# ('splenda_brown_sugar_blend', [('SoutheastAsian', 0.00027995522), ('LatinAmerican', 0.00025227043)])
# ('hot_water', [('NorthernEuropean', 0.010825439), ('SoutheastAsian', 0.010638298)])
# ('short_rib', [('EastAsian', 0.0024209819), ('NorthernEuropean', 0.0013531799)])
# ('rolled_oats', [('WesternEuropean', 0.0025095956), ('SoutheastAsian', 0.00055991043)])
# ('chinese_sesame_paste', [('EastAsian', 0.00067249493), ('African', 0.0)])
# ('dinner_rolls', [('SouthAsian', 0.0008291874), ('LatinAmerican', 0.00033636056)])
# ('sprouts', [('SoutheastAsian', 0.0013997761), ('EastAsian', 0.00094149297)])
# ('cacao', [('NorthAmerican', 0.00071984821), ('WesternEuropean', 0.00044286979)])
# ('dashi_kombu', [('EastAsian', 0.0022864828), ('African', 0.0)])
# ('saltines', [('LatinAmerican', 0.00075681129), ('NorthAmerican', 0.00050171238)])
# ('mole_sauce', [('LatinAmerican', 0.0010931719), ('EastAsian', 0.0)])
# ('baguette', [('SouthernEuropean', 0.01050924), ('WesternEuropean', 0.0093002655)])
# ('kaiser_rolls', [('African', 0.00085251493), ('LatinAmerican', 0.00058863102)])
# ('mini_chocolate_chips', [('SouthernEuropean', 0.00042319085), ('LatinAmerican', 8.4090141e-05)])
# ('sweet_gherkin', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00029524654)])
# ('venison', [('NorthernEuropean', 0.0013531799), ('SoutheastAsian', 0.00027995522)])
# ('baking_spray', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00014762327)])
# ('chocolate_syrup', [('WesternEuropean', 0.0010333628), ('SouthernEuropean', 0.00028212724)])
# ('leek', [('MiddleEastern', 0.032558139), ('WesternEuropean', 0.013433717)])
# ('truffles', [('WesternEuropean', 0.00044286979), ('SouthernEuropean', 0.00014106362)])
# ('campari', [('SouthernEuropean', 0.00063478627), ('EastAsian', 0.0)])
# ('blue_crabs', [('SoutheastAsian', 0.00055991043), ('LatinAmerican', 0.00050454086)])
# ('sesame', [('EastAsian', 0.0028244788), ('SoutheastAsian', 0.00083986565)])
# ('fat_free_mayonnaise', [('LatinAmerican', 0.00075681129), ('SouthernEuropean', 0.00070531812)])
# ('gala_apples', [('WesternEuropean', 0.0011809862), ('EastAsian', 0.00026899797)])
# ('chaat_masala', [('SouthAsian', 0.011608624), ('NorthernEuropean', 0.0013531799)])
# ('sea_scallops', [('WesternEuropean', 0.0041334513), ('SouthernEuropean', 0.0028918041)])
# ('mahi_mahi_fillets', [('LatinAmerican', 0.00058863102), ('SoutheastAsian', 0.00027995522)])
# ('_drained_and_chopped', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('caraway', [('EasternEuropean', 0.05511811), ('NorthernEuropean', 0.041948579)])
# ('_well_scrubbed', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('potato', [('EasternEuropean', 0.19160105), ('MiddleEastern', 0.074418604)])
# ('monterey_jack', [('LatinAmerican', 0.017911201), ('SouthernEuropean', 0.00063478627)])
# ('monkfish_fillets', [('African', 0.00085251493), ('WesternEuropean', 0.00044286979)])
# ('cherry_brandy', [('EasternEuropean', 0.010498688), ('WesternEuropean', 0.0016238559)])
# ('chopped_pecans', [('NorthAmerican', 0.0044499706), ('LatinAmerican', 0.0026067945)])
# ('whole_allspice', [('WesternEuropean', 0.0011809862), ('SouthAsian', 0.0011055832)])
# ('fusilli', [('SouthernEuropean', 0.0031033996), ('LatinAmerican', 0.00058863102)])
# ('lemon_juice', [('MiddleEastern', 0.24806201), ('NorthAmerican', 0.081909999)])
# ('sauvignon_blanc', [('WesternEuropean', 0.00059049309), ('SouthernEuropean', 7.0531809e-05)])
# ('dried_cornhusks', [('LatinAmerican', 0.00067272113), ('EastAsian', 0.0)])
# ('sunflower_oil', [('SouthAsian', 0.010226645), ('EastAsian', 0.0033624747)])
# ('chilegarlic_sauce', [('EastAsian', 0.00094149297), ('SoutheastAsian', 0.00083986565)])
# ('guava', [('LatinAmerican', 0.00067272113), ('SoutheastAsian', 0.00055991043)])
# ('anise_seed', [('NorthernEuropean', 0.0054127197), ('SouthernEuropean', 0.0015516998)])
# ('milk', [('NorthAmerican', 0.26376984), ('EasternEuropean', 0.24671917)])
# ('granulated_white_sugar', [('SoutheastAsian', 0.0022396417), ('EastAsian', 0.00053799595)])
# ('grape', [('SouthernEuropean', 0.013753703), ('LatinAmerican', 0.0066431216)])
# ('camembert_cheese', [('WesternEuropean', 0.0011809862), ('NorthAmerican', 8.7254324e-05)])
# ('accent_seasoning', [('SoutheastAsian', 0.0016797313), ('EastAsian', 0.0)])
# ('canola_mayonnaise', [('SouthernEuropean', 0.00035265906), ('SoutheastAsian', 0.00027995522)])
# ('couscous', [('African', 0.12105712), ('SouthAsian', 0.004145937)])
# ('globe_eggplant', [('SouthernEuropean', 0.00028212724), ('EastAsian', 0.00013449899)])
# ('thai_pepper', [('SoutheastAsian', 0.011198209), ('MiddleEastern', 0.0031007752)])
# ('frozen_pizza_dough', [('SouthernEuropean', 0.00035265906), ('EastAsian', 0.0)])
# ('cold_water', [('NorthernEuropean', 0.024357239), ('EastAsian', 0.019233355)])
# ('icing', [('LatinAmerican', 0.00016818028), ('WesternEuropean', 0.00014762327)])
# ('yeast', [('EasternEuropean', 0.12598425), ('NorthernEuropean', 0.1082544)])
# ('pan_drippings', [('WesternEuropean', 0.00044286979), ('NorthAmerican', 0.00017450865)])
# ('seasoned_flour', [('WesternEuropean', 0.00029524654), ('NorthAmerican', 8.7254324e-05)])
# ('grape_brandy', [('SouthernEuropean', 0.00056425447), ('EastAsian', 0.0)])
# ('farro', [('SouthernEuropean', 0.0011285089), ('African', 0.00085251493)])
# ('brewed_espresso', [('SouthernEuropean', 0.00098744535), ('WesternEuropean', 0.00029524654)])
# ('ground_paprika', [('African', 0.0017050299), ('SouthAsian', 0.0016583748)])
# ('marinara_sauce', [('SouthernEuropean', 0.015869657), ('SoutheastAsian', 0.00027995522)])
# ('catalina_dressing', [('LatinAmerican', 0.00058863102), ('NorthAmerican', 2.1813581e-05)])
# ('peaches', [('NorthAmerican', 0.0041009532), ('WesternEuropean', 0.0028048421)])
# ('bouquet_garni', [('WesternEuropean', 0.0025095956), ('LatinAmerican', 0.00016818028)])
# ('tortillas', [('LatinAmerican', 0.017743021), ('NorthernEuropean', 0.0013531799)])
# ('teas', [('SouthAsian', 0.0030403538), ('NorthernEuropean', 0.0013531799)])
# ('biryani_masala', [('SouthAsian', 0.0030403538), ('EastAsian', 0.0)])
# ('cane_sugar', [('SouthAsian', 0.0011055832), ('EastAsian', 0.00094149297)])
# ('peeled_tomatoes', [('SouthernEuropean', 0.0028918041), ('SouthAsian', 0.001381979)])
# ('triple_sec', [('LatinAmerican', 0.0022704338), ('SouthernEuropean', 0.00035265906)])
# ...
# ('halibut_steak', [('SouthAsian', 0.00055279158), ('SoutheastAsian', 0.00027995522)])
# ('cured_pork', [('SouthernEuropean', 0.0087459441), ('NorthAmerican', 0.0037083088)])
# ('white_kidney_beans', [('NorthernEuropean', 0.0013531799), ('SouthAsian', 0.0008291874)])
# ('kochujang', [('EastAsian', 0.00094149297), ('African', 0.0)])
# ('hellmann_or_best_food_real_mayonnais', [('LatinAmerican', 0.0017658931), ('SoutheastAsian', 0.00083986565)])
# ('instant_espresso', [('WesternEuropean', 0.00059049309), ('SouthernEuropean', 0.00049372268)])
# ('reduced_fat_firm_tofu', [('SoutheastAsian', 0.0013997761), ('SouthAsian', 0.00027639579)])
# ('sausages', [('NorthernEuropean', 0.0067658997), ('WesternEuropean', 0.0047239447)])
# ('pace_picante_sauce', [('LatinAmerican', 0.001177262), ('EastAsian', 0.0)])
# ('ricotta', [('SouthernEuropean', 0.0069826492), ('WesternEuropean', 0.00029524654)])
# ('bulb', [('SoutheastAsian', 0.00055991043), ('SouthAsian', 0.00027639579)])
# ('salad_oil', [('SouthAsian', 0.0022111663), ('EastAsian', 0.0021519838)])
# ('phyllo_pastry', [('African', 0.009377664), ('NorthernEuropean', 0.0013531799)])
# ('stilton', [('WesternEuropean', 0.0013286094), ('EastAsian', 0.0)])
# ('red_radishes', [('EastAsian', 0.00053799595), ('LatinAmerican', 0.00042045073)])
# ('garam_masala', [('SouthAsian', 0.23825318), ('EastAsian', 0.0063214526)])
# ('chuck_roast', [('LatinAmerican', 0.0032795155), ('NorthernEuropean', 0.0013531799)])
# ('vanilla', [('NorthAmerican', 0.19324651), ('EasternEuropean', 0.14698163)])
# ('focaccia', [('SouthernEuropean', 0.00070531812), ('EastAsian', 0.0)])
# ('parmesan_cheese', [('SouthernEuropean', 0.071025535), ('NorthAmerican', 0.043932553)])
# ('agar', [('NorthernEuropean', 0.0027063598), ('SoutheastAsian', 0.00055991043)])
# ('beansprouts', [('SoutheastAsian', 0.080907054), ('EastAsian', 0.021923335)])
# ('pork_liver', [('SoutheastAsian', 0.00027995522), ('WesternEuropean', 0.00014762327)])
# ('bouillon_cube', [('NorthernEuropean', 0.0013531799), ('SoutheastAsian', 0.00055991043)])
# ('capicola', [('SouthernEuropean', 0.00028212724), ('LatinAmerican', 0.00016818028)])
# ('french_fried_onions', [('SouthAsian', 0.0022111663), ('SoutheastAsian', 0.00055991043)])
# ('fresh_spinach', [('SouthAsian', 0.0085682701), ('SouthernEuropean', 0.0080406265)])
# ('stuffing', [('LatinAmerican', 0.00050454086), ('EastAsian', 0.00040349696)])
# ('whole_nutmegs', [('African', 0.00085251493), ('SouthAsian', 0.0008291874)])
# ('squid', [('EastAsian', 0.02125084), ('SoutheastAsian', 0.0075587905)])
# ('black_gram', [('SouthAsian', 0.0019347706), ('EastAsian', 0.00013449899)])
# ('pickled_jalapeno_peppers', [('LatinAmerican', 0.00050454086), ('NorthAmerican', 2.1813581e-05)])
# ('italian_style_seasoning', [('SouthernEuropean', 0.00084638171), ('LatinAmerican', 8.4090141e-05)])
# ('apricots', [('African', 0.0051150895), ('WesternEuropean', 0.0020667256)])
# ('sesame_seed', [('MiddleEastern', 0.040310077), ('EastAsian', 0.024882313)])
# ('shredded_nori', [('EastAsian', 0.00067249493), ('African', 0.0)])
# ('phyllo', [('African', 0.0025575447), ('SouthernEuropean', 0.00077584991)])
# ('cream', [('NorthernEuropean', 0.34100136), ('EasternEuropean', 0.29133859)])
# ('tomatoes', [('SouthAsian', 0.14400221), ('LatinAmerican', 0.0913219)])
# ('poblano', [('LatinAmerican', 0.0012613522), ('EastAsian', 0.0)])
# ('fenugreek', [('SouthAsian', 0.091210611), ('MiddleEastern', 0.021705426)])
# ('balm', [('SoutheastAsian', 0.00083986565), ('NorthAmerican', 6.5440741e-05)])
# ('cuban_peppers', [('African', 0.00085251493), ('LatinAmerican', 0.00042045073)])
# ('croissants', [('WesternEuropean', 0.0010333628), ('SouthAsian', 0.00027639579)])
# ('konbu', [('EastAsian', 0.008742434), ('SoutheastAsian', 0.00027995522)])
# ('broccoli', [('EastAsian', 0.029858775), ('SouthernEuropean', 0.019396247)])
# ('poblano_chiles', [('LatinAmerican', 0.01177262), ('SouthernEuropean', 0.00070531812)])
# ('pasta_water', [('SouthernEuropean', 0.00070531812), ('EastAsian', 0.00013449899)])
# ('feta_cheese', [('MiddleEastern', 0.023255814), ('SouthernEuropean', 0.011426154)])
# ('toasted_pumpkinseeds', [('LatinAmerican', 0.00042045073), ('NorthAmerican', 2.1813581e-05)])
# ('barbecue_sauce', [('LatinAmerican', 0.0031954255), ('NorthAmerican', 0.0014833235)])
# ('vinaigrette', [('WesternEuropean', 0.0019191025), ('African', 0.00085251493)])
# ('gluten_free_tamari', [('SoutheastAsian', 0.00083986565), ('EastAsian', 0.00040349696)])
# ('bananas', [('SoutheastAsian', 0.0092385216), ('LatinAmerican', 0.0052135889)])
# ('mirlitons', [('LatinAmerican', 0.00075681129), ('NorthAmerican', 2.1813581e-05)])
# ('split_black_lentils', [('SouthAsian', 0.0038695412), ('EastAsian', 0.0)])
# ('white_wine', [('EasternEuropean', 0.04199475), ('SouthernEuropean', 0.03427846)])
# ('sea_salt', [('African', 0.024722932), ('SouthAsian', 0.023493642)])
# ('habanero_chile', [('LatinAmerican', 0.0013454423), ('EastAsian', 0.00013449899)])
# ('fat_free_refried_beans', [('LatinAmerican', 0.0010090817), ('SouthernEuropean', 7.0531809e-05)])
# ('i_cant_believe_its_not_butter!_spread', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('medium_firm_tofu', [('EastAsian', 0.0016139878), ('SoutheastAsian', 0.00027995522)])
# ('nira', [('EastAsian', 0.0086079352), ('WesternEuropean', 0.00014762327)])
# ('ghee', [('SouthAsian', 0.075456053), ('EastAsian', 0.0030934769)])
# ('persimmon', [('EastAsian', 0.00040349696), ('SouthAsian', 0.00027639579)])
# ('toasted_nori', [('EastAsian', 0.0018829859), ('African', 0.0)])
# ('small_capers', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('bok_choy', [('EastAsian', 0.01062542), ('SoutheastAsian', 0.010358343)])
# ('japanese_eggplants', [('EastAsian', 0.0034969738), ('SoutheastAsian', 0.0025195968)])
# ('marzipan', [('African', 0.00085251493), ('WesternEuropean', 0.00073811633)])
# ('pearl_couscous', [('African', 0.0017050299), ('SoutheastAsian', 0.00027995522)])
# ('korean_chile_paste', [('EastAsian', 0.0013449899), ('African', 0.0)])
# ('ruby_port', [('WesternEuropean', 0.00073811633), ('EastAsian', 0.00026899797)])
# ('pies', [('WesternEuropean', 0.00014762327), ('NorthAmerican', 0.00013088148)])
# ('marshmallow_creme', [('WesternEuropean', 0.00059049309), ('NorthAmerican', 0.00019632223)])
# ('lovage', [('NorthAmerican', 0.0029012063), ('EasternEuropean', 0.0026246719)])
# ('safflower_oil', [('EastAsian', 0.0016139878), ('SouthAsian', 0.001381979)])
# ('white_flour', [('WesternEuropean', 0.0014762327), ('NorthernEuropean', 0.0013531799)])
# ('onion', [('EasternEuropean', 0.42519686), ('LatinAmerican', 0.38698286)])
# ('fresh_blueberries', [('WesternEuropean', 0.0023619724), ('NorthernEuropean', 0.0013531799)])
# ('vermouth', [('WesternEuropean', 0.00014762327), ('SouthernEuropean', 0.00014106362)])
# ('candy', [('WesternEuropean', 0.0010333628), ('LatinAmerican', 0.00050454086)])
# ('crumbled_gorgonzola', [('SouthernEuropean', 0.002186486), ('WesternEuropean', 0.00044286979)])
# ('cutlet', [('SouthernEuropean', 0.00070531812), ('SoutheastAsian', 0.00027995522)])
# ('sourdough', [('SouthernEuropean', 0.00056425447), ('WesternEuropean', 0.00029524654)])
# ('black_sesame_seeds', [('EastAsian', 0.0052454607), ('SoutheastAsian', 0.0011198209)])
# ('lager', [('LatinAmerican', 0.00058863102), ('WesternEuropean', 0.00044286979)])
# ('crisps', [('EastAsian', 0.00053799595), ('WesternEuropean', 0.00014762327)])
# ('semisweet_chocolate', [('WesternEuropean', 0.012252731), ('NorthernEuropean', 0.0054127197)])
# ('red_delicious_apples', [('WesternEuropean', 0.00044286979), ('SoutheastAsian', 0.00027995522)])
# ('almonds', [('African', 0.021312874), ('SouthAsian', 0.0096738534)])
# ('chocolate_instant_pudding', [('SouthernEuropean', 0.00021159543), ('WesternEuropean', 0.00014762327)])
# ('trout_fillet', [('African', 0.00085251493), ('SoutheastAsian', 0.00083986565)])
# ('bicarbonate_of_soda', [('WesternEuropean', 0.0013286094), ('SouthAsian', 0.00055279158)])
# ('leaf', [('African', 0.056265984), ('SouthernEuropean', 0.053392582)])
# ('green_enchilada_sauce', [('LatinAmerican', 0.0026067945), ('EastAsian', 0.0)])
# ('portobello_caps', [('SouthernEuropean', 0.00028212724), ('LatinAmerican', 0.00025227043)])
# ('diced_tomatoes_in_juice', [('African', 0.0017050299), ('LatinAmerican', 0.00084090146)])
# ('ladyfingers', [('SouthernEuropean', 0.0028212725), ('WesternEuropean', 0.0010333628)])
# ('trout', [('SoutheastAsian', 0.00027995522), ('EastAsian', 0.00026899797)])
# ('pepper', [('LatinAmerican', 0.62193072), ('African', 0.54049444)])
# ('frozen_peas_and_carrots', [('EastAsian', 0.0016139878), ('WesternEuropean', 0.00029524654)])
# ('champagne_wine', [('EasternEuropean', 0.0078740157), ('NorthAmerican', 0.0016360186)])
# ('pasta', [('SouthernEuropean', 0.018761462), ('LatinAmerican', 0.0026067945)])
# ('crusty_rolls', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 8.4090141e-05)])
# ('sicilian_olives', [('SouthernEuropean', 0.00049372268), ('EastAsian', 0.0)])
# ('biscuit_mix', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00044286979)])
# ('thin_pizza_crust', [('SouthernEuropean', 0.00077584991), ('LatinAmerican', 0.00025227043)])
# ('black_bean', [('LatinAmerican', 0.018163471), ('NorthAmerican', 0.0048426152)])
# ('superfine_sugar', [('WesternEuropean', 0.0031000886), ('NorthernEuropean', 0.0027063598)])
# ('smoked_sea_salt', [('SouthAsian', 0.00027639579), ('EastAsian', 0.00026899797)])
# ('seeds', [('SouthAsian', 0.017689331), ('EastAsian', 0.0033624747)])
# ('emmenthal', [('WesternEuropean', 0.00073811633), ('SouthernEuropean', 0.00014106362)])
# ('cranberry', [('NorthAmerican', 0.019152325), ('EasternEuropean', 0.0052493438)])
# ('ditalini_pasta', [('SouthernEuropean', 0.0010579771), ('LatinAmerican', 0.00016818028)])
# ('red_snapper', [('LatinAmerican', 0.0012613522), ('African', 0.00085251493)])
# ('teriyaki_sauce', [('EastAsian', 0.0060524545), ('SoutheastAsian', 0.0019596864)])
# ('steel_cut_oats', [('WesternEuropean', 0.00073811633), ('LatinAmerican', 8.4090141e-05)])
# ('lea_&_perrins_worcestershire_sauce', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('citron', [('NorthernEuropean', 0.0013531799), ('WesternEuropean', 0.00059049309)])
# ('green_tea', [('EastAsian', 0.002017485), ('WesternEuropean', 0.00073811633)])
# ('tenderloin', [('WesternEuropean', 0.00044286979), ('SouthernEuropean', 0.00014106362)])
# ('cocoa', [('NorthAmerican', 0.096394219), ('EasternEuropean', 0.049868766)])
# ('balsamic_reduction', [('SouthernEuropean', 0.00035265906), ('WesternEuropean', 0.00014762327)])
# ('shahi_jeera', [('SouthAsian', 0.0055279159), ('EastAsian', 0.0)])
# ('choy_sum', [('EastAsian', 0.0016139878), ('African', 0.0)])
# ('small_red_beans', [('LatinAmerican', 0.00075681129), ('EastAsian', 0.00013449899)])
# ('custard', [('WesternEuropean', 0.00044286979), ('LatinAmerican', 0.00025227043)])
# ('dried_chives', [('LatinAmerican', 0.00025227043), ('WesternEuropean', 0.00014762327)])
# ('bechamel', [('WesternEuropean', 0.00029524654), ('SouthernEuropean', 0.00021159543)])
# ('vegetables', [('NorthernEuropean', 0.010825439), ('EastAsian', 0.0079354402)])
# ('duck_fat', [('WesternEuropean', 0.0014762327), ('African', 0.00085251493)])
# ('caviar', [('NorthernEuropean', 0.013531799), ('EasternEuropean', 0.0052493438)])
# ('_drain', [('EastAsian', 0.0), ('MiddleEastern', 0.0)])
# ('orzo_pasta', [('African', 0.0017050299), ('SouthernEuropean', 0.0016927634)])
# ('nuoc_mam', [('SoutheastAsian', 0.0013997761), ('WesternEuropean', 0.00014762327)])
# ('ice_water', [('WesternEuropean', 0.0097431354), ('NorthernEuropean', 0.0027063598)])
# ('oven_ready_lasagna_noodles', [('SouthernEuropean', 0.0031033996), ('LatinAmerican', 8.4090141e-05)])
# ('ranch_dressing', [('LatinAmerican', 0.0037840565), ('SouthernEuropean', 0.00042319085)])
# ('gluten', [('SoutheastAsian', 0.0013997761), ('LatinAmerican', 0.00067272113)])
# ('catsup', [('SoutheastAsian', 0.00083986565), ('WesternEuropean', 0.00014762327)])
# ('hash_brown', [('SouthAsian', 0.00027639579), ('LatinAmerican', 0.00025227043)])
# ('demerara_sugar', [('WesternEuropean', 0.0010333628), ('SouthAsian', 0.00027639579)])
# ('strawberries', [('WesternEuropean', 0.012843224), ('NorthernEuropean', 0.0054127197)])
# ('firm_silken_tofu', [('EastAsian', 0.0012104909), ('African', 0.0)])
# ('liquor', [('WesternEuropean', 0.00029524654), ('EastAsian', 0.00013449899)])
# ('fillet_red_snapper', [('LatinAmerican', 0.0010090817), ('SouthernEuropean', 0.0009169135)])
# ('lime_peel_oil', [('African', 0.0025575447), ('LatinAmerican', 0.0017658931)])
# ('artemisia', [('EastAsian', 0.0016139878), ('WesternEuropean', 0.00014762327)])
# ('chopped_fresh_chives', [('NorthernEuropean', 0.013531799), ('WesternEuropean', 0.0095955124)])
# ('chipotles_in_adobo', [('LatinAmerican', 0.014883956), ('SoutheastAsian', 0.00027995522)])
# ('japanese_plum', [('EastAsian', 0.0016139878), ('WesternEuropean', 0.00014762327)])
# ('flat_iron_steaks', [('LatinAmerican', 0.00042045073), ('SoutheastAsian', 0.00027995522)])
# ('seltzer_water', [('EastAsian', 0.00040349696), ('SouthernEuropean', 0.00014106362)])
# ('cake', [('NorthernEuropean', 0.0027063598), ('EastAsian', 0.0013449899)])
# ('condiment', [('MiddleEastern', 0.0031007752), ('African', 0.0017050299)])
# ('taco_seasoning_mix', [('LatinAmerican', 0.015220316), ('EastAsian', 0.0)])
# ('self_rising_flour', [('WesternEuropean', 0.0062001771), ('NorthAmerican', 0.002813952)])
# ('yellow_hominy', [('LatinAmerican', 0.00067272113), ('NorthAmerican', 4.3627162e-05)])
# ('spanish_paprika', [('SouthernEuropean', 0.0016927634), ('LatinAmerican', 0.00025227043)])
# ('roasted_peanuts', [('SoutheastAsian', 0.027715566), ('EastAsian', 0.0053799595)])
# ('soda_water', [('SoutheastAsian', 0.00083986565), ('EastAsian', 0.00040349696)])
# ('sirloin', [('SoutheastAsian', 0.0022396417), ('EastAsian', 0.0013449899)])
# ('pig', [('NorthernEuropean', 0.0013531799), ('SoutheastAsian', 0.00083986565)])
# ('doenzang', [('EastAsian', 0.00080699392), ('African', 0.0)])
# ('penne', [('SouthernEuropean', 0.0074058399), ('LatinAmerican', 0.00033636056)])
# ('firmly_packed_light_brown_sugar', [('WesternEuropean', 0.0016238559), ('SoutheastAsian', 0.0011198209)])
# ('fishcake', [('EastAsian', 0.0013449899), ('African', 0.0)])
# ('hazelnuts', [('NorthernEuropean', 0.0054127197), ('SouthernEuropean', 0.0045845676)])
# ('cashew', [('SouthAsian', 0.045052513), ('SoutheastAsian', 0.0089585669)])
# ('amaretti', [('SouthernEuropean', 0.00042319085), ('WesternEuropean', 0.00014762327)])
# ('fresh_udon', [('EastAsian', 0.0012104909), ('SoutheastAsian', 0.00027995522)])
# ('oat', [('NorthAmerican', 0.026525315), ('NorthernEuropean', 0.0081190802)])
# ('whole_almonds', [('African', 0.0017050299), ('NorthernEuropean', 0.0013531799)])
# ('caesar_salad_dressing', [('SouthernEuropean', 0.00049372268), ('WesternEuropean', 0.00029524654)])
# ('star_anise', [('SoutheastAsian', 0.0044792835), ('EastAsian', 0.0028244788)])
# ('brown_sugar', [('SoutheastAsian', 0.098264277), ('EastAsian', 0.055413585)])
# ('slaw_mix', [('EastAsian', 0.0018829859), ('LatinAmerican', 0.0015977127)])
# ('dried_bonito_flakes', [('EastAsian', 0.0056489576), ('African', 0.0)])
# ('deep_dish_pie_crust', [('WesternEuropean', 0.00014762327), ('NorthAmerican', 0.00013088148)])
# ('gorgonzola', [('SouthernEuropean', 0.0019043589), ('WesternEuropean', 0.00029524654)])
# ('tasso', [('LatinAmerican', 0.0012613522), ('NorthAmerican', 0.00017450865)])
# ('capers', [('SouthernEuropean', 0.025109325), ('WesternEuropean', 0.014762326)])
# ('togarashi', [('EastAsian', 0.0017484869), ('African', 0.0)])
# ('chiffonade', [('SouthAsian', 0.00027639579), ('EastAsian', 0.00026899797)])
# ('french_lentils', [('WesternEuropean', 0.00073811633), ('SouthAsian', 0.00027639579)])
# ('cooking_liquid', [('African', 0.0017050299), ('SoutheastAsian', 0.00027995522)])
# ('munster_cheese', [('NorthAmerican', 0.00052352593), ('LatinAmerican', 0.00016818028)])
# ('liver', [('SoutheastAsian', 0.0041993279), ('WesternEuropean', 0.0029524653)])
# TypeErrorTraceback (most recent call last)
# <ipython-input-47-85c40e786919> in <module>()
#       1 food2cuisine = build_food2cuisine(recipes, vocab)
#       2
# ----> 3 for i in food2cuisine[:10]:
#       4     print i
#       5
#
# TypeError: unhashable type

# %%
with open('../dat/food2cuisine.json', 'w') as f:
    json.dump(food2cuisine, f, indent=2)

# %%
cuisines = list(set(food2cuisine.values()))
# np.random.seed(1234)
# tableau20_sample = np.random.choice(tableau20_rgb, len(cuisines), replace=False)
# cuisine2color = {cuisine: tableau20_sample[i] for i, cuisine in enumerate(cuisines)}
cuisine2color = {
    'African': sns.xkcd_rgb["grey"],
    'LatinAmerican': sns.xkcd_rgb["forest green"],
    'NorthAmerican': sns.xkcd_rgb["light pink"],
    'MiddleEastern': sns.xkcd_rgb["mustard yellow"],
    'EastAsian': sns.xkcd_rgb["orange"],
    'SouthAsian': sns.xkcd_rgb["magenta"],
    'SoutheastAsian': sns.xkcd_rgb["purple"],
    'NorthernEuropean': sns.xkcd_rgb["blue"],
    'EasternEuropean': sns.xkcd_rgb["deep blue"],
    'WesternEuropean': sns.xkcd_rgb["sky blue"],
    'SouthernEuropean': sns.xkcd_rgb["olive"],
}
food2color = {food: cuisine2color[food2cuisine[food]] for food in food2cuisine.keys()}

# %%
legend_order = [
'African',
'LatinAmerican',
'NorthAmerican',
'EastAsian',
'SouthAsian',
'SoutheastAsian',
'MiddleEastern',
'NorthernEuropean',
'EasternEuropean',
'WesternEuropean',
'SouthernEuropean',
]

# %%
labels = [item[0] for item in vocab]
legend_labels = [food2cuisine[food] for food in labels]
labels = [item[0] for item in vocab]
labels = map(pretty_food, labels)
# legend_order = cuisine2color.keys()
make_plot(name='food2vec_food_embeddings_tsne',
          points=low_dim_embs, 
          labels=labels, 
          legend_labels=legend_labels, 
          legend_order=legend_order, 
          legend_label_to_color=cuisine2color, 
          pretty_legend_label=pretty_cuisine,
          publish=False)
# Out:
# 0:88: execution error: "file:///Users/asd/coding/food2vec/src/food2vec_food_embeddings_tsne.html"이(가) ‘open location’ 메시지를 인식하지 못합니다. (-1708)

# %%
len(vocab)

# %% [markdown]
# ## Plot recipes
# NB: TSNE Takes ~10-30 minutes on 50k recipes

# %%
def build_recipe_embedding(recipes, nemb, food2id):
    """Get the recipe embedding.
    
    A recipe's embedding is the mean of its ingredients' embeddings.
    
    Args:
        recipes: list of recipes in the form [cuisine, food1, food2, ...]
        nemb: normalized embeddings
        food2id: map from food string to index in normalized embeddings
    Returns:
        List of tuples, each tuple has form (cuisine, ingredients, recipe embedding)
    """
    recipe_embeddings = []
    for line in recipes:
        cuisine = line.pop(0)
        foods = line
        # check that we have learned the embeddings for all the ingredients
        filtered_foods = [food for food in foods if food in food2id]
        if len(filtered_foods) > 0:
            food_ids = list(map(lambda x: food2id[x], filtered_foods))
            embedding = np.mean(nemb[food_ids], axis=0)
            recipe_embeddings.append((cuisine, foods, embedding))
    return recipe_embeddings

# %%
recipe_embeddings = build_recipe_embedding(recipes, nemb, food2id)

# %%
# subset = np.random.choice(range(len(recipe_embeddings)), 2000, replace=False)
# small = [recipe_embeddings[idx] for idx in subset]

# %%
cuisine_labels, ingredients, embeddings = zip(*recipe_embeddings)
cuisine_labels = list(cuisine_labels)
recipe_nemb = np.vstack(embeddings)

# %%
cuisine_counter = collections.Counter(cuisine_labels)

# %%
cuisine_counter

# %%
recipe_emb_path = os.path.join(path, 'low_dim_recipe_embs.npz')

# %%
# %load_ext wurlitzer
t0 = time.time()
low_dim_recipe_embs = run_tsne(recipe_nemb.astype(np.float64))
np.savez_compressed(recipe_emb_path, low_dim_recipe_embs)
print('time to run tsne on %d points: %.3f mins' % (len(recipe_nemb), (time.time() - t0) / 60.))

# %%
with open(recipe_emb_path, 'rb') as f:
    low_dim_recipe_embs = np.load(f)['arr_0']

# %%
# low_dim_recipe_embs = run_fast_tsne(embeddings)
# low_dim_recipe_embs = tsne.bh_sne(embeddings)
# t0 = time.time()
# low_dim_recipe_embs = bhtsne.run_bh_tsne(nemb, no_dims=2, perplexity=50, theta=0.5, randseed=-1, verbose=False,initial_dims=50, use_pca=True, max_iter=1000)
# print 'time to run tsne on %d points: %.3f mins' % (len(recipe_nemb), (time.time() - t0) / 60.)
low_dim_recipe_embs_list = low_dim_recipe_embs.tolist()

# %%
# clean_string = lambda x: re.sub(r'([^\s\w]|_)+', '', x)
recipe_labels = [', '.join([pretty_food(food) for food in foods]).lower().capitalize() for foods in ingredients]

# %%
make_plot(name='food2vec_recipe_embeddings_tsne',
          points=low_dim_recipe_embs_list, 
          labels=recipe_labels, 
          legend_labels=cuisine_labels, 
          legend_order=legend_order, 
          legend_label_to_color=cuisine2color, 
          pretty_legend_label=pretty_cuisine,
          publish=False)

# %% [markdown]
# ## Cuisine embeddings

# %%
# cuisine embedding as the average of recipe embeddings:
recipe_embeddings[0]
sorted_recipe_embeddings = sorted(recipe_embeddings, key=lambda x: x[0])
cuisine_embeddings = []
for cuisine_name, group in itertools.groupby(sorted_recipe_embeddings, lambda x: x[0]):
    cuisine_recipe_emb = []
    for tup in group:
        _, _, recipe_emb = tup
        cuisine_recipe_emb.append(recipe_emb)
    all_cuisine_recipe_emb = np.stack(cuisine_recipe_emb)
    cuisine_emb = np.mean(all_cuisine_recipe_emb, axis=0)
    cuisine_embeddings.append((cuisine_name, cuisine_emb))  


# cuisine embedding as the average of food embeddings with highest relative prevalence in that cuisine
# def reverse_dict(mydict):
#     reversed_dict = collections.defaultdict(list)
#     for key,value in mydict.iteritems():
#         reversed_dict[value].append(key)
#     return reversed_dict
# cuisine2foods = reverse_dict(food2cuisine)
# cuisine_embeddings = []
# for cuisine, foods in cuisine2foods.items():
#     food_ids = [food2id[food] for food in foods]
#     food_embs = nemb[food_ids]
#     cuisine_embeddings.append((cuisine, np.mean(food_embs, axis=0)))

# %%
t0 = time.time()
cuisine_names, cuisine_emb = zip(*cuisine_embeddings)
cuisine_emb = np.asarray(cuisine_emb)
low_dim_cuisine_embs = run_tsne(cuisine_emb, multicore=False)
print('time to run tsne on %d points: %.3f mins' % (len(cuisine_emb), (time.time() - t0) / 60.))

# %%
make_plot(name='food2vec_cuisine_embeddings_tsne',
          points=low_dim_cuisine_embs, 
          labels=cuisine_names, 
          legend_labels=cuisine_names, 
          legend_order=legend_order, 
          legend_label_to_color=cuisine2color, 
          pretty_legend_label=pretty_cuisine,
          publish=False)

# %% [markdown]
# ## Write foods to json

# %%
foods = [tup[0] for tup in vocab]
food2prettyfood = [{"value": food, "text": pretty_food(food)} for food in foods]
food2prettyfood.append([{"value": tup[0], "text": pretty_cuisine(tup[0])} for tup in cuisine_embeddings])
with open(os.path.join(path, 'foods.json'), 'w') as f:
    json.dump(food2prettyfood, f, indent=4)

# %%
def write_to_js(words, embeddings, path):
    word_vecs = {}
    for word, embedding in zip(words, embeddings):
        word_vecs[word] = embedding.tolist()
    with open(path, 'w') as f:
        f.write('var wordVecs=')
        json.dump(word_vecs, f)
        f.write(';')
# lower precision, faster
# nemb = nemb.astype(np.float16)
words = [pretty_food(food) for food in foods] + [pretty_cuisine(tup[0]) for tup in cuisine_embeddings]
all_emb = np.vstack([nemb, cuisine_emb])
# '../../word2vecjson/data/foodVecs.js'
write_to_js(words, all_emb, path=os.path.join(path, 'foodVecs.js'))

# %%
# print list of foods for autocomplete in assets/js/initm.js
string = str({word: None for word in words})
with open(os.path.join(path, 'javascript_dict.txt'), 'w') as f:
    f.write(string.replace('None', 'null'))
