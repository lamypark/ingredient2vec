# %%
import os
import collections
import smart_open
import random
import numpy as np
import h5py
from gensim.models.keyedvectors import KeyedVectors

import Config
from utils import DataLoader, GensimModels, DataPlotter
gensimLoader = GensimModels.GensimModels()
path_results = ".." + os.sep + "results" + os.sep + "embeddings"
model_ingr2vec_cc = gensimLoader.load_word2vec(path=path_results + os.sep + "embeddings_ingredients_cc_f-5_rs-True_ns-50_ifcharemb-False_dim-10_1801031522.bin")
model_ingr2vec_ic = gensimLoader.load_word2vec(path=path_results + os.sep + "embeddings_ingredients_ic_f-5_rs-True_ns-50_ifcharemb-False_dim-10_1801031522.bin")

# %%
print len(model_ingr2vec_cc.vocab)
print len(model_ingr2vec_ic.vocab)
# Out:
# 731
# 2073

# %%
both = []
for i in model_ingr2vec_cc.vocab:
    if i in model_ingr2vec_ic.vocab:
        both.append(i)
print len(both)
# Out:
# 172

# %%
for i in both:
    print 
    print i
    print model_ingr2vec_cc.most_similar(positive=[i], topn=3)
    print model_ingr2vec_ic.most_similar(positive=[i], topn=3)
# Out:
# brussels_sprout
# [(u'ethiopian_pepper', 0.8240945339202881), (u'nectandra_elaiophora', 0.7902816534042358), (u'nepeta_japonica', 0.7856736779212952)]
# [(u'chicken_liver', 0.9392240643501282), (u'olive_oil', 0.8616132736206055), (u'roasted_pork', 0.8472099900245667)]
#
# sunflower_oil
# [(u'loiseleuria_procumbens', 0.7779616117477417), (u'chinese_quince', 0.7778029441833496), (u'picea_orientalis', 0.7573573589324951)]
# [(u'chillies', 0.9618080258369446), (u'dried_red_chile_peppers', 0.9613711833953857), (u'red_chili_peppers', 0.9368488192558289)]
#
# mackerel
# [(u'bergamot_oil', 0.8145027756690979), (u'polyalthia_canangioides_flower', 0.8050141334533691), (u'wasabi', 0.8024291396141052)]
# [(u'eel', 0.944613516330719), (u'shellfish', 0.9289214611053467), (u'enokidake', 0.921826958656311)]
#
# lemon_juice
# [(u'orange_peel_oil', 0.7562866806983948), (u'brown_rice', 0.7540813684463501), (u'keta_salmon', 0.7522468566894531)]
# [(u'beet', 0.8916716575622559), (u'chicory', 0.8772430419921875), (u'shallot', 0.8669138550758362)]
#
# guava
# [(u'endive', 0.8293793201446533), (u'piper_officinarum', 0.7956449389457703), (u'rose_oil', 0.7901275753974915)]
# [(u'carob', 0.9759153127670288), (u'adzuki_beans', 0.9747030735015869), (u'fudge_brownie_mix', 0.9730829000473022)]
#
# anise_seed
# [(u'japanese_mint', 0.825858473777771), (u'turpentine', 0.7979153990745544), (u'bilberry_wine', 0.7977868914604187)]
# [(u'pistachio', 0.9238476157188416), (u'almond', 0.9036515951156616), (u'pecan', 0.8931223154067993)]
#
# camembert_cheese
# [(u'phallus_impudicus', 0.8070927858352661), (u'sage', 0.8043686151504517), (u'cheese', 0.7857310771942139)]
# [(u'cassava', 0.9626262784004211), (u'mahimahi', 0.960869550704956), (u'natural_pistachios', 0.9587910175323486)]
#
# melon
# [(u'parsley', 0.8105292320251465), (u'corn_oil', 0.7747371196746826), (u'lean_fish', 0.7680411338806152)]
# [(u'watermelon', 0.9767495393753052), (u'grapefruit', 0.9642713665962219), (u'gin', 0.9283366203308105)]
#
# thai_pepper
# [(u'chestnut_honey', 0.7813841700553894), (u'rosa_bourboniana_oil', 0.7701928019523621), (u'eucalyptus_goniocalyx', 0.7657114267349243)]
# [(u'galanga', 0.8972477912902832), (u'lemongrass', 0.8422554135322571), (u'palm', 0.8206241130828857)]
#
# lima_bean
# [(u'buchu', 0.7957279086112976), (u'solidago_odora', 0.7834483981132507), (u'congo_geranium', 0.7611596584320068)]
# [(u'green_bell_pepper', 0.9480816125869751), (u'corn_grit', 0.9109530448913574), (u'onion', 0.896682858467102)]
#
# peanut_butter
# [(u'roasted_beef', 0.8302195072174072), (u'caja_fruit', 0.8021213412284851), (u'black_currant', 0.7873936295509338)]
# [(u'cereal', 0.857315182685852), (u'roasted_peanut', 0.8305386304855347), (u'popcorn', 0.7722870707511902)]
#
# kidney_bean
# [(u'japanese_hop', 0.792615532875061), (u'pinus_sabiniana_terpentine', 0.7825868725776672), (u'anise_brandy', 0.7808544635772705)]
# [(u'red_kidney_bean', 0.9469362497329712), (u'tomato_juice', 0.9318177700042725), (u'smoked_sausage', 0.8690010905265808)]
#
# apple_brandy
# [(u'while_thyme_oil', 0.7606461048126221), (u'pinus_jeffreyi', 0.7522034645080566), (u'citronella_oil', 0.743131160736084)]
# [(u'quince', 0.897124171257019), (u'bartlett_pear', 0.8847014904022217), (u'khoa', 0.8753560781478882)]
#
# smoked_fish
# [(u'saigon_cinnamon', 0.7885667085647583), (u'jamaican_rum', 0.7812202572822571), (u'coconut_oil', 0.7790680527687073)]
# [(u'salmon_roe', 0.9408991932868958), (u'johnsonville_andouille', 0.9336394667625427), (u'fresh_green_peas', 0.9331903457641602)]
#
# egg_noodle
# [(u'loiseleuria_procumbens', 0.8029619455337524), (u'picea_canadensis', 0.8016557693481445), (u'jamaican_rum', 0.7994940876960754)]
# [(u'ham', 0.9353834986686707), (u'corn_grit', 0.9352218508720398), (u'bacon', 0.9251662492752075)]
#
# tea
# [(u'tsuga_canadensis', 0.7999283075332642), (u'orange_peel_oil', 0.7960659265518188), (u'beechwood_tar', 0.7923998832702637)]
# [(u'rum', 0.9119576215744019), (u'rose', 0.8921568393707275), (u'black_tea', 0.8921139240264893)]
#
# almond
# [(u'echinacea', 0.8516219854354858), (u'kencur_oil', 0.8262842893600464), (u'curcuma_aromatica', 0.8180867433547974)]
# [(u'pistachio', 0.9286524057388306), (u'orange_peel', 0.9216068983078003), (u'hazelnut', 0.9112881422042847)]
#
# bacon
# [(u'lesquerella_seed', 0.8597861528396606), (u'eucalyptus_cinereea', 0.8456553220748901), (u'borosma_pulchellum', 0.8219402432441711)]
# [(u'ham', 0.9726660251617432), (u'egg_noodle', 0.9251663684844971), (u'smoked_sausage', 0.8824681639671326)]
#
# lavender
# [(u'chamaecyparis_pisifera', 0.7477412819862366), (u'ambrette_seed', 0.7472397685050964), (u'cicuta_virosa_oil', 0.7445751428604126)]
# [(u'fig', 0.835051417350769), (u'cognac', 0.8185938596725464), (u'pernod', 0.8085914850234985)]
#
# currant
# [(u'hybrid_passion_fruit_juice', 0.8240109086036682), (u'french_peppermint_oil', 0.7862624526023865), (u'skim_milk', 0.7686325311660767)]
# [(u'date', 0.9045125246047974), (u'apricot', 0.9040555357933044), (u'fig', 0.8983598351478577)]
#
# frankfurter
# [(u'perovski_abrotanoides_oil', 0.814660906791687), (u'herring', 0.7857267260551453), (u'wild_strawberry', 0.7856954336166382)]
# [(u'frozen_hash_browns', 0.852537214756012), (u'red_kidney_bean', 0.8289930820465088), (u'taco_toppings', 0.8281775712966919)]
#
# corn_flake
# [(u'roasted_macadamia_nut', 0.7799437642097473), (u'cinchona_officinalis', 0.7553808689117432), (u'coffee', 0.7507486343383789)]
# [(u'lard', 0.909186840057373), (u'rye_flour', 0.8892772197723389), (u'potato_chip', 0.8802779912948608)]
#
# vinegar
# [(u'scallop', 0.7957891821861267), (u'bitter_orange_flower_oil', 0.7713469862937927), (u'bitter_fennel', 0.7624636888504028)]
# [(u'red_wine', 0.9111580848693848), (u'mustard', 0.901736319065094), (u'tabasco_pepper', 0.8663296103477478)]
#
# maple_syrup
# [(u'agaricus', 0.7777389883995056), (u'mango', 0.7679964303970337), (u'corn_mint', 0.7661416530609131)]
# [(u'oat', 0.9081557989120483), (u'pecan', 0.8727982044219971), (u'apple', 0.8566275238990784)]
#
# cinnamon
# [(u'onion_oil', 0.7932419180870056), (u'picea_orientalis', 0.7921295166015625), (u'strawberry_oil', 0.7908909916877747)]
# [(u'mace', 0.9013947248458862), (u'date', 0.8771743178367615), (u'cardamom', 0.8598491549491882)]
#
# smoke
# [(u'grapefruit_juice', 0.7784020900726318), (u'cacao', 0.770850419998169), (u'blenheim_apricot', 0.7689846754074097)]
# [(u'tomato_juice', 0.9647417068481445), (u'roasted_beef', 0.9601536393165588), (u'potato', 0.9072374701499939)]
#
# bartlett_pear
# [(u'anise_hyssop', 0.8016484975814819), (u'winter_savory', 0.7976608872413635), (u'american_sassafras_oil', 0.7835381031036377)]
# [(u'demerara_sugar', 0.9409510493278503), (u'kumquat', 0.9396147727966309), (u'khoa', 0.9388206005096436)]
#
# roquefort_cheese
# [(u'basil_oil', 0.7625409960746765), (u'black_tea_oil', 0.7619988918304443), (u'catfish', 0.7617247104644775)]
# [(u'chayote', 0.8994879722595215), (u'beef_liver', 0.8969035744667053), (u'flanken_short_ribs', 0.8797460198402405)]
#
# herring
# [(u'frankfurter', 0.7857266664505005), (u'perovski_abrotanoides_oil', 0.7741516828536987), (u'cinnamon', 0.7721682190895081)]
# [(u'blackening_seasoning', 0.9607709646224976), (u'bouquet', 0.9483518004417419), (u'canola_mayonnaise', 0.9478545784950256)]
#
# passion_fruit
# [(u'rhus_semialata', 0.7804592251777649), (u'solidago_odora', 0.7776071429252625), (u'pomelo_peel', 0.77629554271698)]
# [(u'grenadine_syrup', 0.9596922993659973), (u'frozen_lemonade_concentrate', 0.9572919607162476), (u'lemonade', 0.9559704661369324)]
#
# raspberry
# [(u'pimento', 0.832283079624176), (u'picea_orientalis', 0.8077077865600586), (u'larix_deciduas', 0.7950565218925476)]
# [(u'strawberry', 0.9683679342269897), (u'gelatin', 0.964419960975647), (u'berry', 0.9466925263404846)]
#
# olive
# [(u'phallus_impudicus', 0.7609338164329529), (u'cananga', 0.7553958892822266), (u'piper_officinarum', 0.7541163563728333)]
# [(u'cannellini_beans', 0.9258986115455627), (u'eggplant', 0.8956694602966309), (u'green_olives', 0.8838386535644531)]
#
# malt
# [(u'chicory', 0.821472704410553), (u'dalbergia_sissoo', 0.8169119358062744), (u'quercus_olive', 0.8137079477310181)]
# [(u'honey', 0.8470349311828613), (u'chinese_rock_sugar', 0.7962680459022522), (u'whole_cloves', 0.7835564613342285)]
#
# chayote
# [(u'chinese_quince', 0.8430896401405334), (u'eucalyptus_globulus_oil', 0.7960839867591858), (u'lobster', 0.794916570186615)]
# [(u'roquefort_cheese', 0.8994879722595215), (u'camembert_cheese', 0.877940833568573), (u'condiment', 0.8662711381912231)]
#
# honey
# [(u'seseli_sibiricum', 0.8708181977272034), (u'cinnamon_leaf_oil', 0.7955357432365417), (u'champaca', 0.7876754403114319)]
# [(u'orange_juice', 0.8947779536247253), (u'malt', 0.8470349311828613), (u'apple', 0.8224436044692993)]
#
# turmeric
# [(u'red_bean', 0.7946746349334717), (u'roasted_beef', 0.7809883952140808), (u'russian_star_anise', 0.7775904536247253)]
# [(u'cashew', 0.8614364862442017), (u'cauliflower', 0.8414860963821411), (u'fresh_curry_leaves', 0.8310906887054443)]
#
# cottage_cheese
# [(u'gardenia_flower_oil', 0.7934248447418213), (u'senecio_kaempferi', 0.7917777895927429), (u'spanish_sage', 0.7894337773323059)]
# [(u'potato_chip', 0.8941472768783569), (u'wheat_bread', 0.8921610713005066), (u'swiss_cheese', 0.8909216523170471)]
#
# porcini
# [(u'dolphin', 0.7940896153450012), (u'crepis_foetida_root', 0.7863932251930237), (u'micromeria_abyssinica', 0.7798577547073364)]
# [(u'veal', 0.9761538505554199), (u'truffle', 0.8948587775230408), (u'pancetta', 0.8675992488861084)]
#
# grape_brandy
# [(u'skim_milk', 0.8103906512260437), (u'boldea_fragrans', 0.7845014333724976), (u'american_sassafras_oil', 0.7842416763305664)]
# [(u'pear_brandy', 0.9814103841781616), (u'orange_flower', 0.9755205512046814), (u'huckleberry', 0.9752400517463684)]
#
# gelatin
# [(u'acacia_flower_oil', 0.7936713695526123), (u'thea_chinensis_oil', 0.7923229932785034), (u'vanilla_oil', 0.7703126072883606)]
# [(u'strawberry', 0.9696444272994995), (u'raspberry', 0.9644200205802917), (u'blackberry', 0.9612395763397217)]
#
# mango
# [(u'mentha_silvestris_oil', 0.8164159059524536), (u'loganberry', 0.8069959878921509), (u'petrosimonia_monandra', 0.7898727655410767)]
# [(u'lime', 0.8788102269172668), (u'papaya', 0.8674827218055725), (u'lime_juice', 0.8479102849960327)]
#
# coconut_oil
# [(u'turnip', 0.829170823097229), (u'grapefruit_peel', 0.8003138303756714), (u'eucalyptus_citridora', 0.7979991436004639)]
# [(u'bengal_gram', 0.9652130007743835), (u'toor_dal', 0.9559523463249207), (u'jackfruit', 0.952355682849884)]
#
# wine
# [(u'california_pepper', 0.772598385810852), (u'verbena_oil', 0.7697156071662903), (u'potato_chip', 0.7677507996559143)]
# [(u'littleneck_clams', 0.8687703013420105), (u'leaf', 0.8640335202217102), (u'mussels', 0.856873631477356)]
#
# cheese
# [(u'lean_fish', 0.8231430649757385), (u'sage', 0.8009987473487854), (u'monarda_citriodora_oil', 0.7962052226066589)]
# [(u'lasagna_noodles', 0.9510716795921326), (u'italian_seasoning', 0.9417792558670044), (u'pasta_sauce', 0.9265916347503662)]
#
# chickpea
# [(u'eucalyptus_oil', 0.8390722870826721), (u'red_kidney_bean', 0.8069323301315308), (u'abies_concolor', 0.7939811944961548)]
# [(u'bell_pepper', 0.8764782547950745), (u'cauliflower', 0.874092698097229), (u'cayenne', 0.8583254814147949)]
#
# katsuobushi
# [(u'chinese_star_anise', 0.8292643427848816), (u'calytrix_tetragona', 0.8102179765701294), (u'ligusticum_acutilobum_oil', 0.788874089717865)]
# [(u'eel', 0.9440261125564575), (u'shellfish', 0.922575831413269), (u'enokidake', 0.913131058216095)]
#
# roasted_sesame_seed
# [(u'teucrium_chamaedrys', 0.9464455246925354), (u'trifolium_pratense_leaf_oil', 0.8432109355926514), (u'grapefruit_blossom', 0.8191261291503906)]
# [(u'radish', 0.9570513963699341), (u'enokidake', 0.9291161894798279), (u'chinese_cabbage', 0.9243600368499756)]
#
# avocado
# [(u'salmon_caviar', 0.8196145296096802), (u'petasites_fragrans', 0.8124136924743652), (u'chive', 0.8076431751251221)]
# [(u'lettuce', 0.8503215312957764), (u'lime', 0.7950376868247986), (u'cilantro', 0.778339684009552)]
#
# tomato_juice
# [(u'pittosporum_glabratum', 0.7922805547714233), (u'ethiopian_pepper', 0.7770334482192993), (u'cherimoya', 0.7657593488693237)]
# [(u'smoke', 0.9647417068481445), (u'kidney_bean', 0.9318177700042725), (u'roasted_beef', 0.922230064868927)]
#
# black_sesame_seed
# [(u'rhodotorula_glutinis', 0.7658379673957825), (u'ambrette_seed', 0.7645931243896484), (u'squash', 0.7552262544631958)]
# [(u'red_bean', 0.9668108820915222), (u'eel', 0.9201486706733704), (u'gardenia', 0.9037775993347168)]
#
# carnation
# [(u'strawberry_jam', 0.8137702941894531), (u'salmon_caviar', 0.8110685348510742), (u'blackberry_juice', 0.7944210767745972)]
# [(u'pasilla', 0.9618573188781738), (u'wheels', 0.961578369140625), (u'frozen_pizza_dough', 0.9542436003684998)]
#
# wasabi
# [(u'russian_champagne', 0.8413848876953125), (u'mackerel', 0.8024291396141052), (u'bergamot_oil', 0.7872375249862671)]
# [(u'seaweed', 0.9699903726577759), (u'sushi_nori', 0.9365025758743286), (u'gari', 0.8752674460411072)]
#
# chicory
# [(u'litsea_guatemalensis_oil', 0.8297551870346069), (u'dalbergia_sissoo', 0.8278759717941284), (u'malt', 0.821472704410553)]
# [(u'endive', 0.9018827080726624), (u'beet', 0.8910462856292725), (u'white_wine', 0.8895290493965149)]
#
# bread
# [(u'hyacinth_oil', 0.8574455976486206), (u'pennyroyal_oil', 0.8160293698310852), (u'agastache_formosana', 0.7800532579421997)]
# [(u'white_bread', 0.8503235578536987), (u'pimento', 0.7903620004653931), (u'rosemary', 0.7679364085197449)]
#
# juniper_berry
# [(u'eriostemon_coxii_leaf_oil', 0.8083113431930542), (u'crayfish', 0.8067768216133118), (u'purple_passion_fruit', 0.8000230193138123)]
# [(u'cabernet_sauvignon_wine', 0.875636637210846), (u'roasted_pork', 0.8463401198387146), (u'marjoram', 0.8266525864601135)]
#
# meat
# [(u'bilberry_wine', 0.7814250588417053), (u'doryphora_sassafras_leaf_oil', 0.7594675421714783), (u'pinus_excelsa', 0.7576763033866882)]
# [(u'beef', 0.9355772733688354), (u'lima_bean', 0.8890708088874817), (u'green_bell_pepper', 0.8718773126602173)]
#
# chicken_broth
# [(u'bulgarian_clary_sage_oil', 0.7854304909706116), (u'cereal', 0.7815080285072327), (u'wild_rice', 0.7800427079200745)]
# [(u'potato', 0.9301536679267883), (u'carrot', 0.9171411991119385), (u'parsnip', 0.897211492061615)]
#
# beef_broth
# [(u'feces', 0.799282431602478), (u'vitis_labrusca', 0.7812153100967407), (u'ambrette_seed_oil', 0.7570492625236511)]
# [(u'barley', 0.9424795508384705), (u'roasted_beef', 0.9121639728546143), (u'turnip', 0.9068267941474915)]
#
# turnip
# [(u'cinnamomum_cassia_oil', 0.8416310548782349), (u'coconut_oil', 0.829170823097229), (u'eucalyptus_citriodora_oil', 0.8129439353942871)]
# [(u'parsnip', 0.9717426300048828), (u'beef_broth', 0.9068267941474915), (u'barley', 0.9005488157272339)]
#
# sweet_potato
# [(u'barosma_crenulata', 0.7970632314682007), (u'angelica', 0.7825822234153748), (u'rhus_semialata', 0.7675120234489441)]
# [(u'yam', 0.9459108710289001), (u'raisin', 0.9231957793235779), (u'walnut', 0.84404057264328)]
#
# rye_flour
# [(u'brassica', 0.8543230891227722), (u'tsuga_canadensis', 0.8285995721817017), (u'russian_champagne', 0.8065390586853027)]
# [(u'lard', 0.9333568811416626), (u'corn_flake', 0.8892772197723389), (u'whole_grain_wheat_flour', 0.8838925957679749)]
#
# black_tea
# [(u'ceylon_tea_citronella_oil', 0.8159499168395996), (u'calytrix_tetragona', 0.8106200695037842), (u'salmon_caviar', 0.7827650904655457)]
# [(u'fruit', 0.9345245361328125), (u'citrus', 0.9255010485649109), (u'tangerine', 0.9231797456741333)]
#
# cassava
# [(u'citronella_oil', 0.8030415177345276), (u'cacao', 0.7581419348716736), (u'vetiver', 0.7557376027107239)]
# [(u'camembert_cheese', 0.9626262784004211), (u'huckleberry', 0.9417926669120789), (u'tandoori_seasoning', 0.9367626309394836)]
#
# orange_flower
# [(u'oak_leaf', 0.7834088206291199), (u'pinus_communis_oil', 0.7708237171173096), (u'castoreum', 0.7693795561790466)]
# [(u'pear_brandy', 0.975719690322876), (u'grape_brandy', 0.9755205512046814), (u'concord_grape', 0.9583433270454407)]
#
# bay
# [(u'boldo_leaf', 0.8011335134506226), (u'eel', 0.7933735847473145), (u'grapefruit_blossom', 0.7859996557235718)]
# [(u'celery', 0.9153846502304077), (u'kale', 0.8909082412719727), (u'thyme', 0.859821081161499)]
#
# licorice
# [(u'vitis_labrusca', 0.8084625005722046), (u'pandanus_odoratissimus_oil', 0.7807595133781433), (u'caucas', 0.7647831439971924)]
# [(u'concord_grape', 0.9686142802238464), (u'pear_brandy', 0.9631994962692261), (u'pie_filling', 0.9617427587509155)]
#
# scallion
# [(u'cocoa_leaf', 0.7913357019424438), (u'teucrium_chamaedrys', 0.7772085666656494), (u'mulberry_leaf', 0.7638128995895386)]
# [(u'roasted_sesame_seed', 0.923893928527832), (u'sesame_seed', 0.9080204367637634), (u'radish', 0.9026183485984802)]
#
# kiwi
# [(u'phallus_impudicus', 0.8283581733703613), (u'caraway_seed', 0.8009743094444275), (u'borosma_pulchellum', 0.7924980521202087)]
# [(u'gin', 0.904472291469574), (u'watermelon', 0.9012750387191772), (u'grapefruit', 0.8921703100204468)]
#
# cereal
# [(u'spanish_sage', 0.7958883047103882), (u'eucalyptus_maideni', 0.7942326664924622), (u'litsea_guatemalensis_oil', 0.7941812872886658)]
# [(u'oat', 0.9510020017623901), (u'pecan', 0.8612145185470581), (u'lard', 0.860832154750824)]
#
# banana
# [(u'litsea_guatemalensis', 0.7928743958473206), (u'peanut_butter', 0.7737600803375244), (u'artemisia_ferganensis', 0.7691068053245544)]
# [(u'blueberry', 0.8785713911056519), (u'lime_peel_oil', 0.8683263063430786), (u'gelatin', 0.843994677066803)]
#
# haddock
# [(u'muscat_grape_juice', 0.7938569784164429), (u'coffee', 0.7847040295600891), (u'roasted_sesame_seed', 0.7833429574966431)]
# [(u'hungarian_paprika', 0.8444451689720154), (u'schmaltz', 0.8415448665618896), (u'bouillon_cube', 0.8295374512672424)]
#
# bergamot
# [(u'eucalyptus_oil', 0.811126708984375), (u'mimusops_elengi_flower', 0.793630838394165), (u'abies_concolor', 0.7789820432662964)]
# [(u'gran_marnier', 0.9549549221992493), (u'figs', 0.9511003494262695), (u'ruby_port', 0.9484129548072815)]
#
# coconut
# [(u'krill', 0.7979550361633301), (u'cistus_ladaniferus', 0.7948781251907349), (u'michelia', 0.7908920645713806)]
# [(u'curry_paste', 0.8531264066696167), (u'cashew', 0.847705066204071), (u'jaggery', 0.79876708984375)]
#
# corn_grit
# [(u'catfish', 0.8005039691925049), (u'bergamot_peel_oil', 0.7942818403244019), (u'fagroea_racemosa_flower', 0.7856625914573669)]
# [(u'egg_noodle', 0.9352218508720398), (u'green_bell_pepper', 0.9176925420761108), (u'lima_bean', 0.9109531044960022)]
#
# violet
# [(u'heracleum_candicans_oil', 0.7835085988044739), (u'cayenne', 0.7752577066421509), (u'iberis_sempervirens_seed', 0.7658470273017883)]
# [(u'croissants', 0.9818518161773682), (u'panettone', 0.9756945371627808), (u'mini_chocolate_chips', 0.9737913608551025)]
#
# cucumber
# [(u'artemisia_juncea', 0.8353062868118286), (u'cantaloupe', 0.8286035060882568), (u'prawn', 0.7775309681892395)]
# [(u'watercress', 0.8227666020393372), (u'lettuce', 0.8214025497436523), (u'tuna', 0.8126185536384583)]
#
# port_wine
# [(u'bilberry_wine', 0.8169214725494385), (u'artemisia_juncea', 0.8066821098327637), (u'ceylon_tea', 0.7986307144165039)]
# [(u'orange_peel', 0.8709875345230103), (u'sour_cherry', 0.8704416751861572), (u'hazelnut', 0.858532190322876)]
#
# seed
# [(u'haddock', 0.7786838412284851), (u'litsea_zeylanica_oil', 0.7720743417739868), (u'teucrium_chamaedrys', 0.7711148262023926)]
# [(u'vegetable_oil', 0.9151059985160828), (u'beet', 0.8561381101608276), (u'mustard', 0.8538274168968201)]
#
# mint
# [(u'rose', 0.7711955904960632), (u'blackberry_juice', 0.7701690196990967), (u'oak_tar_oil', 0.7676360607147217)]
# [(u'melon', 0.8327782154083252), (u'watermelon', 0.8044416904449463), (u'papaya', 0.7916266918182373)]
#
# cayenne
# [(u'imperatoria', 0.8340539336204529), (u'picea_balsamea_oil', 0.8296678066253662), (u'wintergreen_leaf', 0.8204634785652161)]
# [(u'tamarind', 0.9071311950683594), (u'onion', 0.8805989027023315), (u'kidney_bean', 0.8650764226913452)]
#
# zucchini
# [(u'sassafras_root_oil', 0.8093100190162659), (u'chinese_cinnamon', 0.7741685509681702), (u'nectarine', 0.7687623500823975)]
# [(u'basil', 0.8526899814605713), (u'chicken', 0.8062329292297363), (u'squash', 0.7733033895492554)]
#
# mace
# [(u'roasted_mate', 0.8027075529098511), (u'java_citronella', 0.7793906927108765), (u'honey', 0.7742670774459839)]
# [(u'cinnamon', 0.9013947248458862), (u'cardamom', 0.8706849813461304), (u'apricot', 0.8501359224319458)]
#
# oyster
# [(u'aconitum_napellus', 0.811002254486084), (u'micromeria_abyssinica', 0.8017405867576599), (u'orange_leaf_oil', 0.7986194491386414)]
# [(u'shiitake', 0.957237958908081), (u'soy_sauce', 0.8802649974822998), (u'kelp', 0.8782253861427307)]
#
# sauerkraut
# [(u'eucalyptus_dives', 0.8606881499290466), (u'kelp', 0.817675769329071), (u'petasites_fragrans', 0.814342737197876)]
# [(u'caraway', 0.8791686296463013), (u'ham', 0.8310512900352478), (u'bacon', 0.819925844669342)]
#
# macadamia_nut
# [(u'oak_tar_oil', 0.7954599857330322), (u'wort', 0.7832809686660767), (u'perovski_abrotanoides_oil', 0.7786570191383362)]
# [(u'sour_milk', 0.9458789825439453), (u'coffee', 0.9334611892700195), (u'rhubarb', 0.9293658137321472)]
#
# egg
# [(u'luvunga_scadens_oil', 0.8496553301811218), (u'cantaloupe', 0.7994226217269897), (u'picea_canadensis', 0.7957106828689575)]
# [(u'wheat_bread', 0.8843655586242676), (u'cream_cheese', 0.8724806308746338), (u'lard', 0.8620766401290894)]
#
# tequila
# [(u'sugarcane', 0.815303385257721), (u'cinnamon_oil', 0.806719183921814), (u'peru_balsam', 0.803535521030426)]
# [(u'watermelon', 0.8785502910614014), (u'papaya', 0.8730145692825317), (u'kiwi', 0.8491712212562561)]
#
# sage
# [(u'camembert_cheese', 0.8043687343597412), (u'parsley', 0.8025025129318237), (u'cheese', 0.8009987473487854)]
# [(u'thyme', 0.9238771200180054), (u'liver', 0.9045877456665039), (u'marjoram', 0.8977543115615845)]
#
# rye_bread
# [(u'luvunga_scadens_oil', 0.808377206325531), (u'picea_canadensis', 0.7824045419692993), (u'melilotus_officinalis_flower', 0.7804874181747437)]
# [(u'swiss_cheese', 0.9075366854667664), (u'egg_noodle', 0.8678708076477051), (u'ham', 0.8422372341156006)]
#
# fennel
# [(u'seseli_sibiricum', 0.8407410383224487), (u'russian_champagne', 0.835932731628418), (u'fermented_tea_leaf_oil', 0.8226219415664673)]
# [(u'rosemary', 0.8770495653152466), (u'bay', 0.8279713988304138), (u'lamb', 0.827277660369873)]
#
# shellfish
# [(u'prawn', 0.7930631041526794), (u'mango', 0.7889784574508667), (u'kale', 0.7856407165527344)]
# [(u'eel', 0.947868824005127), (u'mackerel', 0.9289214611053467), (u'katsuobushi', 0.922575831413269)]
#
# nectarine
# [(u'ceylon_tea_citronella_oil', 0.8023401498794556), (u'eucalyptus_cinereea', 0.7952991724014282), (u'pinus_densiflora', 0.7783148288726807)]
# [(u'peach', 0.945297360420227), (u'citrus', 0.9351893663406372), (u'flower', 0.9227278232574463)]
#
# milk_fat
# [(u'cocoa_leaf', 0.7973200082778931), (u'feronia_elephantum', 0.7970330119132996), (u'limburger_cheese', 0.7934846878051758)]
# [(u'white_bread', 0.9002647995948792), (u'lemon_peel', 0.8738971948623657), (u'lard', 0.8643109798431396)]
#
# celery
# [(u'artemisia_cina', 0.8246279358863831), (u'berry_bud', 0.7956815361976624), (u'thea_chinensis_oil', 0.7944358587265015)]
# [(u'smoked_sausage', 0.9205232262611389), (u'bay', 0.9153846502304077), (u'beef_broth', 0.8813264966011047)]
#
# mung_bean
# [(u'larix_deciduas', 0.7803834676742554), (u'siam_benzoin', 0.7672104239463806), (u'eucalyptus_dives_oil', 0.7660739421844482)]
# [(u'boneless_sirloin_steak', 0.9363162517547607), (u'dried_scallops', 0.9350672960281372), (u'asian_eggplants', 0.9293093085289001)]
#
# rice
# [(u'seseli_sibiricum', 0.831873893737793), (u'robinia_pseudoacacia', 0.7978394627571106), (u'lantana_camara_oil', 0.7899185419082642)]
# [(u'vegetable', 0.8996731042861938), (u'cabbage', 0.8834643959999084), (u'shrimp', 0.818962574005127)]
#
# orange_juice
# [(u'brassica', 0.7903794646263123), (u'brown_rice', 0.7899518013000488), (u'citrus_peel_oil', 0.7826691269874573)]
# [(u'pear', 0.9312636256217957), (u'cranberry', 0.8969635367393494), (u'honey', 0.8947780132293701)]
#
# litchi
# [(u'fermented_tea', 0.8241167068481445), (u'raw_lamb', 0.8079581260681152), (u'mandarin_leaf_oil', 0.7894206047058105)]
# [(u'quail_eggs', 0.9702150225639343), (u'self_raising_flour', 0.9696414470672607), (u'sandwiches', 0.9689955711364746)]
#
# grape_juice
# [(u'raw_beef', 0.8646216988563538), (u'chamomile_oil', 0.8473243713378906), (u'artemisia_transiliensis', 0.8159343600273132)]
# [(u'olive_oil', 0.9167998433113098), (u'red_wine', 0.9089835286140442), (u'chicory', 0.8871457576751709)]
#
# mutton
# [(u'citronella_oil', 0.7993917465209961), (u'litchi', 0.7632659673690796), (u'eucalyptus_macarthurii', 0.7502578496932983)]
# [(u'ground_tumeric', 0.9794424176216125), (u'dried_chickpeas', 0.9655886888504028), (u'yellow_lentils', 0.9597713947296143)]
#
# roasted_peanut
# [(u'salmon_roe', 0.8133900165557861), (u'chamaecyparis_pisifera', 0.8008977174758911), (u'myrtle', 0.7937278747558594)]
# [(u'peanut_butter', 0.8305386304855347), (u'peanut_oil', 0.7854040861129761), (u'peanut', 0.7612056136131287)]
#
# whiskey
# [(u'american_peppermint_oil', 0.7954940795898438), (u'uncured_smoked_pork', 0.7831239104270935), (u'eucalyptus_oil', 0.770439624786377)]
# [(u'peaches', 0.8967342972755432), (u'golden_brown_sugar', 0.8923816680908203), (u'pecans', 0.8808737993240356)]
#
# elderberry
# [(u'coprosma_foetidissima_leaf', 0.8159276247024536), (u'polianthes_tuberosa_oil', 0.7946926951408386), (u'wood_oil', 0.7920503616333008)]
# [(u'satsumas', 0.9884425401687622), (u'amaretto_liqueur', 0.9879955649375916), (u'sweet_vermouth', 0.9853962063789368)]
#
# roasted_meat
# [(u'champaca', 0.7975268959999084), (u'raspberry_brandy', 0.7775720953941345), (u'raspberry', 0.7637200355529785)]
# [(u'small_red_beans', 0.9001516103744507), (u'catsup', 0.8873574137687683), (u'crumbled_cornbread', 0.8758276700973511)]
#
# lemon_peel
# [(u'nezara_viridula', 0.8290452361106873), (u'petitgrain_lime', 0.7766363620758057), (u'bitter_fennel', 0.7747226357460022)]
# [(u'milk_fat', 0.8738970756530762), (u'smoked_salmon', 0.8685592412948608), (u'goat_cheese', 0.8354082107543945)]
#
# cantaloupe
# [(u'cucumber', 0.8286035060882568), (u'polyalthia_canangioides_flower', 0.8234149217605591), (u'mandarin_leaf_oil', 0.8134641647338867)]
# [(u'navel_oranges', 0.9242994785308838), (u'lemonade', 0.9238021969795227), (u'simple_syrup', 0.9176504611968994)]
#
# jasmine
# [(u'chamomile', 0.8231003284454346), (u'petrosimonia_monandra', 0.8182586431503296), (u'american_peppermint_oil', 0.7952581644058228)]
# [(u'red_curry_paste', 0.95542973279953), (u'prawns', 0.9532291889190674), (u'thai_green_curry_paste', 0.9490102529525757)]
#
# brassica
# [(u'rye_flour', 0.8543230891227722), (u'turpentine', 0.8450663089752197), (u'estragon', 0.8348228335380554)]
# [(u'black_pepper', 0.9148694276809692), (u'roasted_beef', 0.889687180519104), (u'smoke', 0.8861253261566162)]
#
# berry
# [(u'hedychium_spicatum', 0.7933294773101807), (u'phallus_impudicus', 0.7793118953704834), (u'winter_savory', 0.7630359530448914)]
# [(u'raspberry', 0.9466925263404846), (u'pistachio', 0.9397869110107422), (u'blackberry', 0.9340287446975708)]
#
# blue_cheese
# [(u'mint_oil', 0.8268766403198242), (u'potato_chip', 0.8179563879966736), (u'crisp_bread', 0.8009333610534668)]
# [(u'goat_cheese', 0.9633331894874573), (u'chicory', 0.8679727911949158), (u'cottage_cheese', 0.8436024785041809)]
#
# scallop
# [(u'tequila', 0.7997390031814575), (u'basil_oil', 0.796696662902832), (u'vinegar', 0.7957891821861267)]
# [(u'white_wine', 0.9337131977081299), (u'lobster', 0.9309666156768799), (u'mussel', 0.9191817045211792)]
#
# pear_brandy
# [(u'mantis_shrimp', 0.7703420519828796), (u'raspberry_juice', 0.7662361860275269), (u'juniper_berry', 0.7516794204711914)]
# [(u'grape_brandy', 0.9814103841781616), (u'orange_flower', 0.975719690322876), (u'violet', 0.9670935273170471)]
#
# turkey
# [(u'eucalyptus_cinereea', 0.8184776902198792), (u'bergamot_oil', 0.7898129820823669), (u'bacon', 0.7843643426895142)]
# [(u'tomato', 0.8851786255836487), (u'beef', 0.8355684280395508), (u'lima_bean', 0.8264639377593994)]
#
# shiitake
# [(u'crownberry', 0.7825249433517456), (u'shoro', 0.7637671232223511), (u'orange_peel', 0.7609660625457764)]
# [(u'oyster', 0.9572380781173706), (u'soy_sauce', 0.8698389530181885), (u'sesame_oil', 0.8650667071342468)]
#
# parsley
# [(u'melon', 0.8105292320251465), (u'sage', 0.8025025129318237), (u'muscat_grape_juice', 0.7995624542236328)]
# [(u'savory', 0.8950580358505249), (u'white_wine', 0.8768720030784607), (u'rosemary', 0.8588370680809021)]
#
# grapefruit
# [(u'irish_whiskey', 0.8566645383834839), (u'guava_peel', 0.8058324456214905), (u'french_peppermint_oil', 0.782532811164856)]
# [(u'watermelon', 0.9676203727722168), (u'melon', 0.9642713665962219), (u'gin', 0.9278600811958313)]
#
# roasted_beef
# [(u'peanut_butter', 0.8302195072174072), (u'french_peppermint_oil', 0.8194457292556763), (u'palmarosa_oil', 0.8006730079650879)]
# [(u'smoke', 0.9601537585258484), (u'tomato_juice', 0.9222301840782166), (u'beef_broth', 0.9121639728546143)]
#
# red_wine
# [(u'cypress_oil', 0.7813544869422913), (u'eucalyptus_dives', 0.774811863899231), (u'crownberry', 0.7618744373321533)]
# [(u'vinegar', 0.91115802526474), (u'black_pepper', 0.9107780456542969), (u'grape_juice', 0.9089835286140442)]
#
# liver
# [(u'paraguay_petitgrain', 0.7549159526824951), (u'pandanus_odoratissimus_oil', 0.7512588500976562), (u'thujopsis_dolabrata', 0.7458862662315369)]
# [(u'rutabaga', 0.9287664294242859), (u'sage', 0.9045877456665039), (u'chicken_liver', 0.889478862285614)]
#
# capsicum
# [(u'berry_bud', 0.7801443934440613), (u'yellow_mombin', 0.7738629579544067), (u'pomelo_peel', 0.7726960182189941)]
# [(u'asafetida', 0.9510199427604675), (u'amchur', 0.9501623511314392), (u'gram_flour', 0.9468562602996826)]
#
# potato_chip
# [(u'berry_bud', 0.8485373258590698), (u'blue_cheese', 0.8179563879966736), (u'wine', 0.7677507996559143)]
# [(u'wheat_bread', 0.9534938335418701), (u'cottage_cheese', 0.8941471576690674), (u'swiss_cheese', 0.8898525834083557)]
#
# black_currant
# [(u'garlic', 0.8020609021186829), (u'strawberry_oil', 0.8013826608657837), (u'peanut_butter', 0.7873936295509338)]
# [(u'sassafras', 0.9537512063980103), (u'cherry_brandy', 0.9523007273674011), (u'orange_flower', 0.9452196955680847)]
#
# coffee
# [(u'krill', 0.794217050075531), (u'cistus_ladaniferus', 0.7873193025588989), (u'haddock', 0.7847039699554443)]
# [(u'macadamia_nut', 0.9334611892700195), (u'cocoa', 0.9207687377929688), (u'sour_milk', 0.9058360457420349)]
#
# red_kidney_bean
# [(u'boronia_anemonifolia', 0.8282986283302307), (u'chickpea', 0.8069323301315308), (u'uncured_smoked_pork', 0.8049229383468628)]
# [(u'kidney_bean', 0.9469362497329712), (u'tomato_juice', 0.9201464056968689), (u'corn_grit', 0.8781498670578003)]
#
# macaroni
# [(u'boronia_ledifolia_leaf', 0.7968611717224121), (u'iberis_sempervirens_seed', 0.781499445438385), (u'smoked_pork', 0.7721109986305237)]
# [(u'cured_pork', 0.9059346318244934), (u'mozzarella_cheese', 0.8920379877090454), (u'artichoke', 0.8873295187950134)]
#
# catfish
# [(u'basil_oil', 0.848817765712738), (u'carob', 0.8371692895889282), (u'orthodon_linalooliferum', 0.8109788298606873)]
# [(u'hot_sauce', 0.8030354976654053), (u'heinz_chili_sauce', 0.7954467535018921), (u'frankfurter', 0.7731499075889587)]
#
# vegetable
# [(u'buchu_leaf_oil', 0.7675613164901733), (u'red_meat', 0.7505545616149902), (u'cocoa_leaf', 0.7461881637573242)]
# [(u'rice', 0.8996731042861938), (u'cabbage', 0.82979416847229), (u'chicken', 0.818291425704956)]
#
# fruit
# [(u'raw_pork', 0.8216776251792908), (u'annona_reticulata', 0.7958433032035828), (u'pimenta', 0.7862100601196289)]
# [(u'rum', 0.9672534465789795), (u'pistachio', 0.9501911997795105), (u'black_tea', 0.9345245957374573)]
#
# garlic
# [(u'fermented_shrimp', 0.8729358911514282), (u'strawberry_oil', 0.8597233891487122), (u'raspberry_oil', 0.8348233103752136)]
# [(u'chicken', 0.8572914004325867), (u'shrimp', 0.7923150658607483), (u'cayenne', 0.7921210527420044)]
#
# pimento
# [(u'raspberry', 0.8322830200195312), (u'melilotus_albus_leaf', 0.7918590903282166), (u'calytrix_virgata', 0.7871139049530029)]
# [(u'macaroni', 0.8353472948074341), (u'bell_pepper', 0.8244422674179077), (u'tuna', 0.8200119137763977)]
#
# tuna
# [(u'chinese_quince_peel', 0.8450828790664673), (u'litsea_guatemalensis', 0.8279460668563843), (u'dried_spinach', 0.8230080008506775)]
# [(u'crab', 0.8803055286407471), (u'pimento', 0.8200118541717529), (u'cucumber', 0.8126185536384583)]
#
# salmon_roe
# [(u'roasted_peanut', 0.8133900165557861), (u'spermaceti_oil', 0.8121116161346436), (u'hop', 0.7854468822479248)]
# [(u'caviar', 0.9633718729019165), (u'smoked_fish', 0.9408991932868958), (u'blackening_seasoning', 0.8842088580131531)]
#
# brown_rice
# [(u'orange_juice', 0.7899518013000488), (u'kelp', 0.788783073425293), (u'saxifragaceae', 0.784522533416748)]
# [(u'barley', 0.8861750364303589), (u'pea', 0.8735659122467041), (u'lentil', 0.8600338101387024)]
#
# butter
# [(u'onion_oil', 0.8520727157592773), (u'aconitum_napellus', 0.8219580054283142), (u'agarwood', 0.7885253429412842)]
# [(u'yeast', 0.8634133338928223), (u'gruyere_cheese', 0.8216875791549683), (u'lard', 0.7712303400039673)]
#
# orange_peel
# [(u'bulgarian_clary_sage_oil', 0.8078281879425049), (u'squash', 0.7818249464035034), (u'pinus_densiflora', 0.7786765098571777)]
# [(u'almond', 0.9216070175170898), (u'citrus', 0.9016456604003906), (u'peach', 0.901530921459198)]
#
# kale
# [(u'brandy', 0.8104569911956787), (u'prunus', 0.8086119294166565), (u'coffee_flower', 0.8064855337142944)]
# [(u'pepper', 0.9064314365386963), (u'thyme', 0.8928690552711487), (u'bay', 0.8909082412719727)]
#
# roasted_pork
# [(u'monarda_citriodora_oil', 0.7894386649131775), (u'chicken_liver', 0.780363142490387), (u'roasted_sesame_seed', 0.76038658618927)]
# [(u'red_wine', 0.8823691606521606), (u'brussels_sprout', 0.8472099900245667), (u'juniper_berry', 0.8463401198387146)]
#
# rose
# [(u'eucalyptus_cinereea', 0.8032833933830261), (u'wort', 0.8001652956008911), (u'pinus_densiflora', 0.7801432013511658)]
# [(u'flower', 0.9406195282936096), (u'fruit', 0.9297439455986023), (u'date', 0.9211567640304565)]
#
# lime_juice
# [(u'eriostemon_coxii_leaf_oil', 0.7696025371551514), (u'tea_oil', 0.7440378665924072), (u'jamaican_rum', 0.7371179461479187)]
# [(u'mango', 0.8479103446006775), (u'cilantro', 0.8013710975646973), (u'papaya', 0.769105851650238)]
#
# horseradish
# [(u'red_currant', 0.8126004934310913), (u'black_seabream', 0.7913118004798889), (u'pinus_communis_oil', 0.7901031970977783)]
# [(u'smoke', 0.8342230319976807), (u'rye_bread', 0.8257229328155518), (u'mustard', 0.825326144695282)]
#
# kelp
# [(u'michelia_champaca_oil', 0.8245983719825745), (u'sauerkraut', 0.8176758289337158), (u'cananga', 0.8097264766693115)]
# [(u'chinese_cabbage', 0.981316089630127), (u'nira', 0.964725911617279), (u'enokidake', 0.9640241861343384)]
#
# galanga
# [(u'corn_salad', 0.8073365688323975), (u'french_bean', 0.7958866953849792), (u'cicuta_virosa_oil', 0.7783769965171814)]
# [(u'lemongrass', 0.9685888886451721), (u'palm', 0.9515712261199951), (u'red_curry_paste', 0.944585919380188)]
#
# kumquat
# [(u'oriental_storax', 0.8273884057998657), (u'rhus_semialata', 0.8233035802841187), (u'cupressus_macrocarpa_oil', 0.814992368221283)]
# [(u'grape_brandy', 0.9461247324943542), (u'huckleberry', 0.9447954297065735), (u'orange_flower', 0.9429233074188232)]
#
# endive
# [(u'guava', 0.8293793201446533), (u'jamaican_rum', 0.8114755749702454), (u'tuna', 0.7963751554489136)]
# [(u'chicory', 0.9018827080726624), (u'chervil', 0.8972461223602295), (u'tarragon', 0.8912399411201477)]
#
# concord_grape
# [(u'juniperus_chinensis_oil', 0.7966611385345459), (u'mackerel', 0.7833249568939209), (u'tea_tree_oil', 0.7750416994094849)]
# [(u'pie_filling', 0.9714416265487671), (u'licorice', 0.9686142802238464), (u'grape_brandy', 0.965661883354187)]
#
# thyme
# [(u'basil', 0.775486946105957), (u'pinus_jeffreyi_terpentine', 0.7750933170318604), (u'california_pepper', 0.7648176550865173)]
# [(u'sage', 0.9238771200180054), (u'marjoram', 0.9008453488349915), (u'kale', 0.8928690552711487)]
#
# eel
# [(u'thuja_plicata', 0.8280524015426636), (u'cognac_oil', 0.8169819712638855), (u'zingiberaceae', 0.8090872168540955)]
# [(u'shellfish', 0.947868824005127), (u'mackerel', 0.944613516330719), (u'katsuobushi', 0.9440261125564575)]
#
# blackberry
# [(u'litsea_zeylanica_oil', 0.7772901058197021), (u'chinese_cinnamon', 0.7592053413391113), (u'orange_flower', 0.7511478662490845)]
# [(u'blueberry', 0.9630689024925232), (u'gelatin', 0.9612394571304321), (u'pistachio', 0.9424611926078796)]
#
# lobster
# [(u'boldea_fragrans', 0.8041922450065613), (u'chinese_quince', 0.7958304286003113), (u'chayote', 0.794916570186615)]
# [(u'scallop', 0.9309666156768799), (u'white_wine', 0.8961889743804932), (u'mussel', 0.8767597079277039)]
#
# chicken_liver
# [(u'grapefruit_juice', 0.8017702102661133), (u'roasted_pork', 0.780363142490387), (u'rue', 0.7696163654327393)]
# [(u'brussels_sprout', 0.9392240643501282), (u'liver', 0.889478862285614), (u'gruyere_cheese', 0.8525930643081665)]
#
# pea
# [(u'chestnut_honey', 0.7778631448745728), (u'orange_oil', 0.762958824634552), (u'apple_sauce', 0.7594260573387146)]
# [(u'cod', 0.9184492826461792), (u'mussel', 0.9142735600471497), (u'brown_rice', 0.8735657930374146)]
#
# rum
# [(u'strawberry_oil', 0.7824612855911255), (u'spanish_origanum', 0.7810109853744507), (u'orris', 0.7746808528900146)]
# [(u'fruit', 0.9672533869743347), (u'rose', 0.9133141040802002), (u'tea', 0.9119576811790466)]
#
# corn
# [(u'doryphora_sassafras_leaf_oil', 0.8018075823783875), (u'muscat_grape', 0.774742841720581), (u'spearmint_scotch_oil', 0.7714691162109375)]
# [(u'celery_oil', 0.8148430585861206), (u'beer', 0.7143173813819885), (u'tamarind', 0.713090181350708)]
#
# carob
# [(u'brazilian_sassafras_oil', 0.8390886783599854), (u'catfish', 0.8371692895889282), (u'russian_star_anise', 0.8032128810882568)]
# [(u'guava', 0.9759151935577393), (u'demerara_sugar', 0.9612172245979309), (u'self_raising_flour', 0.9609712958335876)]
#
# plum
# [(u'black_chokeberry', 0.773461103439331), (u'while_thyme_oil', 0.7546613812446594), (u'horseradish', 0.7459773421287537)]
# [(u'pitted_green_olives', 0.8839900493621826), (u'green_olives', 0.8730794191360474), (u'pitted_kalamata_olives', 0.8384526968002319)]
#
# swiss_cheese
# [(u'chinese_quince', 0.7993496060371399), (u'ruta_pinnata_leaf_oil', 0.7957471013069153), (u'south_african_mentha_longifolia', 0.7801787257194519)]
# [(u'rye_bread', 0.9075366854667664), (u'cheddar_cheese', 0.893813967704773), (u'egg_noodle', 0.893531084060669)]
#
# chive
# [(u'avocado', 0.8076429963111877), (u'abies_concolor', 0.7994791865348816), (u'cayenne', 0.7927682995796204)]
# [(u'smoked_salmon', 0.8917860388755798), (u'vegetable_oil', 0.8351729512214661), (u'horseradish', 0.764533281326294)]
#
# white_bread
# [(u'peanut_butter', 0.7847252488136292), (u'pine_turpentine', 0.7664879560470581), (u'rhus_cotinus_leaf', 0.7597392797470093)]
# [(u'milk_fat', 0.9002647399902344), (u'swiss_cheese', 0.8901389241218567), (u'wheat_bread', 0.8580257892608643)]
#
# bitter_orange
# [(u'strawberry_jam', 0.8458412885665894), (u'plant', 0.8133142590522766), (u'cabbage_juice', 0.8020698428153992)]
# [(u'berry', 0.9138637781143188), (u'tangerine', 0.9064815044403076), (u'brandy', 0.8978104591369629)]
#
# gin
# [(u'leptospermum_liversidgei', 0.8509013056755066), (u'morus_bombycis_oil', 0.8303262591362), (u'mexican_linaloe', 0.809395968914032)]
# [(u'ice_cubes', 0.9463828206062317), (u'simple_syrup', 0.9401587843894958), (u'melon', 0.9283367991447449)]
#
# prawn
# [(u'shellfish', 0.7930630445480347), (u'frankfurter', 0.7824587225914001), (u'cucumber', 0.7775309085845947)]
# [(u'galanga', 0.9262542128562927), (u'thai_chile', 0.9196956157684326), (u'palm', 0.9181674718856812)]
#
# basil
# [(u'litsea_guatemalensis', 0.7801010608673096), (u'pinus_jeffreyi_terpentine', 0.776159405708313), (u'thyme', 0.775486946105957)]
# [(u'artichoke', 0.8816958069801331), (u'macaroni', 0.8628416061401367), (u'zucchini', 0.8526899814605713)]
#
# strawberry
# [(u'vetiver', 0.8107212781906128), (u'robinia_pseudoacacia', 0.8103935122489929), (u'pinus_jeffreyi', 0.7842714190483093)]
# [(u'gelatin', 0.9696444272994995), (u'raspberry', 0.9683679342269897), (u'blueberry', 0.9276282787322998)]
#
# palm
# [(u'saigon_cinnamon', 0.7930048704147339), (u'fried_cured_pork', 0.7625491619110107), (u'wasabi', 0.7534617185592651)]
# [(u'lemongrass', 0.9711682796478271), (u'thai_chile', 0.9650111198425293), (u'galangal', 0.9573900103569031)]
#
# cacao
# [(u'polyalthia_canangioides_flower', 0.797516942024231), (u'cantaloupe', 0.7831487059593201), (u'sumatra_benzoin', 0.7817354798316956)]
# [(u'cookies', 0.9726321697235107), (u'frozen_whip_topping_thaw', 0.9651062488555908), (u'ladyfingers', 0.9643415212631226)]
#
# cream
# [(u'polianthes_tuberosa_oil', 0.7585176229476929), (u'shiitake', 0.7583834528923035), (u'wasabi', 0.7581130266189575)]
# [(u'wheat_bread', 0.7372668385505676), (u'milk', 0.7302746772766113), (u'potato_chip', 0.7214514017105103)]
#
# mushroom
# [(u'waste_wort', 0.7847774028778076), (u'fermented_tea', 0.7795740365982056), (u'melaleuca_oil', 0.7626363039016724)]
# [(u'egg_noodle', 0.8936111927032471), (u'brassica', 0.850556492805481), (u'bacon', 0.8485749959945679)]
#
# red_bean
# [(u'rhus_cotinus_leaf', 0.8136290311813354), (u'russian_star_anise', 0.7974250912666321), (u'turmeric', 0.7946746349334717)]
# [(u'black_sesame_seed', 0.9668110609054565), (u'mandarin_peel', 0.9495296478271484), (u'green_tea', 0.9220585823059082)]
#
# pear
# [(u'basil_oil', 0.8127850890159607), (u'lean_fish', 0.8052064180374146), (u'crownberry', 0.7757843732833862)]
# [(u'orange_juice', 0.9312635660171509), (u'champagne_wine', 0.8862744569778442), (u'almond', 0.8432650566101074)]
#
# squash
# [(u'ceanothus_velutinus_leaf', 0.8006439208984375), (u'orange_peel', 0.7818249464035034), (u'mimusops_elengi_flower', 0.7709707021713257)]
# [(u'fennel', 0.789490818977356), (u'zucchini', 0.7733033895492554), (u'oregano', 0.7556366920471191)]
#
# brandy
# [(u'kale', 0.8104568719863892), (u'ceanothus_velutinus_leaf', 0.7985625863075256), (u'grapefruit_blossom', 0.7948442101478577)]
# [(u'fig', 0.9333977699279785), (u'bitter_orange', 0.8978104591369629), (u'tangerine', 0.8712709546089172)]
#
# okra
# [(u'dalbergia_sissoo', 0.8477184772491455), (u'american_potato_chip', 0.8444538116455078), (u'brazil_peppermint_oil', 0.8056022524833679)]
# [(u'smoked_sausage', 0.9319584965705872), (u'black_eyed_peas', 0.9152867197990417), (u'andouille_sausage', 0.8974738121032715)]
